# %% [markdown]
# el valor de A_v para slit 1 es 0.441226171766746134+/-0.102598650110381065
#
# el valor de A_v para slit 3 es 0.220109655543697047+/-0.079875592976604501
#
# el valor de A_v para slit 4 es 0.162772720404793236+/-0.072723075951692570
#
# el valor de A_v para slit 7 es 0.434375276975023483+/-0.112248861257837951
#
# el valor de A_v para slit 8 es 0.232001529467910389+/-0.077635817723874484
#
# el valor de A_v para slit 9 es 0.178049898704286974+/-0.063493920171655546
#
# el valor de A_v para slit 10 es 0.036289577167067204+/-0.097411325074392346
#
# el valor de A_v para slit 11 es 0.511335672370859973+/-0.120917657104915768
#
# el valor de A_v para slit 12 es 0.051533815345795958+/-0.089682145987302203
#
# el valor de A_v para slit 13 es 0.114917177494059011+/-0.064936715799579520
#
# el valor de A_v para slit 14 es 0.357939452119454771+/-0.091591472190163711
#
# el valor de A_v para slit 16 es 0.355091960032595078+/-0.117486462374847139
#
# el valor de A_v para slit 17 es 0.219347601674380333+/-0.069516027409266989
#
# el valor de A_v para slit 19 es 0.238846589107888641+/-0.090919169966305516
#
# el valor de A_v para slit 21 mask 1 es 0.718120235736187107+/-0.163053526958214540
#
# el valor de A_v para slit 21 mask 2 es 0.063822766913487677+/-0.114646696554907432
#
# el valor de A_v para slit 23 mask 1 es 0.134484332586560423+/-0.064399973428184085
#
# el valor de A_v para slit 25 es 0.031173215562035488+/-0.244375504902843182
#
# el valor de A_v para slit 27 es 0.160620793356388541+/-0.410233698333169639

# %%
A_v1 = 0.441226171366746134
A_v3 = 0.220109655543697047
A_v4 = 0.162772720404793236
A_v7 = 0.434375276975023483
A_v8 = 0.232001529467910389
A_v9 = 0.178049898704286974
A_v10 = 0.036289577167067204
A_v11 = 0.511335672370859973
A_v12 = 0.051533815345795958
A_v13 = 0.114917177494059011
A_v14 = 0.357939452119454771
A_v16 = 0.355091960032595078
A_v17 = 0.219347601674380333
A_v19 = 0.238846589107888641
A_v21_1 = 0.718120235736187107
A_v21_2 = 0.063822766913487677
A_v23_1 = 0.134484332586560423
A_v25 = 0.031173215562035488
A_v27 = 0.160620793356388541

# %%
import astropy
from astropy.io import fits
import numpy as np
import matplotlib.pyplot as plt
from astropy.wcs import WCS

# %% [markdown]
# MASK 1

# %%
#slit 1, now sin f99
#abrir mi fits
#slit1_f99 = '../../Documentos/RESPALDO/NGC1313_250624_extinction/datos/slit1_2D_f99.fits'
slit1 = '../../../reduccion/NGC1313/espectros_oficiales/slit1.fits'
sp1 = fits.open(slit1)

sp1.info()
sp1[0].header["OBJECT"]
# Out:
# Filename: ../../../reduccion/NGC1313/espectros_oficiales/slit1.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      71   (2234, 1)   float32
# 'NGC1313-MSK01 2D CON LACOS'

# %%
# extraer data (flux sin corregir por galáctica)
data1=sp1[0].data
header1=sp1[0].header
obj_name1 = header1.get("OBJECT", "Unknown")

flux1=data1[0]
w1=WCS(header1, naxis=1, relax=False, fix=False)
wave1=w1.wcs_pix2world(np.arange(len(flux1)),0)[0]

plt.plot(wave1, flux1)
plt.title("Espectro slit 1 sin corrección galáctica")
plt.xlabel('Wavelength (Angstrom)')
plt.ylabel('Flux $(erg\ cm^{-2} s^{-1} A^{-1} · 1 x 10^{-15})$')
# Out:
# <>:13: SyntaxWarning: invalid escape sequence '\ '
# <>:13: SyntaxWarning: invalid escape sequence '\ '
# /var/folders/1d/sms3rjzs38jbhp0zx04sz91c0000gn/T/ipykernel_3374/60182647.py:13: SyntaxWarning: invalid escape sequence '\ '
#   plt.ylabel('Flux $(erg\ cm^{-2} s^{-1} A^{-1} · 1 x 10^{-15})$')
# WARNING: FITSFixedWarning: RADECSYS= 'FK5 ' / R.A./DEC. coordinate system reference
# the RADECSYS keyword is deprecated, use RADESYSa. [astropy.wcs.wcs]
# Text(0, 0.5, 'Flux $(erg\\ cm^{-2} s^{-1} A^{-1} · 1 x 10^{-15})$')

# %%
wave1, flux1
# Out:
# (array([4024.00463867, 4025.50053573, 4026.99643278, ..., 7361.35096765,
#         7362.8468647 , 7364.34276175]),
#  array([0.28093654, 0.1263353 , 0.66459733, ..., 0.07287291, 0.07423379,
#         0.06625135], dtype='>f4'))

# %%
# %matplotlib inline
plt.figure(figsize=(10, 6))
plt.plot(wave1, flux1, linestyle='-', color='b')
plt.xlabel('Wavelength (Angstrom)')
plt.ylabel('Flux $(erg\ cm^{-2} s^{-1} A^{-1} · 1x 10^{-15})$')
plt.title('Espectro slit 1 sin corección galáctica')
plt.grid(True)
plt.show()
# Out:
# <>:5: SyntaxWarning: invalid escape sequence '\ '
# <>:5: SyntaxWarning: invalid escape sequence '\ '
# /var/folders/1d/sms3rjzs38jbhp0zx04sz91c0000gn/T/ipykernel_3374/719868734.py:5: SyntaxWarning: invalid escape sequence '\ '
#   plt.ylabel('Flux $(erg\ cm^{-2} s^{-1} A^{-1} · 1x 10^{-15})$')

# %%
import extinction
from extinction import calzetti00

#tengo mi array de longitudes de onda de todo el espectro: wave1
# Calzetti+2000 with A_V = según el slit and R_V = 4.05
# mi A_v es A_v1m ojo que aquí estoy asumiendo que la MW es starburst !
wave1_c00 = extinction.calzetti00(wave1, A_v1, 4.05)
print(f' extinción en magnitudes para slit 1 con calzetti00: {wave1_c00}') #array of extinction in magnitudes at each input wavelength
# Out:
#  extinción en magnitudes para slit 1 con calzetti00: [0.59766521 0.59747024 0.59727536 ... 0.31254393 0.31246078 0.31237766]

# %%
from extinction import calzetti00, remove

print(f'valor de flujo sin corregir para slit 1: {flux1}')

# "deredden" flux by A_v1 with calzetti+2000
flux1_c00 = remove(calzetti00(wave1, A_v1, 4.05), flux1)
print(f'valor de flujo deredden para slit 1 con calzetti00: {flux1_c00}')
# Out:
# valor de flujo sin corregir para slit 1: [0.28093654 0.1263353  0.66459733 ... 0.07287291 0.07423379 0.06625135]
# valor de flujo deredden para slit 1 con calzetti00: [0.48716302 0.21903463 1.15204313 ... 0.09718151 0.09898877 0.08833764]

# %%
# %matplotlib inline
plt.figure(figsize=(10, 6))
plt.plot(wave1, flux1_c00, linestyle='-', color='b')
plt.xlabel('Wavelength (Angstrom)')
plt.ylabel('Flux $(erg\ cm^{-2} s^{-1} A^{-1} · 1x 10^{-15})$')
plt.title('Espectro slit 1 desenrojecido sólo con calzetti+2000')
plt.grid(True)
plt.show()
# Out:
# <>:5: SyntaxWarning: invalid escape sequence '\ '
# <>:5: SyntaxWarning: invalid escape sequence '\ '
# /var/folders/1d/sms3rjzs38jbhp0zx04sz91c0000gn/T/ipykernel_3374/1164065302.py:5: SyntaxWarning: invalid escape sequence '\ '
#   plt.ylabel('Flux $(erg\ cm^{-2} s^{-1} A^{-1} · 1x 10^{-15})$')

# %%
# guardar info corregida en un nuevo fits
# metemos el array de flujo corregido a la data del espectro
data1[0] = flux1_c00

# crear nuevo HDU 
slit1corrected = fits.PrimaryHDU(data=data1, header=header1)

# crear nuevo HDUList para guardar en un fits
sp1_corrected = fits.HDUList([slit1corrected])

# guardar datos corregidos en un nuevo archivo FITS
#new_fits_file1 = '../../Documentos/RESPALDO/NGC1313_250624_extinction/datos/slit1_2D_f99_c00.fits'
new_fits_file1 = '../../../reduccion/NGC1313/espectros_oficiales/slit1_2D_c00.fits'
sp1_corrected.writeto(new_fits_file1, overwrite=True)

print(f"Se ha guardado el archivo FITS corregido: {new_fits_file1}")
# Out:
# Se ha guardado el archivo FITS corregido: ../../../reduccion/NGC1313/espectros_oficiales/slit1_2D_c00.fits

# %% [markdown]
# SLIT 3

# %%
#slit 1, now sin f99
#abrir mi fits
#slit1_f99 = '../../Documentos/RESPALDO/NGC1313_250624_extinction/datos/slit1_2D_f99.fits'
slit3 = '../../../reduccion/NGC1313/espectros_oficiales/slit3.fits'
sp3 = fits.open(slit3)

sp3.info()
sp3[0].header["OBJECT"]
# Out:
# Filename: ../../../reduccion/NGC1313/espectros_oficiales/slit3.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      71   (2225, 1)   float32
# 'NGC1313-MSK01 2D CON LACOS'

# %%
# extraer data (flux sin corregir por galáctica)
data3=sp3[0].data
header3=sp3[0].header
obj_name3 = header3.get("OBJECT", "Unknown")

flux3=data3[0]
w3=WCS(header3, naxis=1, relax=False, fix=False)
wave3=w3.wcs_pix2world(np.arange(len(flux3)),0)[0]

plt.plot(wave3, flux3)
plt.title("Espectro slit 3 sin corrección galáctica")
plt.xlabel('Wavelength (Angstrom)')
plt.ylabel('Flux $(erg\ cm^{-2} s^{-1} A^{-1} · 1 x 10^{-15})$')
# Out:
# <>:13: SyntaxWarning: invalid escape sequence '\ '
# <>:13: SyntaxWarning: invalid escape sequence '\ '
# /var/folders/1d/sms3rjzs38jbhp0zx04sz91c0000gn/T/ipykernel_3374/1099186249.py:13: SyntaxWarning: invalid escape sequence '\ '
#   plt.ylabel('Flux $(erg\ cm^{-2} s^{-1} A^{-1} · 1 x 10^{-15})$')
# WARNING: FITSFixedWarning: RADECSYS= 'FK5 ' / R.A./DEC. coordinate system reference
# the RADECSYS keyword is deprecated, use RADESYSa. [astropy.wcs.wcs]
# Text(0, 0.5, 'Flux $(erg\\ cm^{-2} s^{-1} A^{-1} · 1 x 10^{-15})$')

# %%
# %matplotlib inline
plt.figure(figsize=(10, 6))
plt.plot(wave3, flux3, linestyle='-', color='b')
plt.xlabel('Wavelength (Angstrom)')
plt.ylabel('Flux $(erg\ cm^{-2} s^{-1} A^{-1} · 1x 10^{-15})$')
plt.title('Espectro slit 3 sin corección galáctica')
plt.grid(True)
plt.show()
# Out:
# <>:5: SyntaxWarning: invalid escape sequence '\ '
# <>:5: SyntaxWarning: invalid escape sequence '\ '
# /var/folders/1d/sms3rjzs38jbhp0zx04sz91c0000gn/T/ipykernel_3374/310862709.py:5: SyntaxWarning: invalid escape sequence '\ '
#   plt.ylabel('Flux $(erg\ cm^{-2} s^{-1} A^{-1} · 1x 10^{-15})$')

# %%
import extinction
from extinction import calzetti00

#tengo mi array de longitudes de onda de todo el espectro: wave1
# Calzetti+2000 with A_V = según el slit and R_V = 4.05
# mi A_v es A_v1m ojo que aquí estoy asumiendo que la MW es starburst !
wave3_c00 = extinction.calzetti00(wave3, A_v3, 4.05)
print(f' extinción en magnitudes para slit 3 con calzetti00: {wave3_c00}') #array of extinction in magnitudes at each input wavelength
# Out:
#  extinción en magnitudes para slit 3 con calzetti00: [0.29809323 0.297996   0.29789882 ... 0.15627283 0.15623121 0.15618961]

# %%
from extinction import calzetti00, remove

print(f'valor de flujo sin corregir para slit 3: {flux3}')

# "deredden" flux by A_v1 with calzetti+2000
flux3_c00 = remove(calzetti00(wave3, A_v3, 4.05), flux3)
print(f'valor de flujo deredden para slit 3 con calzetti00: {flux3_c00}')
# Out:
# valor de flujo sin corregir para slit 3: [-0.21122663  0.23303586 -0.48038784 ...  0.02420557  0.02303245
#   0.0214294 ]
# valor de flujo deredden para slit 3 con calzetti00: [-0.27796234  0.3066346  -0.63205014 ...  0.02795275  0.026597
#   0.02474491]

# %%
# %matplotlib inline
plt.figure(figsize=(10, 6))
plt.plot(wave3, flux3_c00, linestyle='-', color='b')
plt.xlabel('Wavelength (Angstrom)')
plt.ylabel('Flux $(erg\ cm^{-2} s^{-1} A^{-1} · 1x 10^{-15})$')
plt.title('Espectro slit 3 desenrojecido sólo con calzetti+2000')
plt.grid(True)
plt.show()
# Out:
# <>:5: SyntaxWarning: invalid escape sequence '\ '
# <>:5: SyntaxWarning: invalid escape sequence '\ '
# /var/folders/1d/sms3rjzs38jbhp0zx04sz91c0000gn/T/ipykernel_3374/2632598431.py:5: SyntaxWarning: invalid escape sequence '\ '
#   plt.ylabel('Flux $(erg\ cm^{-2} s^{-1} A^{-1} · 1x 10^{-15})$')

# %%
# guardar info corregida en un nuevo fits
# metemos el array de flujo corregido a la data del espectro
data3[0] = flux3_c00

# crear nuevo HDU 
slit3corrected = fits.PrimaryHDU(data=data3, header=header3)

# crear nuevo HDUList para guardar en un fits
sp3_corrected = fits.HDUList([slit3corrected])

# guardar datos corregidos en un nuevo archivo FITS
#new_fits_file1 = '../../Documentos/RESPALDO/NGC1313_250624_extinction/datos/slit1_2D_f99_c00.fits'
new_fits_file3 = '../../../reduccion/NGC1313/espectros_oficiales/slit3_2D_c00.fits'
sp3_corrected.writeto(new_fits_file3, overwrite=True)

print(f"Se ha guardado el archivo FITS corregido: {new_fits_file3}")
# Out:
# Se ha guardado el archivo FITS corregido: ../../../reduccion/NGC1313/espectros_oficiales/slit3_2D_c00.fits

# %% [markdown]
# SLIT 7

# %%
#slit 1, now sin f99
#abrir mi fits
#slit1_f99 = '../../Documentos/RESPALDO/NGC1313_250624_extinction/datos/slit1_2D_f99.fits'
slit7 = '../../../reduccion/NGC1313/espectros_oficiales/slit7.fits'
sp7 = fits.open(slit7)

sp7.info()
sp7[0].header["OBJECT"]
# Out:
# Filename: ../../../reduccion/NGC1313/espectros_oficiales/slit7.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      71   (2178, 1)   float32
# 'NGC1313-MSK01 2D CON LACOS'

# %%
# extraer data (flux sin corregir por galáctica)
data7=sp7[0].data
header7=sp7[0].header
obj_name7 = header7.get("OBJECT", "Unknown")

flux7=data7[0]
w7=WCS(header7, naxis=1, relax=False, fix=False)
wave7=w7.wcs_pix2world(np.arange(len(flux7)),0)[0]

plt.plot(wave7, flux7)
plt.title("Espectro slit 7 sin corrección galáctica")
plt.xlabel('Wavelength (Angstrom)')
plt.ylabel('Flux $(erg\ cm^{-2} s^{-1} A^{-1} · 1 x 10^{-15})$')
# Out:
# <>:13: SyntaxWarning: invalid escape sequence '\ '
# <>:13: SyntaxWarning: invalid escape sequence '\ '
# /var/folders/1d/sms3rjzs38jbhp0zx04sz91c0000gn/T/ipykernel_3374/966805564.py:13: SyntaxWarning: invalid escape sequence '\ '
#   plt.ylabel('Flux $(erg\ cm^{-2} s^{-1} A^{-1} · 1 x 10^{-15})$')
# WARNING: FITSFixedWarning: RADECSYS= 'FK5 ' / R.A./DEC. coordinate system reference
# the RADECSYS keyword is deprecated, use RADESYSa. [astropy.wcs.wcs]
# Text(0, 0.5, 'Flux $(erg\\ cm^{-2} s^{-1} A^{-1} · 1 x 10^{-15})$')

# %%
# %matplotlib inline
plt.figure(figsize=(10, 6))
plt.plot(wave7, flux7, linestyle='-', color='b')
plt.xlabel('Wavelength (Angstrom)')
plt.ylabel('Flux $(erg\ cm^{-2} s^{-1} A^{-1} · 1x 10^{-15})$')
plt.title('Espectro slit 7 sin corección galáctica')
plt.grid(True)
plt.show()
# Out:
# <>:5: SyntaxWarning: invalid escape sequence '\ '
# <>:5: SyntaxWarning: invalid escape sequence '\ '
# /var/folders/1d/sms3rjzs38jbhp0zx04sz91c0000gn/T/ipykernel_3374/3076149611.py:5: SyntaxWarning: invalid escape sequence '\ '
#   plt.ylabel('Flux $(erg\ cm^{-2} s^{-1} A^{-1} · 1x 10^{-15})$')

# %%
import extinction
from extinction import calzetti00

#tengo mi array de longitudes de onda de todo el espectro: wave1
# Calzetti+2000 with A_V = según el slit and R_V = 4.05
# mi A_v es A_v1m ojo que aquí estoy asumiendo que la MW es starburst !
wave7_c00 = extinction.calzetti00(wave7, A_v7, 4.05)
print(f' extinción en magnitudes para slit 7 con calzetti00: {wave7_c00}') #array of extinction in magnitudes at each input wavelength
# Out:
#  extinción en magnitudes para slit 7 con calzetti00: [0.58867689 0.58848473 0.58829265 ... 0.31237135 0.31228754 0.31220377]

# %%
from extinction import calzetti00, remove

print(f'valor de flujo sin corregir para slit 7: {flux7}')

# "deredden" flux by A_v1 with calzetti+2000
flux7_c00 = remove(calzetti00(wave7, A_v7, 4.05), flux7)
print(f'valor de flujo deredden para slit 7 con calzetti00: {flux7_c00}')
# Out:
# valor de flujo sin corregir para slit 7: [0.         0.         0.         ... 0.02432255 0.02350372 0.02177298]
# valor de flujo deredden para slit 7 con calzetti00: [0.         0.         0.         ... 0.0324308  0.03133659 0.02902682]

# %%
# %matplotlib inline
plt.figure(figsize=(10, 6))
plt.plot(wave7, flux7_c00, linestyle='-', color='b')
plt.xlabel('Wavelength (Angstrom)')
plt.ylabel('Flux $(erg\ cm^{-2} s^{-1} A^{-1} · 1x 10^{-15})$')
plt.title('Espectro slit 7 desenrojecido sólo con calzetti+2000')
plt.grid(True)
plt.show()
# Out:
# <>:5: SyntaxWarning: invalid escape sequence '\ '
# <>:5: SyntaxWarning: invalid escape sequence '\ '
# /var/folders/1d/sms3rjzs38jbhp0zx04sz91c0000gn/T/ipykernel_3374/77016319.py:5: SyntaxWarning: invalid escape sequence '\ '
#   plt.ylabel('Flux $(erg\ cm^{-2} s^{-1} A^{-1} · 1x 10^{-15})$')

# %%
# guardar info corregida en un nuevo fits
# metemos el array de flujo corregido a la data del espectro
data7[0] = flux7_c00

# crear nuevo HDU 
slit7corrected = fits.PrimaryHDU(data=data7, header=header7)

# crear nuevo HDUList para guardar en un fits
sp7_corrected = fits.HDUList([slit7corrected])

# guardar datos corregidos en un nuevo archivo FITS
#new_fits_file1 = '../../Documentos/RESPALDO/NGC1313_250624_extinction/datos/slit1_2D_f99_c00.fits'
new_fits_file7 = '../../../reduccion/NGC1313/espectros_oficiales/slit7_2D_c00.fits'
sp7_corrected.writeto(new_fits_file7, overwrite=True)

print(f"Se ha guardado el archivo FITS corregido: {new_fits_file7}")
# Out:
# Se ha guardado el archivo FITS corregido: ../../../reduccion/NGC1313/espectros_oficiales/slit7_2D_c00.fits

# %% [markdown]
# SLIT 9

# %%
#slit 1, now sin f99
#abrir mi fits
#slit1_f99 = '../../Documentos/RESPALDO/NGC1313_250624_extinction/datos/slit1_2D_f99.fits'
slit9 = '../../../reduccion/NGC1313/espectros_oficiales/slit9.fits'
sp9 = fits.open(slit9)

sp9.info()
sp9[0].header["OBJECT"]
# Out:
# Filename: ../../../reduccion/NGC1313/espectros_oficiales/slit9.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      71   (2807, 1)   float32
# 'NGC1313-MSK01 2D CON LACOS'

# %%
# extraer data (flux sin corregir por galáctica)
data9=sp9[0].data
header9=sp9[0].header
obj_name9 = header9.get("OBJECT", "Unknown")

flux9=data9[0]
w9=WCS(header9, naxis=1, relax=False, fix=False)
wave9=w9.wcs_pix2world(np.arange(len(flux9)),0)[0]

plt.plot(wave9, flux9)
plt.title("Espectro slit 9 sin corrección galáctica")
plt.xlabel('Wavelength (Angstrom)')
plt.ylabel('Flux $(erg\ cm^{-2} s^{-1} A^{-1} · 1 x 10^{-15})$')
# Out:
# <>:13: SyntaxWarning: invalid escape sequence '\ '
# <>:13: SyntaxWarning: invalid escape sequence '\ '
# /var/folders/1d/sms3rjzs38jbhp0zx04sz91c0000gn/T/ipykernel_3374/87074268.py:13: SyntaxWarning: invalid escape sequence '\ '
#   plt.ylabel('Flux $(erg\ cm^{-2} s^{-1} A^{-1} · 1 x 10^{-15})$')
# WARNING: FITSFixedWarning: RADECSYS= 'FK5 ' / R.A./DEC. coordinate system reference
# the RADECSYS keyword is deprecated, use RADESYSa. [astropy.wcs.wcs]
# Text(0, 0.5, 'Flux $(erg\\ cm^{-2} s^{-1} A^{-1} · 1 x 10^{-15})$')

# %%
# %matplotlib inline
plt.figure(figsize=(10, 6))
plt.plot(wave9, flux9, linestyle='-', color='b')
plt.xlabel('Wavelength (Angstrom)')
plt.ylabel('Flux $(erg\ cm^{-2} s^{-1} A^{-1} · 1x 10^{-15})$')
plt.title('Espectro slit 9 sin corección galáctica')
plt.grid(True)
plt.show()
# Out:
# <>:5: SyntaxWarning: invalid escape sequence '\ '
# <>:5: SyntaxWarning: invalid escape sequence '\ '
# /var/folders/1d/sms3rjzs38jbhp0zx04sz91c0000gn/T/ipykernel_3374/2098127178.py:5: SyntaxWarning: invalid escape sequence '\ '
#   plt.ylabel('Flux $(erg\ cm^{-2} s^{-1} A^{-1} · 1x 10^{-15})$')

# %%
import extinction
from extinction import calzetti00

#tengo mi array de longitudes de onda de todo el espectro: wave1
# Calzetti+2000 with A_V = según el slit and R_V = 4.05
# mi A_v es A_v1m ojo que aquí estoy asumiendo que la MW es starburst !
wave9_c00 = extinction.calzetti00(wave9, A_v9, 4.05)
print(f' extinción en magnitudes para slit 9 con calzetti00: {wave9_c00}') #array of extinction in magnitudes at each input wavelength
# Out:
#  extinción en magnitudes para slit 9 con calzetti00: [0.24059494 0.24051699 0.24043907 ... 0.10914324 0.10911639 0.10908955]

# %%
from extinction import calzetti00, remove

print(f'valor de flujo sin corregir para slit 9: {flux9}')

# "deredden" flux by A_v1 with calzetti+2000
flux9_c00 = remove(calzetti00(wave9, A_v9, 4.05), flux9)
print(f'valor de flujo deredden para slit 9 con calzetti00: {flux9_c00}')
# Out:
# valor de flujo sin corregir para slit 9: [0.05935967 0.08791086 0.04706356 ... 0.01801529 0.01813462 0.01958222]
# valor de flujo deredden para slit 9 con calzetti00: [0.07408486 0.10971079 0.05873005 ... 0.01992042 0.02005187 0.02165199]

# %%
# %matplotlib inline
plt.figure(figsize=(10, 6))
plt.plot(wave9, flux9_c00, linestyle='-', color='b')
plt.xlabel('Wavelength (Angstrom)')
plt.ylabel('Flux $(erg\ cm^{-2} s^{-1} A^{-1} · 1x 10^{-15})$')
plt.title('Espectro slit 9 desenrojecido sólo con calzetti+2000')
plt.grid(True)
plt.show()
# Out:
# <>:5: SyntaxWarning: invalid escape sequence '\ '
# <>:5: SyntaxWarning: invalid escape sequence '\ '
# /var/folders/1d/sms3rjzs38jbhp0zx04sz91c0000gn/T/ipykernel_3374/1107070531.py:5: SyntaxWarning: invalid escape sequence '\ '
#   plt.ylabel('Flux $(erg\ cm^{-2} s^{-1} A^{-1} · 1x 10^{-15})$')

# %%
# guardar info corregida en un nuevo fits
# metemos el array de flujo corregido a la data del espectro
data9[0] = flux9_c00

# crear nuevo HDU 
slit9corrected = fits.PrimaryHDU(data=data9, header=header9)

# crear nuevo HDUList para guardar en un fits
sp9_corrected = fits.HDUList([slit9corrected])

# guardar datos corregidos en un nuevo archivo FITS
#new_fits_file1 = '../../Documentos/RESPALDO/NGC1313_250624_extinction/datos/slit1_2D_f99_c00.fits'
new_fits_file9 = '../../../reduccion/NGC1313/espectros_oficiales/slit9_2D_c00.fits'
sp9_corrected.writeto(new_fits_file9, overwrite=True)

print(f"Se ha guardado el archivo FITS corregido: {new_fits_file9}")
# Out:
# Se ha guardado el archivo FITS corregido: ../../../reduccion/NGC1313/espectros_oficiales/slit9_2D_c00.fits

# %% [markdown]
# SLIT 11

# %%
#slit 1, now sin f99
#abrir mi fits
#slit1_f99 = '../../Documentos/RESPALDO/NGC1313_250624_extinction/datos/slit1_2D_f99.fits'
slit11 = '../../../reduccion/NGC1313/espectros_oficiales/slit11.fits'
sp11 = fits.open(slit11)

sp11.info()
sp11[0].header["OBJECT"]
# Out:
# Filename: ../../../reduccion/NGC1313/espectros_oficiales/slit11.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      71   (2789, 1)   float32
# 'NGC1313-MSK01 2D CON LACOS'

# %%
# extraer data (flux sin corregir por galáctica)
data11=sp11[0].data
header11=sp11[0].header
obj_name11 = header11.get("OBJECT", "Unknown")

flux11=data11[0]
w11=WCS(header11, naxis=1, relax=False, fix=False)
wave11=w11.wcs_pix2world(np.arange(len(flux11)),0)[0]

plt.plot(wave11, flux11)
plt.title("Espectro slit 11 sin corrección galáctica")
plt.xlabel('Wavelength (Angstrom)')
plt.ylabel('Flux $(erg\ cm^{-2} s^{-1} A^{-1} · 1 x 10^{-15})$')
# Out:
# <>:13: SyntaxWarning: invalid escape sequence '\ '
# <>:13: SyntaxWarning: invalid escape sequence '\ '
# /var/folders/1d/sms3rjzs38jbhp0zx04sz91c0000gn/T/ipykernel_3374/2181855767.py:13: SyntaxWarning: invalid escape sequence '\ '
#   plt.ylabel('Flux $(erg\ cm^{-2} s^{-1} A^{-1} · 1 x 10^{-15})$')
# WARNING: FITSFixedWarning: RADECSYS= 'FK5 ' / R.A./DEC. coordinate system reference
# the RADECSYS keyword is deprecated, use RADESYSa. [astropy.wcs.wcs]
# Text(0, 0.5, 'Flux $(erg\\ cm^{-2} s^{-1} A^{-1} · 1 x 10^{-15})$')

# %%
# %matplotlib inline
plt.figure(figsize=(10, 6))
plt.plot(wave11, flux11, linestyle='-', color='b')
plt.xlabel('Wavelength (Angstrom)')
plt.ylabel('Flux $(erg\ cm^{-2} s^{-1} A^{-1} · 1x 10^{-15})$')
plt.title('Espectro slit 11 sin corección galáctica')
plt.grid(True)
plt.show()
# Out:
# <>:5: SyntaxWarning: invalid escape sequence '\ '
# <>:5: SyntaxWarning: invalid escape sequence '\ '
# /var/folders/1d/sms3rjzs38jbhp0zx04sz91c0000gn/T/ipykernel_3374/3761779837.py:5: SyntaxWarning: invalid escape sequence '\ '
#   plt.ylabel('Flux $(erg\ cm^{-2} s^{-1} A^{-1} · 1x 10^{-15})$')

# %%
import extinction
from extinction import calzetti00

#tengo mi array de longitudes de onda de todo el espectro: wave1
# Calzetti+2000 with A_V = según el slit and R_V = 4.05
# mi A_v es A_v1m ojo que aquí estoy asumiendo que la MW es starburst !
wave11_c00 = extinction.calzetti00(wave11, A_v11, 4.05)
print(f' extinción en magnitudes para slit 11 con calzetti00: {wave11_c00}') #array of extinction in magnitudes at each input wavelength
# Out:
#  extinción en magnitudes para slit 11 con calzetti00: [0.69090829 0.69068438 0.69046057 ... 0.31476069 0.31468308 0.31460549]

# %%
from extinction import calzetti00, remove

print(f'valor de flujo sin corregir para slit 11: {flux11}')

# "deredden" flux by A_v1 with calzetti+2000
flux11_c00 = remove(calzetti00(wave11, A_v11, 4.05), flux11)
print(f'valor de flujo deredden para slit 11 con calzetti00: {flux11_c00}')
# Out:
# valor de flujo sin corregir para slit 11: [-0.39257786  0.09593909  0.08961169 ...  0.04024966  0.03908245
#   0.03922698]
# valor de flujo deredden para slit 11 con calzetti00: [-0.74180391  0.18124639  0.16925787 ...  0.05378565  0.05222218
#   0.05241155]

# %%
# %matplotlib inline
plt.figure(figsize=(10, 6))
plt.plot(wave11, flux11_c00, linestyle='-', color='b')
plt.xlabel('Wavelength (Angstrom)')
plt.ylabel('Flux $(erg\ cm^{-2} s^{-1} A^{-1} · 1x 10^{-15})$')
plt.title('Espectro slit 11 desenrojecido sólo con calzetti+2000')
plt.grid(True)
plt.show()
# Out:
# <>:5: SyntaxWarning: invalid escape sequence '\ '
# <>:5: SyntaxWarning: invalid escape sequence '\ '
# /var/folders/1d/sms3rjzs38jbhp0zx04sz91c0000gn/T/ipykernel_3374/324145629.py:5: SyntaxWarning: invalid escape sequence '\ '
#   plt.ylabel('Flux $(erg\ cm^{-2} s^{-1} A^{-1} · 1x 10^{-15})$')

# %%
# guardar info corregida en un nuevo fits
# metemos el array de flujo corregido a la data del espectro
data11[0] = flux11_c00

# crear nuevo HDU 
slit11corrected = fits.PrimaryHDU(data=data11, header=header11)

# crear nuevo HDUList para guardar en un fits
sp11_corrected = fits.HDUList([slit11corrected])

# guardar datos corregidos en un nuevo archivo FITS
#new_fits_file1 = '../../Documentos/RESPALDO/NGC1313_250624_extinction/datos/slit1_2D_f99_c00.fits'
new_fits_file11 = '../../../reduccion/NGC1313/espectros_oficiales/slit11_2D_c00.fits'
sp11_corrected.writeto(new_fits_file11, overwrite=True)

print(f"Se ha guardado el archivo FITS corregido: {new_fits_file11}")
# Out:
# Se ha guardado el archivo FITS corregido: ../../../reduccion/NGC1313/espectros_oficiales/slit11_2D_c00.fits

# %% [markdown]
# SLIT 13

# %%
#slit 1, now sin f99
#abrir mi fits
#slit1_f99 = '../../Documentos/RESPALDO/NGC1313_250624_extinction/datos/slit1_2D_f99.fits'
slit13 = '../../../reduccion/NGC1313/espectros_oficiales/slit13.fits'
sp13 = fits.open(slit13)

sp13.info()
sp13[0].header["OBJECT"]
# Out:
# Filename: ../../../reduccion/NGC1313/espectros_oficiales/slit13.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      71   (2519, 1)   float32
# 'NGC1313-MSK01 2D CON LACOS'

# %%
# extraer data (flux sin corregir por galáctica)
data13=sp13[0].data
header13=sp13[0].header
obj_name13 = header13.get("OBJECT", "Unknown")

flux13=data13[0]
w13=WCS(header13, naxis=1, relax=False, fix=False)
wave13=w13.wcs_pix2world(np.arange(len(flux13)),0)[0]

plt.plot(wave13, flux13)
plt.title("Espectro slit 13 sin corrección galáctica")
plt.xlabel('Wavelength (Angstrom)')
plt.ylabel('Flux $(erg\ cm^{-2} s^{-1} A^{-1} · 1 x 10^{-15})$')
# Out:
# <>:13: SyntaxWarning: invalid escape sequence '\ '
# <>:13: SyntaxWarning: invalid escape sequence '\ '
# /var/folders/1d/sms3rjzs38jbhp0zx04sz91c0000gn/T/ipykernel_3374/1426067876.py:13: SyntaxWarning: invalid escape sequence '\ '
#   plt.ylabel('Flux $(erg\ cm^{-2} s^{-1} A^{-1} · 1 x 10^{-15})$')
# WARNING: FITSFixedWarning: RADECSYS= 'FK5 ' / R.A./DEC. coordinate system reference
# the RADECSYS keyword is deprecated, use RADESYSa. [astropy.wcs.wcs]
# Text(0, 0.5, 'Flux $(erg\\ cm^{-2} s^{-1} A^{-1} · 1 x 10^{-15})$')

# %%
# %matplotlib inline
plt.figure(figsize=(10, 6))
plt.plot(wave13, flux13, linestyle='-', color='b')
plt.xlabel('Wavelength (Angstrom)')
plt.ylabel('Flux $(erg\ cm^{-2} s^{-1} A^{-1} · 1x 10^{-15})$')
plt.title('Espectro slit 13 sin corección galáctica')
plt.grid(True)
plt.show()
# Out:
# <>:5: SyntaxWarning: invalid escape sequence '\ '
# <>:5: SyntaxWarning: invalid escape sequence '\ '
# /var/folders/1d/sms3rjzs38jbhp0zx04sz91c0000gn/T/ipykernel_3374/1423499027.py:5: SyntaxWarning: invalid escape sequence '\ '
#   plt.ylabel('Flux $(erg\ cm^{-2} s^{-1} A^{-1} · 1x 10^{-15})$')

# %%
import extinction
from extinction import calzetti00

#tengo mi array de longitudes de onda de todo el espectro: wave1
# Calzetti+2000 with A_V = según el slit and R_V = 4.05
# mi A_v es A_v1m ojo que aquí estoy asumiendo que la MW es starburst !
wave13_c00 = extinction.calzetti00(wave13, A_v13, 4.05)
print(f' extinción en magnitudes para slit 13 con calzetti00: {wave13_c00}') #array of extinction in magnitudes at each input wavelength
# Out:
#  extinción en magnitudes para slit 13 con calzetti00: [0.15526998 0.15521952 0.15516907 ... 0.07555008 0.07553079 0.07551151]

# %%
from extinction import calzetti00, remove

print(f'valor de flujo sin corregir para slit 13: {flux13}')

# "deredden" flux by A_v1 with calzetti+2000
flux13_c00 = remove(calzetti00(wave13, A_v13, 4.05), flux13)
print(f'valor de flujo deredden para slit 13 con calzetti00: {flux13_c00}')
# Out:
# valor de flujo sin corregir para slit 13: [0.         0.         0.         ... 0.03493275 0.03693881 0.04341558]
# valor de flujo deredden para slit 13 con calzetti00: [0.         0.         0.         ... 0.03745009 0.03960001 0.04654255]

# %%
# %matplotlib inline
plt.figure(figsize=(10, 6))
plt.plot(wave13, flux13_c00, linestyle='-', color='b')
plt.xlabel('Wavelength (Angstrom)')
plt.ylabel('Flux $(erg\ cm^{-2} s^{-1} A^{-1} · 1x 10^{-15})$')
plt.title('Espectro slit 13 desenrojecido sólo con calzetti+2000')
plt.grid(True)
plt.show()
# Out:
# <>:5: SyntaxWarning: invalid escape sequence '\ '
# <>:5: SyntaxWarning: invalid escape sequence '\ '
# /var/folders/1d/sms3rjzs38jbhp0zx04sz91c0000gn/T/ipykernel_3374/1129957082.py:5: SyntaxWarning: invalid escape sequence '\ '
#   plt.ylabel('Flux $(erg\ cm^{-2} s^{-1} A^{-1} · 1x 10^{-15})$')

# %%
# guardar info corregida en un nuevo fits
# metemos el array de flujo corregido a la data del espectro
data13[0] = flux13_c00

# crear nuevo HDU 
slit13corrected = fits.PrimaryHDU(data=data13, header=header13)

# crear nuevo HDUList para guardar en un fits
sp13_corrected = fits.HDUList([slit13corrected])

# guardar datos corregidos en un nuevo archivo FITS
#new_fits_file1 = '../../Documentos/RESPALDO/NGC1313_250624_extinction/datos/slit1_2D_f99_c00.fits'
new_fits_file13 = '../../../reduccion/NGC1313/espectros_oficiales/slit13_2D_c00.fits'
sp13_corrected.writeto(new_fits_file13, overwrite=True)

print(f"Se ha guardado el archivo FITS corregido: {new_fits_file13}")
# Out:
# Se ha guardado el archivo FITS corregido: ../../../reduccion/NGC1313/espectros_oficiales/slit13_2D_c00.fits

# %% [markdown]
# SLIT 17

# %%
#slit 1, now sin f99
#abrir mi fits
#slit1_f99 = '../../Documentos/RESPALDO/NGC1313_250624_extinction/datos/slit1_2D_f99.fits'
slit17 = '../../../reduccion/NGC1313/espectros_oficiales/slit17.fits'
sp17 = fits.open(slit17)

sp17.info()
sp17[0].header["OBJECT"]
# Out:
# Filename: ../../../reduccion/NGC1313/espectros_oficiales/slit17.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      71   (2325, 1)   float32
# 'NGC1313-MSK01 2D CON LACOS'

# %%
# extraer data (flux sin corregir por galáctica)
data17=sp17[0].data
header17=sp17[0].header
obj_name17 = header17.get("OBJECT", "Unknown")

flux17=data17[0]
w17=WCS(header17, naxis=1, relax=False, fix=False)
wave17=w17.wcs_pix2world(np.arange(len(flux17)),0)[0]

plt.plot(wave17, flux17)
plt.title("Espectro slit 17 sin corrección galáctica")
plt.xlabel('Wavelength (Angstrom)')
plt.ylabel('Flux $(erg\ cm^{-2} s^{-1} A^{-1} · 1 x 10^{-15})$')
# Out:
# <>:13: SyntaxWarning: invalid escape sequence '\ '
# <>:13: SyntaxWarning: invalid escape sequence '\ '
# /var/folders/1d/sms3rjzs38jbhp0zx04sz91c0000gn/T/ipykernel_3374/1251998423.py:13: SyntaxWarning: invalid escape sequence '\ '
#   plt.ylabel('Flux $(erg\ cm^{-2} s^{-1} A^{-1} · 1 x 10^{-15})$')
# WARNING: FITSFixedWarning: RADECSYS= 'FK5 ' / R.A./DEC. coordinate system reference
# the RADECSYS keyword is deprecated, use RADESYSa. [astropy.wcs.wcs]
# Text(0, 0.5, 'Flux $(erg\\ cm^{-2} s^{-1} A^{-1} · 1 x 10^{-15})$')

# %%
# %matplotlib inline
plt.figure(figsize=(10, 6))
plt.plot(wave17, flux17, linestyle='-', color='b')
plt.xlabel('Wavelength (Angstrom)')
plt.ylabel('Flux $(erg\ cm^{-2} s^{-1} A^{-1} · 1x 10^{-15})$')
plt.title('Espectro slit 17 sin corección galáctica')
plt.grid(True)
plt.show()
# Out:
# <>:5: SyntaxWarning: invalid escape sequence '\ '
# <>:5: SyntaxWarning: invalid escape sequence '\ '
# /var/folders/1d/sms3rjzs38jbhp0zx04sz91c0000gn/T/ipykernel_3374/363327448.py:5: SyntaxWarning: invalid escape sequence '\ '
#   plt.ylabel('Flux $(erg\ cm^{-2} s^{-1} A^{-1} · 1x 10^{-15})$')

# %%
import extinction
from extinction import calzetti00

#tengo mi array de longitudes de onda de todo el espectro: wave1
# Calzetti+2000 with A_V = según el slit and R_V = 4.05
# mi A_v es A_v1m ojo que aquí estoy asumiendo que la MW es starburst !
wave17_c00 = extinction.calzetti00(wave17, A_v17, 4.05)
print(f' extinción en magnitudes para slit 17 con calzetti00: {wave17_c00}') #array of extinction in magnitudes at each input wavelength
# Out:
#  extinción en magnitudes para slit 17 con calzetti00: [0.29660992 0.29651328 0.29641668 ... 0.1515226  0.15148284 0.15144309]

# %%
from extinction import calzetti00, remove

print(f'valor de flujo sin corregir para slit 17: {flux17}')

# "deredden" flux by A_v1 with calzetti+2000
flux17_c00 = remove(calzetti00(wave17, A_v17, 4.05), flux17)
print(f'valor de flujo deredden para slit 17 con calzetti00: {flux17_c00}')
# Out:
# valor de flujo sin corregir para slit 17: [0.07924721 0.10050514 0.01363148 ... 0.01888852 0.01887495 0.01901458]
# valor de flujo deredden para slit 17 con calzetti00: [0.10414249 0.13206678 0.01791058 ... 0.02171735 0.02170096 0.0218607 ]

# %%
# %matplotlib inline
plt.figure(figsize=(10, 6))
plt.plot(wave17, flux17_c00, linestyle='-', color='b')
plt.xlabel('Wavelength (Angstrom)')
plt.ylabel('Flux $(erg\ cm^{-2} s^{-1} A^{-1} · 1x 10^{-15})$')
plt.title('Espectro slit 17 desenrojecido sólo con calzetti+2000')
plt.grid(True)
plt.show()
# Out:
# <>:5: SyntaxWarning: invalid escape sequence '\ '
# <>:5: SyntaxWarning: invalid escape sequence '\ '
# /var/folders/1d/sms3rjzs38jbhp0zx04sz91c0000gn/T/ipykernel_3374/1304023192.py:5: SyntaxWarning: invalid escape sequence '\ '
#   plt.ylabel('Flux $(erg\ cm^{-2} s^{-1} A^{-1} · 1x 10^{-15})$')

# %%
# guardar info corregida en un nuevo fits
# metemos el array de flujo corregido a la data del espectro
data17[0] = flux17_c00

# crear nuevo HDU 
slit17corrected = fits.PrimaryHDU(data=data17, header=header17)

# crear nuevo HDUList para guardar en un fits
sp17_corrected = fits.HDUList([slit17corrected])

# guardar datos corregidos en un nuevo archivo FITS
#new_fits_file1 = '../../Documentos/RESPALDO/NGC1313_250624_extinction/datos/slit1_2D_f99_c00.fits'
new_fits_file17 = '../../../reduccion/NGC1313/espectros_oficiales/slit17_2D_c00.fits'
sp17_corrected.writeto(new_fits_file17, overwrite=True)

print(f"Se ha guardado el archivo FITS corregido: {new_fits_file17}")
# Out:
# Se ha guardado el archivo FITS corregido: ../../../reduccion/NGC1313/espectros_oficiales/slit17_2D_c00.fits

# %% [markdown]
# SLIT 19

# %%
#slit 1, now sin f99
#abrir mi fits
#slit1_f99 = '../../Documentos/RESPALDO/NGC1313_250624_extinction/datos/slit1_2D_f99.fits'
slit19 = '../../../reduccion/NGC1313/espectros_oficiales/slit19.fits'
sp19 = fits.open(slit19)

sp19.info()
sp19[0].header["OBJECT"]
# Out:
# Filename: ../../../reduccion/NGC1313/espectros_oficiales/slit19.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      71   (2680, 1)   float32
# 'NGC1313-MSK01 2D CON LACOS'

# %%
# extraer data (flux sin corregir por galáctica)
data19=sp19[0].data
header19=sp19[0].header
obj_name19 = header19.get("OBJECT", "Unknown")

flux19=data19[0]
w19=WCS(header19, naxis=1, relax=False, fix=False)
wave19=w19.wcs_pix2world(np.arange(len(flux19)),0)[0]

plt.plot(wave19, flux19)
plt.title("Espectro slit 19 sin corrección galáctica")
plt.xlabel('Wavelength (Angstrom)')
plt.ylabel('Flux $(erg\ cm^{-2} s^{-1} A^{-1} · 1 x 10^{-15})$')
# Out:
# <>:13: SyntaxWarning: invalid escape sequence '\ '
# <>:13: SyntaxWarning: invalid escape sequence '\ '
# /var/folders/1d/sms3rjzs38jbhp0zx04sz91c0000gn/T/ipykernel_3374/1596934371.py:13: SyntaxWarning: invalid escape sequence '\ '
#   plt.ylabel('Flux $(erg\ cm^{-2} s^{-1} A^{-1} · 1 x 10^{-15})$')
# WARNING: FITSFixedWarning: RADECSYS= 'FK5 ' / R.A./DEC. coordinate system reference
# the RADECSYS keyword is deprecated, use RADESYSa. [astropy.wcs.wcs]
# Text(0, 0.5, 'Flux $(erg\\ cm^{-2} s^{-1} A^{-1} · 1 x 10^{-15})$')

# %%
# %matplotlib inline
plt.figure(figsize=(10, 6))
plt.plot(wave19, flux19, linestyle='-', color='b')
plt.xlabel('Wavelength (Angstrom)')
plt.ylabel('Flux $(erg\ cm^{-2} s^{-1} A^{-1} · 1x 10^{-15})$')
plt.title('Espectro slit 19 sin corección galáctica')
plt.grid(True)
plt.show()
# Out:
# <>:5: SyntaxWarning: invalid escape sequence '\ '
# <>:5: SyntaxWarning: invalid escape sequence '\ '
# /var/folders/1d/sms3rjzs38jbhp0zx04sz91c0000gn/T/ipykernel_3374/4028688979.py:5: SyntaxWarning: invalid escape sequence '\ '
#   plt.ylabel('Flux $(erg\ cm^{-2} s^{-1} A^{-1} · 1x 10^{-15})$')

# %%
import extinction
from extinction import calzetti00

#tengo mi array de longitudes de onda de todo el espectro: wave1
# Calzetti+2000 with A_V = según el slit and R_V = 4.05
# mi A_v es A_v1m ojo que aquí estoy asumiendo que la MW es starburst !
wave19_c00 = extinction.calzetti00(wave19, A_v19, 4.05)
print(f' extinción en magnitudes para slit 19 con calzetti00: {wave19_c00}') #array of extinction in magnitudes at each input wavelength
# Out:
#  extinción en magnitudes para slit 19 con calzetti00: [0.32282829 0.32272351 0.32261878 ... 0.15095838 0.15092064 0.1508829 ]

# %%
from extinction import calzetti00, remove

print(f'valor de flujo sin corregir para slit 19: {flux19}')

# "deredden" flux by A_v1 with calzetti+2000
flux19_c00 = remove(calzetti00(wave19, A_v19, 4.05), flux19)
print(f'valor de flujo deredden para slit 19 con calzetti00: {flux19_c00}')
# Out:
# valor de flujo sin corregir para slit 19: [0.22060804 0.10943001 0.19279249 ... 0.02183094 0.01114585 0.00970298]
# valor de flujo deredden para slit 19 con calzetti00: [0.2969974  0.14730783 0.25950016 ... 0.02508741 0.01280801 0.01114958]

# %%
# %matplotlib inline
plt.figure(figsize=(10, 6))
plt.plot(wave19, flux19_c00, linestyle='-', color='b')
plt.xlabel('Wavelength (Angstrom)')
plt.ylabel('Flux $(erg\ cm^{-2} s^{-1} A^{-1} · 1x 10^{-15})$')
plt.title('Espectro slit 19 desenrojecido sólo con calzetti+2000')
plt.grid(True)
plt.show()
# Out:
# <>:5: SyntaxWarning: invalid escape sequence '\ '
# <>:5: SyntaxWarning: invalid escape sequence '\ '
# /var/folders/1d/sms3rjzs38jbhp0zx04sz91c0000gn/T/ipykernel_3374/3215904147.py:5: SyntaxWarning: invalid escape sequence '\ '
#   plt.ylabel('Flux $(erg\ cm^{-2} s^{-1} A^{-1} · 1x 10^{-15})$')

# %%
# guardar info corregida en un nuevo fits
# metemos el array de flujo corregido a la data del espectro
data19[0] = flux19_c00

# crear nuevo HDU 
slit19corrected = fits.PrimaryHDU(data=data19, header=header19)

# crear nuevo HDUList para guardar en un fits
sp19_corrected = fits.HDUList([slit19corrected])

# guardar datos corregidos en un nuevo archivo FITS
#new_fits_file1 = '../../Documentos/RESPALDO/NGC1313_250624_extinction/datos/slit1_2D_f99_c00.fits'
new_fits_file19 = '../../../reduccion/NGC1313/espectros_oficiales/slit19_2D_c00.fits'
sp19_corrected.writeto(new_fits_file19, overwrite=True)

print(f"Se ha guardado el archivo FITS corregido: {new_fits_file19}")
# Out:
# Se ha guardado el archivo FITS corregido: ../../../reduccion/NGC1313/espectros_oficiales/slit19_2D_c00.fits

# %% [markdown]
# SLIT 21

# %%
#slit 1, now sin f99
#abrir mi fits
#slit1_f99 = '../../Documentos/RESPALDO/NGC1313_250624_extinction/datos/slit1_2D_f99.fits'
slit21_1 = '../../../reduccion/NGC1313/espectros_oficiales/slit21_mask1.fits'
sp21_1 = fits.open(slit21_1)

sp21_1.info()
sp21_1[0].header["OBJECT"]
# Out:
# Filename: ../../../reduccion/NGC1313/espectros_oficiales/slit21_mask1.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      71   (2799, 1)   float32
# 'NGC1313-MSK01 2D CON LACOS'

# %%
# extraer data (flux sin corregir por galáctica)
data21_1=sp21_1[0].data
header21_1=sp21_1[0].header
obj_name21_1 = header21_1.get("OBJECT", "Unknown")

flux21_1=data21_1[0]
w21_1=WCS(header21_1, naxis=1, relax=False, fix=False)
wave21_1=w21_1.wcs_pix2world(np.arange(len(flux21_1)),0)[0]

plt.plot(wave21_1, flux21_1)
plt.title("Espectro slit 21_1 sin corrección galáctica")
plt.xlabel('Wavelength (Angstrom)')
plt.ylabel('Flux $(erg\ cm^{-2} s^{-1} A^{-1} · 1 x 10^{-15})$')
# Out:
# <>:13: SyntaxWarning: invalid escape sequence '\ '
# <>:13: SyntaxWarning: invalid escape sequence '\ '
# /var/folders/1d/sms3rjzs38jbhp0zx04sz91c0000gn/T/ipykernel_3374/4042927578.py:13: SyntaxWarning: invalid escape sequence '\ '
#   plt.ylabel('Flux $(erg\ cm^{-2} s^{-1} A^{-1} · 1 x 10^{-15})$')
# WARNING: FITSFixedWarning: RADECSYS= 'FK5 ' / R.A./DEC. coordinate system reference
# the RADECSYS keyword is deprecated, use RADESYSa. [astropy.wcs.wcs]
# Text(0, 0.5, 'Flux $(erg\\ cm^{-2} s^{-1} A^{-1} · 1 x 10^{-15})$')

# %%
# %matplotlib inline
plt.figure(figsize=(10, 6))
plt.plot(wave21_1, flux21_1, linestyle='-', color='b')
plt.xlabel('Wavelength (Angstrom)')
plt.ylabel('Flux $(erg\ cm^{-2} s^{-1} A^{-1} · 1x 10^{-15})$')
plt.title('Espectro slit 21_1 sin corección galáctica')
plt.grid(True)
plt.show()
# Out:
# <>:5: SyntaxWarning: invalid escape sequence '\ '
# <>:5: SyntaxWarning: invalid escape sequence '\ '
# /var/folders/1d/sms3rjzs38jbhp0zx04sz91c0000gn/T/ipykernel_3374/3662580820.py:5: SyntaxWarning: invalid escape sequence '\ '
#   plt.ylabel('Flux $(erg\ cm^{-2} s^{-1} A^{-1} · 1x 10^{-15})$')

# %%
import extinction
from extinction import calzetti00

#tengo mi array de longitudes de onda de todo el espectro: wave1
# Calzetti+2000 with A_V = según el slit and R_V = 4.05
# mi A_v es A_v1m ojo que aquí estoy asumiendo que la MW es starburst !
wave21_1_c00 = extinction.calzetti00(wave21_1, A_v21_1, 4.05)
print(f' extinción en magnitudes para slit 21_1 con calzetti00: {wave21_1_c00}') #array of extinction in magnitudes at each input wavelength
# Out:
#  extinción en magnitudes para slit 21_1 con calzetti00: [0.97029105 0.96997675 0.96966258 ... 0.44109176 0.44098316 0.4408746 ]

# %%
from extinction import calzetti00, remove

print(f'valor de flujo sin corregir para slit 21_1: {flux21_1}')

# "deredden" flux by A_v1 with calzetti+2000
flux21_1_c00 = remove(calzetti00(wave21_1, A_v21_1, 4.05), flux21_1)
print(f'valor de flujo deredden para slit 21 mask 1 con calzetti00: {flux21_1_c00}')
# Out:
# valor de flujo sin corregir para slit 21_1: [-0.05697761  0.15893006  0.2841458  ...  0.02046324  0.0176235
#   0.01754855]
# valor de flujo deredden para slit 21 mask 1 con calzetti00: [-0.13925817  0.38832626  0.6940748  ...  0.03071928  0.02645364
#   0.0263385 ]

# %%
# %matplotlib inline
plt.figure(figsize=(10, 6))
plt.plot(wave21_1, flux21_1_c00, linestyle='-', color='b')
plt.xlabel('Wavelength (Angstrom)')
plt.ylabel('Flux $(erg\ cm^{-2} s^{-1} A^{-1} · 1x 10^{-15})$')
plt.title('Espectro slit 21_1 desenrojecido sólo con calzetti+2000')
plt.grid(True)
plt.show()
# Out:
# <>:5: SyntaxWarning: invalid escape sequence '\ '
# <>:5: SyntaxWarning: invalid escape sequence '\ '
# /var/folders/1d/sms3rjzs38jbhp0zx04sz91c0000gn/T/ipykernel_3374/2301435979.py:5: SyntaxWarning: invalid escape sequence '\ '
#   plt.ylabel('Flux $(erg\ cm^{-2} s^{-1} A^{-1} · 1x 10^{-15})$')

# %%
# guardar info corregida en un nuevo fits
# metemos el array de flujo corregido a la data del espectro
data21_1[0] = flux21_1_c00

# crear nuevo HDU 
slit21_1corrected = fits.PrimaryHDU(data=data21_1, header=header21_1)

# crear nuevo HDUList para guardar en un fits
sp21_1_corrected = fits.HDUList([slit21_1corrected])

# guardar datos corregidos en un nuevo archivo FITS
#new_fits_file1 = '../../Documentos/RESPALDO/NGC1313_250624_extinction/datos/slit1_2D_f99_c00.fits'
new_fits_file21_1 = '../../../reduccion/NGC1313/espectros_oficiales/slit21_1_2D_c00.fits'
sp21_1_corrected.writeto(new_fits_file21_1, overwrite=True)

print(f"Se ha guardado el archivo FITS corregido: {new_fits_file21_1}")
# Out:
# Se ha guardado el archivo FITS corregido: ../../../reduccion/NGC1313/espectros_oficiales/slit21_1_2D_c00.fits

# %% [markdown]
# SLIT 23

# %%
#abrir mi fits
#slit1_f99 = '../../Documentos/RESPALDO/NGC1313_250624_extinction/datos/slit1_2D_f99.fits'
slit23_1 = '../../../reduccion/NGC1313/espectros_oficiales/slit23_mask1.fits'
sp23_1 = fits.open(slit23_1)

sp23_1.info()
sp23_1[0].header["OBJECT"]
# Out:
# Filename: ../../../reduccion/NGC1313/espectros_oficiales/slit23_mask1.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      71   (2704, 1)   float32
# 'NGC1313-MSK01 2D CON LACOS'

# %%
# extraer data (flux sin corregir por galáctica)
data23_1=sp23_1[0].data
header23_1=sp23_1[0].header
obj_name23_1 = header23_1.get("OBJECT", "Unknown")

flux23_1=data23_1[0]
w23_1=WCS(header23_1, naxis=1, relax=False, fix=False)
wave23_1=w23_1.wcs_pix2world(np.arange(len(flux23_1)),0)[0]

plt.plot(wave23_1, flux23_1)
plt.title("Espectro slit 23 mask 1 sin corrección galáctica")
plt.xlabel('Wavelength (Angstrom)')
plt.ylabel('Flux $(erg\ cm^{-2} s^{-1} A^{-1} · 1 x 10^{-15})$')
# Out:
# <>:13: SyntaxWarning: invalid escape sequence '\ '
# <>:13: SyntaxWarning: invalid escape sequence '\ '
# /var/folders/1d/sms3rjzs38jbhp0zx04sz91c0000gn/T/ipykernel_3374/1342360794.py:13: SyntaxWarning: invalid escape sequence '\ '
#   plt.ylabel('Flux $(erg\ cm^{-2} s^{-1} A^{-1} · 1 x 10^{-15})$')
# WARNING: FITSFixedWarning: RADECSYS= 'FK5 ' / R.A./DEC. coordinate system reference
# the RADECSYS keyword is deprecated, use RADESYSa. [astropy.wcs.wcs]
# Text(0, 0.5, 'Flux $(erg\\ cm^{-2} s^{-1} A^{-1} · 1 x 10^{-15})$')

# %%
# %matplotlib inline
plt.figure(figsize=(10, 6))
plt.plot(wave23_1, flux23_1, linestyle='-', color='b')
plt.xlabel('Wavelength (Angstrom)')
plt.ylabel('Flux $(erg\ cm^{-2} s^{-1} A^{-1} · 1x 10^{-15})$')
plt.title('Espectro slit 23 mask 1 sin corección galáctica')
plt.grid(True)
plt.show()
# Out:
# <>:5: SyntaxWarning: invalid escape sequence '\ '
# <>:5: SyntaxWarning: invalid escape sequence '\ '
# /var/folders/1d/sms3rjzs38jbhp0zx04sz91c0000gn/T/ipykernel_3374/1611652935.py:5: SyntaxWarning: invalid escape sequence '\ '
#   plt.ylabel('Flux $(erg\ cm^{-2} s^{-1} A^{-1} · 1x 10^{-15})$')

# %%
import extinction
from extinction import calzetti00

#tengo mi array de longitudes de onda de todo el espectro: wave1
# Calzetti+2000 with A_V = según el slit and R_V = 4.05
# mi A_v es A_v1m ojo que aquí estoy asumiendo que la MW es starburst !
wave23_1_c00 = extinction.calzetti00(wave23_1, A_v23_1, 4.05)
print(f' extinción en magnitudes para slit 23 mask 1 con calzetti00: {wave23_1_c00}') #array of extinction in magnitudes at each input wavelength
# Out:
#  extinción en magnitudes para slit 23 mask 1 con calzetti00: [0.18178801 0.18172904 0.1816701  ... 0.08453069 0.08450962 0.08448856]

# %%
from extinction import calzetti00, remove

print(f'valor de flujo sin corregir para slit 23 mask 1: {flux23_1}')

# "deredden" flux by A_v1 with calzetti+2000
flux23_1_c00 = remove(calzetti00(wave23_1, A_v23_1, 4.05), flux23_1)
print(f'valor de flujo deredden para slit 23 mask 1 con calzetti00: {flux23_1_c00}')
# Out:
# valor de flujo sin corregir para slit 23 mask 1: [ 0.07697215 -0.09624738 -0.06405802 ...  0.02005473  0.0208165
#   0.02014694]
# valor de flujo deredden para slit 23 mask 1 con calzetti00: [ 0.09100156 -0.11378383 -0.0757254  ...  0.02167849  0.02250151
#   0.02177732]

# %%
# %matplotlib inline
plt.figure(figsize=(10, 6))
plt.plot(wave23_1, flux23_1_c00, linestyle='-', color='b')
plt.xlabel('Wavelength (Angstrom)')
plt.ylabel('Flux $(erg\ cm^{-2} s^{-1} A^{-1} · 1x 10^{-15})$')
plt.title('Espectro slit 23 mask 1 desenrojecido sólo con calzetti+2000')
plt.grid(True)
plt.show()
# Out:
# <>:5: SyntaxWarning: invalid escape sequence '\ '
# <>:5: SyntaxWarning: invalid escape sequence '\ '
# /var/folders/1d/sms3rjzs38jbhp0zx04sz91c0000gn/T/ipykernel_3374/1183207571.py:5: SyntaxWarning: invalid escape sequence '\ '
#   plt.ylabel('Flux $(erg\ cm^{-2} s^{-1} A^{-1} · 1x 10^{-15})$')

# %%
# guardar info corregida en un nuevo fits
# metemos el array de flujo corregido a la data del espectro
data23_1[0] = flux23_1_c00

# crear nuevo HDU 
slit23_1corrected = fits.PrimaryHDU(data=data23_1, header=header23_1)

# crear nuevo HDUList para guardar en un fits
sp23_1_corrected = fits.HDUList([slit23_1corrected])

# guardar datos corregidos en un nuevo archivo FITS
#new_fits_file1 = '../../Documentos/RESPALDO/NGC1313_250624_extinction/datos/slit1_2D_f99_c00.fits'
new_fits_file23_1 = '../../../reduccion/NGC1313/espectros_oficiales/slit23_1_2D_c00.fits'
sp23_1_corrected.writeto(new_fits_file23_1, overwrite=True)

print(f"Se ha guardado el archivo FITS corregido: {new_fits_file23_1}")
# Out:
# Se ha guardado el archivo FITS corregido: ../../../reduccion/NGC1313/espectros_oficiales/slit23_1_2D_c00.fits

# %% [markdown]
# **MASK 2**

# %% [markdown]
# SLIT 4

# %%
#slit 4, now sin f99
#abrir mi fits
#slit1_f99 = '../../Documentos/RESPALDO/NGC1313_250624_extinction/datos/slit1_2D_f99.fits'
slit4 = '../../../reduccion/NGC1313/espectros_oficiales/slit4.fits'
sp4 = fits.open(slit4)

sp4.info()
sp4[0].header["OBJECT"]
# Out:
# Filename: ../../../reduccion/NGC1313/espectros_oficiales/slit4.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      71   (2245, 1)   float32
# 'NGC1313-FIELD2 MASK02_median_avsig'

# %%
# extraer data (flux sin corregir por galáctica)
data4=sp4[0].data
header4=sp4[0].header
obj_name4 = header4.get("OBJECT", "Unknown")

flux4=data4[0]
w4=WCS(header4, naxis=1, relax=False, fix=False)
wave4=w4.wcs_pix2world(np.arange(len(flux4)),0)[0]

plt.plot(wave4, flux4)
plt.title("Espectro slit 4 sin corrección galáctica")
plt.xlabel('Wavelength (Angstrom)')
plt.ylabel('Flux $(erg\ cm^{-2} s^{-1} A^{-1} · 1 x 10^{-15})$')
# Out:
# <>:13: SyntaxWarning: invalid escape sequence '\ '
# <>:13: SyntaxWarning: invalid escape sequence '\ '
# /var/folders/1d/sms3rjzs38jbhp0zx04sz91c0000gn/T/ipykernel_3374/3387483278.py:13: SyntaxWarning: invalid escape sequence '\ '
#   plt.ylabel('Flux $(erg\ cm^{-2} s^{-1} A^{-1} · 1 x 10^{-15})$')
# WARNING: FITSFixedWarning: RADECSYS= 'FK5 ' / R.A./DEC. coordinate system reference
# the RADECSYS keyword is deprecated, use RADESYSa. [astropy.wcs.wcs]
# Text(0, 0.5, 'Flux $(erg\\ cm^{-2} s^{-1} A^{-1} · 1 x 10^{-15})$')

# %%
# %matplotlib inline
plt.figure(figsize=(10, 6))
plt.plot(wave4, flux4, linestyle='-', color='b')
plt.xlabel('Wavelength (Angstrom)')
plt.ylabel('Flux $(erg\ cm^{-2} s^{-1} A^{-1} · 1x 10^{-15})$')
plt.title('Espectro slit 4 sin corección galáctica')
plt.grid(True)
plt.show()
# Out:
# <>:5: SyntaxWarning: invalid escape sequence '\ '
# <>:5: SyntaxWarning: invalid escape sequence '\ '
# /var/folders/1d/sms3rjzs38jbhp0zx04sz91c0000gn/T/ipykernel_3374/2170222386.py:5: SyntaxWarning: invalid escape sequence '\ '
#   plt.ylabel('Flux $(erg\ cm^{-2} s^{-1} A^{-1} · 1x 10^{-15})$')

# %%
import extinction
from extinction import calzetti00

#tengo mi array de longitudes de onda de todo el espectro: wave1
# Calzetti+2000 with A_V = según el slit and R_V = 4.05
# mi A_v es A_v1m ojo que aquí estoy asumiendo que la MW es starburst !
wave4_c00 = extinction.calzetti00(wave4, A_v4, 4.05)
print(f' extinción en magnitudes para slit 4 con calzetti00: {wave4_c00}') #array of extinction in magnitudes at each input wavelength
# Out:
#  extinción en magnitudes para slit 4 con calzetti00: [0.22048142 0.22040949 0.22033759 ... 0.11495539 0.11492485 0.11489433]

# %%
from extinction import calzetti00, remove

print(f'valor de flujo sin corregir para slit 4: {flux4}')

# "deredden" flux by A_v1 with calzetti+2000
flux4_c00 = remove(calzetti00(wave4, A_v4, 4.05), flux4)
print(f'valor de flujo deredden para slit 4 con calzetti00: {flux4_c00}')
# Out:
# valor de flujo sin corregir para slit 4: [-0.16368231 -0.02690807 -0.1849791  ...  0.01477027  0.0126317
#   0.01146719]
# valor de flujo deredden para slit 4 con calzetti00: [-0.20053691 -0.03296448 -0.22659884 ...  0.0164199   0.01404209
#   0.0127472 ]

# %%
# %matplotlib inline
plt.figure(figsize=(10, 6))
plt.plot(wave4, flux4_c00, linestyle='-', color='b')
plt.xlabel('Wavelength (Angstrom)')
plt.ylabel('Flux $(erg\ cm^{-2} s^{-1} A^{-1} · 1x 10^{-15})$')
plt.title('Espectro slit 4 desenrojecido sólo con calzetti+2000')
plt.grid(True)
plt.show()
# Out:
# <>:5: SyntaxWarning: invalid escape sequence '\ '
# <>:5: SyntaxWarning: invalid escape sequence '\ '
# /var/folders/1d/sms3rjzs38jbhp0zx04sz91c0000gn/T/ipykernel_3374/1226270439.py:5: SyntaxWarning: invalid escape sequence '\ '
#   plt.ylabel('Flux $(erg\ cm^{-2} s^{-1} A^{-1} · 1x 10^{-15})$')

# %%
# guardar info corregida en un nuevo fits
# metemos el array de flujo corregido a la data del espectro
data4[0] = flux4_c00

# crear nuevo HDU 
slit4corrected = fits.PrimaryHDU(data=data4, header=header4)

# crear nuevo HDUList para guardar en un fits
sp4_corrected = fits.HDUList([slit4corrected])

# guardar datos corregidos en un nuevo archivo FITS
#new_fits_file1 = '../../Documentos/RESPALDO/NGC1313_250624_extinction/datos/slit1_2D_f99_c00.fits'
new_fits_file4 = '../../../reduccion/NGC1313/espectros_oficiales/slit4_2D_c00.fits'
sp4_corrected.writeto(new_fits_file4, overwrite=True)

print(f"Se ha guardado el archivo FITS corregido: {new_fits_file4}")
# Out:
# Se ha guardado el archivo FITS corregido: ../../../reduccion/NGC1313/espectros_oficiales/slit4_2D_c00.fits

# %% [markdown]
# SLIT 8

# %%
#slit 4, now sin f99
#abrir mi fits
#slit1_f99 = '../../Documentos/RESPALDO/NGC1313_250624_extinction/datos/slit1_2D_f99.fits'
slit8 = '../../../reduccion/NGC1313/espectros_oficiales/slit8.fits'
sp8 = fits.open(slit8)

sp8.info()
sp8[0].header["OBJECT"]
# Out:
# Filename: ../../../reduccion/NGC1313/espectros_oficiales/slit8.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      71   (2382, 1)   float32
# 'NGC1313-FIELD2 MASK02_median_avsig'

# %%
# extraer data (flux sin corregir por galáctica)
data8=sp8[0].data
header8=sp8[0].header
obj_name8 = header8.get("OBJECT", "Unknown")

flux8=data8[0]
w8=WCS(header8, naxis=1, relax=False, fix=False)
wave8=w8.wcs_pix2world(np.arange(len(flux8)),0)[0]

plt.plot(wave8, flux8)
plt.title("Espectro slit 8 sin corrección galáctica")
plt.xlabel('Wavelength (Angstrom)')
plt.ylabel('Flux $(erg\ cm^{-2} s^{-1} A^{-1} · 1 x 10^{-15})$')
# Out:
# <>:13: SyntaxWarning: invalid escape sequence '\ '
# <>:13: SyntaxWarning: invalid escape sequence '\ '
# /var/folders/1d/sms3rjzs38jbhp0zx04sz91c0000gn/T/ipykernel_3374/1047590088.py:13: SyntaxWarning: invalid escape sequence '\ '
#   plt.ylabel('Flux $(erg\ cm^{-2} s^{-1} A^{-1} · 1 x 10^{-15})$')
# WARNING: FITSFixedWarning: RADECSYS= 'FK5 ' / R.A./DEC. coordinate system reference
# the RADECSYS keyword is deprecated, use RADESYSa. [astropy.wcs.wcs]
# Text(0, 0.5, 'Flux $(erg\\ cm^{-2} s^{-1} A^{-1} · 1 x 10^{-15})$')

# %%
# %matplotlib inline
plt.figure(figsize=(10, 6))
plt.plot(wave8, flux8, linestyle='-', color='b')
plt.xlabel('Wavelength (Angstrom)')
plt.ylabel('Flux $(erg\ cm^{-2} s^{-1} A^{-1} · 1x 10^{-15})$')
plt.title('Espectro slit 8 sin corección galáctica')
plt.grid(True)
plt.show()
# Out:
# <>:5: SyntaxWarning: invalid escape sequence '\ '
# <>:5: SyntaxWarning: invalid escape sequence '\ '
# /var/folders/1d/sms3rjzs38jbhp0zx04sz91c0000gn/T/ipykernel_3374/1162828631.py:5: SyntaxWarning: invalid escape sequence '\ '
#   plt.ylabel('Flux $(erg\ cm^{-2} s^{-1} A^{-1} · 1x 10^{-15})$')

# %%
import extinction
from extinction import calzetti00

#tengo mi array de longitudes de onda de todo el espectro: wave1
# Calzetti+2000 with A_V = según el slit and R_V = 4.05
# mi A_v es A_v1m ojo que aquí estoy asumiendo que la MW es starburst !
wave8_c00 = extinction.calzetti00(wave8, A_v8, 4.05)
print(f' extinción en magnitudes para slit 8 con calzetti00: {wave8_c00}') #array of extinction in magnitudes at each input wavelength
# Out:
#  extinción en magnitudes para slit 8 con calzetti00: [0.31395414 0.31385189 0.31374969 ... 0.15806137 0.15802022 0.15797908]

# %%
from extinction import calzetti00, remove

print(f'valor de flujo sin corregir para slit 8: {flux8}')

# "deredden" flux by A_v1 with calzetti+2000
flux8_c00 = remove(calzetti00(wave8, A_v8, 4.05), flux8)
print(f'valor de flujo deredden para slit 8 con calzetti00: {flux8_c00}')
# Out:
# valor de flujo sin corregir para slit 8: [-0.39833716  0.3696341  -0.18279268 ...  0.00947641  0.0100037
#   0.00830871]
# valor de flujo deredden para slit 8 con calzetti00: [-0.53190304  0.49352911 -0.24403868 ...  0.01096146  0.01157094
#   0.00961004]

# %%
# %matplotlib inline
plt.figure(figsize=(10, 6))
plt.plot(wave8, flux8_c00, linestyle='-', color='b')
plt.xlabel('Wavelength (Angstrom)')
plt.ylabel('Flux $(erg\ cm^{-2} s^{-1} A^{-1} · 1x 10^{-15})$')
plt.title('Espectro slit 8 desenrojecido sólo con calzetti+2000')
plt.grid(True)
plt.show()
# Out:
# <>:5: SyntaxWarning: invalid escape sequence '\ '
# <>:5: SyntaxWarning: invalid escape sequence '\ '
# /var/folders/1d/sms3rjzs38jbhp0zx04sz91c0000gn/T/ipykernel_3374/352598942.py:5: SyntaxWarning: invalid escape sequence '\ '
#   plt.ylabel('Flux $(erg\ cm^{-2} s^{-1} A^{-1} · 1x 10^{-15})$')

# %%
# guardar info corregida en un nuevo fits
# metemos el array de flujo corregido a la data del espectro
data8[0] = flux8_c00

# crear nuevo HDU 
slit8corrected = fits.PrimaryHDU(data=data8, header=header8)

# crear nuevo HDUList para guardar en un fits
sp8_corrected = fits.HDUList([slit8corrected])

# guardar datos corregidos en un nuevo archivo FITS
#new_fits_file1 = '../../Documentos/RESPALDO/NGC1313_250624_extinction/datos/slit1_2D_f99_c00.fits'
new_fits_file8 = '../../../reduccion/NGC1313/espectros_oficiales/slit8_2D_c00.fits'
sp8_corrected.writeto(new_fits_file8, overwrite=True)

print(f"Se ha guardado el archivo FITS corregido: {new_fits_file8}")
# Out:
# Se ha guardado el archivo FITS corregido: ../../../reduccion/NGC1313/espectros_oficiales/slit8_2D_c00.fits

# %% [markdown]
# SLIT 10

# %%
#slit 4, now sin f99
#abrir mi fits
#slit1_f99 = '../../Documentos/RESPALDO/NGC1313_250624_extinction/datos/slit1_2D_f99.fits'
slit10 = '../../../reduccion/NGC1313/espectros_oficiales/slit10.fits'
sp10 = fits.open(slit10)

sp10.info()
sp10[0].header["OBJECT"]
# Out:
# Filename: ../../../reduccion/NGC1313/espectros_oficiales/slit10.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      71   (2386, 1)   float32
# 'NGC1313-FIELD2 MASK02_median_avsig'

# %%
# extraer data (flux sin corregir por galáctica)
data10=sp10[0].data
header10=sp10[0].header
obj_name10 = header10.get("OBJECT", "Unknown")

flux10=data10[0]
w10=WCS(header10, naxis=1, relax=False, fix=False)
wave10=w10.wcs_pix2world(np.arange(len(flux10)),0)[0]

plt.plot(wave10, flux10)
plt.title("Espectro slit 10 sin corrección galáctica")
plt.xlabel('Wavelength (Angstrom)')
plt.ylabel('Flux $(erg\ cm^{-2} s^{-1} A^{-1} · 1 x 10^{-15})$')
# Out:
# <>:13: SyntaxWarning: invalid escape sequence '\ '
# <>:13: SyntaxWarning: invalid escape sequence '\ '
# /var/folders/1d/sms3rjzs38jbhp0zx04sz91c0000gn/T/ipykernel_3374/3540729550.py:13: SyntaxWarning: invalid escape sequence '\ '
#   plt.ylabel('Flux $(erg\ cm^{-2} s^{-1} A^{-1} · 1 x 10^{-15})$')
# WARNING: FITSFixedWarning: RADECSYS= 'FK5 ' / R.A./DEC. coordinate system reference
# the RADECSYS keyword is deprecated, use RADESYSa. [astropy.wcs.wcs]
# Text(0, 0.5, 'Flux $(erg\\ cm^{-2} s^{-1} A^{-1} · 1 x 10^{-15})$')

# %%
# %matplotlib inline
plt.figure(figsize=(10, 6))
plt.plot(wave10, flux10, linestyle='-', color='b')
plt.xlabel('Wavelength (Angstrom)')
plt.ylabel('Flux $(erg\ cm^{-2} s^{-1} A^{-1} · 1x 10^{-15})$')
plt.title('Espectro slit 10 sin corección galáctica')
plt.grid(True)
plt.show()
# Out:
# <>:5: SyntaxWarning: invalid escape sequence '\ '
# <>:5: SyntaxWarning: invalid escape sequence '\ '
# /var/folders/1d/sms3rjzs38jbhp0zx04sz91c0000gn/T/ipykernel_3374/4261203294.py:5: SyntaxWarning: invalid escape sequence '\ '
#   plt.ylabel('Flux $(erg\ cm^{-2} s^{-1} A^{-1} · 1x 10^{-15})$')

# %%
import extinction
from extinction import calzetti00

#tengo mi array de longitudes de onda de todo el espectro: wave1
# Calzetti+2000 with A_V = según el slit and R_V = 4.05
# mi A_v es A_v1m ojo que aquí estoy asumiendo que la MW es starburst !
wave10_c00 = extinction.calzetti00(wave10, A_v10, 4.05)
print(f' extinción en magnitudes para slit 10 con calzetti00: {wave10_c00}') #array of extinction in magnitudes at each input wavelength
# Out:
#  extinción en magnitudes para slit 10 con calzetti00: [0.04911581 0.04909981 0.04908382 ... 0.02470033 0.0246939  0.02468747]

# %%
from extinction import calzetti00, remove

print(f'valor de flujo sin corregir para slit 10: {flux10}')

# "deredden" flux by A_v1 with calzetti+2000
flux10_c00 = remove(calzetti00(wave10, A_v10, 4.05), flux10)
print(f'valor de flujo deredden para slit 10 con calzetti00: {flux10_c00}')
# Out:
# valor de flujo sin corregir para slit 10: [-0.10635892 -0.25736502 -0.00201372 ...  0.00572949  0.00482062
#   0.00442484]
# valor de flujo deredden para slit 10 con calzetti00: [-0.1112808  -0.26927091 -0.00210684 ...  0.00586133  0.00493152
#   0.00452661]

# %%
# %matplotlib inline
plt.figure(figsize=(10, 6))
plt.plot(wave10, flux10_c00, linestyle='-', color='b')
plt.xlabel('Wavelength (Angstrom)')
plt.ylabel('Flux $(erg\ cm^{-2} s^{-1} A^{-1} · 1x 10^{-15})$')
plt.title('Espectro slit 10 desenrojecido sólo con calzetti+2000')
plt.grid(True)
plt.show()
# Out:
# <>:5: SyntaxWarning: invalid escape sequence '\ '
# <>:5: SyntaxWarning: invalid escape sequence '\ '
# /var/folders/1d/sms3rjzs38jbhp0zx04sz91c0000gn/T/ipykernel_3374/283944164.py:5: SyntaxWarning: invalid escape sequence '\ '
#   plt.ylabel('Flux $(erg\ cm^{-2} s^{-1} A^{-1} · 1x 10^{-15})$')

# %%
# guardar info corregida en un nuevo fits
# metemos el array de flujo corregido a la data del espectro
data10[0] = flux10_c00

# crear nuevo HDU 
slit10corrected = fits.PrimaryHDU(data=data10, header=header10)

# crear nuevo HDUList para guardar en un fits
sp10_corrected = fits.HDUList([slit10corrected])

# guardar datos corregidos en un nuevo archivo FITS
#new_fits_file1 = '../../Documentos/RESPALDO/NGC1313_250624_extinction/datos/slit1_2D_f99_c00.fits'
new_fits_file10 = '../../../reduccion/NGC1313/espectros_oficiales/slit10_2D_c00.fits'
sp10_corrected.writeto(new_fits_file10, overwrite=True)

print(f"Se ha guardado el archivo FITS corregido: {new_fits_file10}")
# Out:
# Se ha guardado el archivo FITS corregido: ../../../reduccion/NGC1313/espectros_oficiales/slit10_2D_c00.fits

# %% [markdown]
# SLIT 12

# %%
#slit 4, now sin f99
#abrir mi fits
#slit1_f99 = '../../Documentos/RESPALDO/NGC1313_250624_extinction/datos/slit1_2D_f99.fits'
slit12 = '../../../reduccion/NGC1313/espectros_oficiales/slit12.fits'
sp12 = fits.open(slit12)

sp12.info()
sp12[0].header["OBJECT"]
# Out:
# Filename: ../../../reduccion/NGC1313/espectros_oficiales/slit12.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      71   (2440, 1)   float32
# 'NGC1313-FIELD2 MASK02_median_avsig'

# %%
# extraer data (flux sin corregir por galáctica)
data12=sp12[0].data
header12=sp12[0].header
obj_name12 = header12.get("OBJECT", "Unknown")

flux12=data12[0]
w12=WCS(header12, naxis=1, relax=False, fix=False)
wave12=w12.wcs_pix2world(np.arange(len(flux12)),0)[0]

plt.plot(wave12, flux12)
plt.title("Espectro slit 12 sin corrección galáctica")
plt.xlabel('Wavelength (Angstrom)')
plt.ylabel('Flux $(erg\ cm^{-2} s^{-1} A^{-1} · 1 x 10^{-15})$')
# Out:
# <>:13: SyntaxWarning: invalid escape sequence '\ '
# <>:13: SyntaxWarning: invalid escape sequence '\ '
# /var/folders/1d/sms3rjzs38jbhp0zx04sz91c0000gn/T/ipykernel_3374/874758926.py:13: SyntaxWarning: invalid escape sequence '\ '
#   plt.ylabel('Flux $(erg\ cm^{-2} s^{-1} A^{-1} · 1 x 10^{-15})$')
# WARNING: FITSFixedWarning: RADECSYS= 'FK5 ' / R.A./DEC. coordinate system reference
# the RADECSYS keyword is deprecated, use RADESYSa. [astropy.wcs.wcs]
# Text(0, 0.5, 'Flux $(erg\\ cm^{-2} s^{-1} A^{-1} · 1 x 10^{-15})$')

# %%
# %matplotlib inline
plt.figure(figsize=(10, 6))
plt.plot(wave12, flux12, linestyle='-', color='b')
plt.xlabel('Wavelength (Angstrom)')
plt.ylabel('Flux $(erg\ cm^{-2} s^{-1} A^{-1} · 1x 10^{-15})$')
plt.title('Espectro slit 12 sin corección galáctica')
plt.grid(True)
plt.show()
# Out:
# <>:5: SyntaxWarning: invalid escape sequence '\ '
# <>:5: SyntaxWarning: invalid escape sequence '\ '
# /var/folders/1d/sms3rjzs38jbhp0zx04sz91c0000gn/T/ipykernel_3374/1656138604.py:5: SyntaxWarning: invalid escape sequence '\ '
#   plt.ylabel('Flux $(erg\ cm^{-2} s^{-1} A^{-1} · 1x 10^{-15})$')

# %%
import extinction
from extinction import calzetti00

#tengo mi array de longitudes de onda de todo el espectro: wave1
# Calzetti+2000 with A_V = según el slit and R_V = 4.05
# mi A_v es A_v1m ojo que aquí estoy asumiendo que la MW es starburst !
wave12_c00 = extinction.calzetti00(wave12, A_v12, 4.05)
print(f' extinción en magnitudes para slit 12 con calzetti00: {wave12_c00}') #array of extinction in magnitudes at each input wavelength
# Out:
#  extinción en magnitudes para slit 12 con calzetti00: [0.06968407 0.06966139 0.06963872 ... 0.03457112 0.03456219 0.03455327]

# %%
from extinction import calzetti00, remove

print(f'valor de flujo sin corregir para slit 12: {flux12}')

# "deredden" flux by A_v1 with calzetti+2000
flux12_c00 = remove(calzetti00(wave12, A_v12, 4.05), flux12)
print(f'valor de flujo deredden para slit 12 con calzetti00: {flux12_c00}')
# Out:
# valor de flujo sin corregir para slit 12: [-0.04272235 -0.01342985  0.04804478 ...  0.00052727  0.00097142
#   0.00056144]
# valor de flujo deredden para slit 12 con calzetti00: [-0.04555423 -0.01431976  0.05122733 ...  0.00054433  0.00100284
#   0.0005796 ]

# %%
# %matplotlib inline
plt.figure(figsize=(10, 6))
plt.plot(wave12, flux12_c00, linestyle='-', color='b')
plt.xlabel('Wavelength (Angstrom)')
plt.ylabel('Flux $(erg\ cm^{-2} s^{-1} A^{-1} · 1x 10^{-15})$')
plt.title('Espectro slit 12 desenrojecido sólo con calzetti+2000')
plt.grid(True)
plt.show()
# Out:
# <>:5: SyntaxWarning: invalid escape sequence '\ '
# <>:5: SyntaxWarning: invalid escape sequence '\ '
# /var/folders/1d/sms3rjzs38jbhp0zx04sz91c0000gn/T/ipykernel_3374/3539556030.py:5: SyntaxWarning: invalid escape sequence '\ '
#   plt.ylabel('Flux $(erg\ cm^{-2} s^{-1} A^{-1} · 1x 10^{-15})$')

# %%
# guardar info corregida en un nuevo fits
# metemos el array de flujo corregido a la data del espectro
data12[0] = flux12_c00

# crear nuevo HDU 
slit12corrected = fits.PrimaryHDU(data=data12, header=header12)

# crear nuevo HDUList para guardar en un fits
sp12_corrected = fits.HDUList([slit12corrected])

# guardar datos corregidos en un nuevo archivo FITS
#new_fits_file1 = '../../Documentos/RESPALDO/NGC1313_250624_extinction/datos/slit1_2D_f99_c00.fits'
new_fits_file12 = '../../../reduccion/NGC1313/espectros_oficiales/slit12_2D_c00.fits'
sp12_corrected.writeto(new_fits_file12, overwrite=True)

print(f"Se ha guardado el archivo FITS corregido: {new_fits_file12}")
# Out:
# Se ha guardado el archivo FITS corregido: ../../../reduccion/NGC1313/espectros_oficiales/slit12_2D_c00.fits

# %% [markdown]
# SLIT 14

# %%
#slit 4, now sin f99
#abrir mi fits
#slit1_f99 = '../../Documentos/RESPALDO/NGC1313_250624_extinction/datos/slit1_2D_f99.fits'
slit14 = '../../../reduccion/NGC1313/espectros_oficiales/slit14.fits'
sp14 = fits.open(slit14)

sp14.info()
sp14[0].header["OBJECT"]
# Out:
# Filename: ../../../reduccion/NGC1313/espectros_oficiales/slit14.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      71   (2809, 1)   float32
# 'NGC1313-FIELD2 MASK02_median_avsig'

# %%
# extraer data (flux sin corregir por galáctica)
data14=sp14[0].data
header14=sp14[0].header
obj_name14 = header14.get("OBJECT", "Unknown")

flux14=data14[0]
w14=WCS(header14, naxis=1, relax=False, fix=False)
wave14=w14.wcs_pix2world(np.arange(len(flux14)),0)[0]

plt.plot(wave14, flux14)
plt.title("Espectro slit 14 sin corrección galáctica")
plt.xlabel('Wavelength (Angstrom)')
plt.ylabel('Flux $(erg\ cm^{-2} s^{-1} A^{-1} · 1 x 10^{-15})$')
# Out:
# <>:13: SyntaxWarning: invalid escape sequence '\ '
# <>:13: SyntaxWarning: invalid escape sequence '\ '
# /var/folders/1d/sms3rjzs38jbhp0zx04sz91c0000gn/T/ipykernel_3374/572798620.py:13: SyntaxWarning: invalid escape sequence '\ '
#   plt.ylabel('Flux $(erg\ cm^{-2} s^{-1} A^{-1} · 1 x 10^{-15})$')
# WARNING: FITSFixedWarning: RADECSYS= 'FK5 ' / R.A./DEC. coordinate system reference
# the RADECSYS keyword is deprecated, use RADESYSa. [astropy.wcs.wcs]
# Text(0, 0.5, 'Flux $(erg\\ cm^{-2} s^{-1} A^{-1} · 1 x 10^{-15})$')

# %%
wave14, flux14
# Out:
# (array([4036.02270508, 4037.50927031, 4038.99583554, ..., 8207.32474685,
#         8208.81131208, 8210.29787731]),
#  array([0.47265196, 0.04581696, 0.07054584, ..., 0.0074958 , 0.00774259,
#         0.00829834], dtype='>f4'))

# %%
# %matplotlib inline
plt.figure(figsize=(10, 6))
plt.plot(wave14, flux14, linestyle='-', color='b')
plt.xlabel('Wavelength (Angstrom)')
plt.ylabel('Flux $(erg\ cm^{-2} s^{-1} A^{-1} · 1x 10^{-15})$')
plt.title('Espectro slit 14 sin corección galáctica')
plt.grid(True)
plt.show()
# Out:
# <>:5: SyntaxWarning: invalid escape sequence '\ '
# <>:5: SyntaxWarning: invalid escape sequence '\ '
# /var/folders/1d/sms3rjzs38jbhp0zx04sz91c0000gn/T/ipykernel_3374/2534435187.py:5: SyntaxWarning: invalid escape sequence '\ '
#   plt.ylabel('Flux $(erg\ cm^{-2} s^{-1} A^{-1} · 1x 10^{-15})$')

# %%
import extinction
from extinction import calzetti00

#tengo mi array de longitudes de onda de todo el espectro: wave1
# Calzetti+2000 with A_V = según el slit and R_V = 4.05
# mi A_v es A_v1m ojo que aquí estoy asumiendo que la MW es starburst !
wave14_c00 = extinction.calzetti00(wave14, A_v14, 4.05)
print(f' extinción en magnitudes para slit 14 con calzetti00: {wave14_c00}') #array of extinction in magnitudes at each input wavelength
# Out:
#  extinción en magnitudes para slit 14 con calzetti00: [0.48358006 0.48342344 0.4832669  ... 0.21932563 0.2192717  0.2192178 ]

# %%
from extinction import calzetti00, remove

print(f'valor de flujo sin corregir para slit 14: {flux14}')

# "deredden" flux by A_v1 with calzetti+2000
flux14_c00 = remove(calzetti00(wave14, A_v14, 4.05), flux14)
print(f'valor de flujo deredden para slit 14 con calzetti00: {flux14_c00}')
# Out:
# valor de flujo sin corregir para slit 14: [0.47265196 0.04581696 0.07054584 ... 0.0074958  0.00774259 0.00829834]
# valor de flujo deredden para slit 14 con calzetti00: [0.73785918 0.07151476 0.11009769 ... 0.00917378 0.00947535 0.01015496]

# %%
# %matplotlib inline
plt.figure(figsize=(10, 6))
plt.plot(wave14, flux14_c00, linestyle='-', color='b')
plt.xlabel('Wavelength (Angstrom)')
plt.ylabel('Flux $(erg\ cm^{-2} s^{-1} A^{-1} · 1x 10^{-15})$')
plt.title('Espectro slit 14 desenrojecido sólo con calzetti+2000')
plt.grid(True)
plt.show()
# Out:
# <>:5: SyntaxWarning: invalid escape sequence '\ '
# <>:5: SyntaxWarning: invalid escape sequence '\ '
# /var/folders/1d/sms3rjzs38jbhp0zx04sz91c0000gn/T/ipykernel_3374/626103728.py:5: SyntaxWarning: invalid escape sequence '\ '
#   plt.ylabel('Flux $(erg\ cm^{-2} s^{-1} A^{-1} · 1x 10^{-15})$')

# %%
# guardar info corregida en un nuevo fits
# metemos el array de flujo corregido a la data del espectro
data14[0] = flux14_c00

# crear nuevo HDU 
slit14corrected = fits.PrimaryHDU(data=data14, header=header14)

# crear nuevo HDUList para guardar en un fits
sp14_corrected = fits.HDUList([slit14corrected])

# guardar datos corregidos en un nuevo archivo FITS
#new_fits_file1 = '../../Documentos/RESPALDO/NGC1313_250624_extinction/datos/slit1_2D_f99_c00.fits'
new_fits_file14 = '../../../reduccion/NGC1313/espectros_oficiales/slit14_2D_c00.fits'
sp14_corrected.writeto(new_fits_file14, overwrite=True)

print(f"Se ha guardado el archivo FITS corregido: {new_fits_file14}")
# Out:
# Se ha guardado el archivo FITS corregido: ../../../reduccion/NGC1313/espectros_oficiales/slit14_2D_c00.fits

# %% [markdown]
# SLIT 16

# %%
#slit 4, now sin f99
#abrir mi fits
#slit1_f99 = '../../Documentos/RESPALDO/NGC1313_250624_extinction/datos/slit1_2D_f99.fits'
slit16 = '../../../reduccion/NGC1313/espectros_oficiales/slit16.fits'
sp16 = fits.open(slit16)

sp16.info()
sp16[0].header["OBJECT"]
# Out:
# Filename: ../../../reduccion/NGC1313/espectros_oficiales/slit16.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      71   (2696, 1)   float32
# 'NGC1313-FIELD2 MASK02_median_avsig'

# %%
# extraer data (flux sin corregir por galáctica)
data16=sp16[0].data
header16=sp16[0].header
obj_name16 = header16.get("OBJECT", "Unknown")

flux16=data16[0]
w16=WCS(header16, naxis=1, relax=False, fix=False)
wave16=w16.wcs_pix2world(np.arange(len(flux16)),0)[0]

plt.plot(wave16, flux16)
plt.title("Espectro slit 16 sin corrección galáctica")
plt.xlabel('Wavelength (Angstrom)')
plt.ylabel('Flux $(erg\ cm^{-2} s^{-1} A^{-1} · 1 x 10^{-15})$')
# Out:
# <>:13: SyntaxWarning: invalid escape sequence '\ '
# <>:13: SyntaxWarning: invalid escape sequence '\ '
# /var/folders/1d/sms3rjzs38jbhp0zx04sz91c0000gn/T/ipykernel_3374/292865375.py:13: SyntaxWarning: invalid escape sequence '\ '
#   plt.ylabel('Flux $(erg\ cm^{-2} s^{-1} A^{-1} · 1 x 10^{-15})$')
# WARNING: FITSFixedWarning: RADECSYS= 'FK5 ' / R.A./DEC. coordinate system reference
# the RADECSYS keyword is deprecated, use RADESYSa. [astropy.wcs.wcs]
# Text(0, 0.5, 'Flux $(erg\\ cm^{-2} s^{-1} A^{-1} · 1 x 10^{-15})$')

# %%
# %matplotlib inline
plt.figure(figsize=(10, 6))
plt.plot(wave16, flux16, linestyle='-', color='b')
plt.xlabel('Wavelength (Angstrom)')
plt.ylabel('Flux $(erg\ cm^{-2} s^{-1} A^{-1} · 1x 10^{-15})$')
plt.title('Espectro slit 16 sin corección galáctica')
plt.grid(True)
plt.show()
# Out:
# <>:5: SyntaxWarning: invalid escape sequence '\ '
# <>:5: SyntaxWarning: invalid escape sequence '\ '
# /var/folders/1d/sms3rjzs38jbhp0zx04sz91c0000gn/T/ipykernel_3374/3808210326.py:5: SyntaxWarning: invalid escape sequence '\ '
#   plt.ylabel('Flux $(erg\ cm^{-2} s^{-1} A^{-1} · 1x 10^{-15})$')

# %%
import extinction
from extinction import calzetti00

#tengo mi array de longitudes de onda de todo el espectro: wave1
# Calzetti+2000 with A_V = según el slit and R_V = 4.05
# mi A_v es A_v1m ojo que aquí estoy asumiendo que la MW es starburst !
wave16_c00 = extinction.calzetti00(wave16, A_v16, 4.05)
print(f' extinción en magnitudes para slit 16 con calzetti00: {wave16_c00}') #array of extinction in magnitudes at each input wavelength
# Out:
#  extinción en magnitudes para slit 16 con calzetti00: [0.47998679 0.47983108 0.47967544 ... 0.2236228  0.22356701 0.22351124]

# %%
from extinction import calzetti00, remove

print(f'valor de flujo sin corregir para slit 16: {flux16}')

# "deredden" flux by A_v1 with calzetti+2000
flux16_c00 = remove(calzetti00(wave16, A_v16, 4.05), flux16)
print(f'valor de flujo deredden para slit 16 con calzetti00: {flux16_c00}')
# Out:
# valor de flujo sin corregir para slit 16: [0.01131533 0.17266868 0.44698045 ... 0.00402992 0.00597299 0.00499991]
# valor de flujo deredden para slit 16 con calzetti00: [0.01760606 0.26862474 0.69527834 ... 0.0049516  0.00733869 0.00614281]

# %%
# %matplotlib inline
plt.figure(figsize=(10, 6))
plt.plot(wave16, flux16_c00, linestyle='-', color='b')
plt.xlabel('Wavelength (Angstrom)')
plt.ylabel('Flux $(erg\ cm^{-2} s^{-1} A^{-1} · 1x 10^{-15})$')
plt.title('Espectro slit 16 desenrojecido sólo con calzetti+2000')
plt.grid(True)
plt.show()
# Out:
# <>:5: SyntaxWarning: invalid escape sequence '\ '
# <>:5: SyntaxWarning: invalid escape sequence '\ '
# /var/folders/1d/sms3rjzs38jbhp0zx04sz91c0000gn/T/ipykernel_3374/542592727.py:5: SyntaxWarning: invalid escape sequence '\ '
#   plt.ylabel('Flux $(erg\ cm^{-2} s^{-1} A^{-1} · 1x 10^{-15})$')

# %%
# guardar info corregida en un nuevo fits
# metemos el array de flujo corregido a la data del espectro
data16[0] = flux16_c00

# crear nuevo HDU 
slit16corrected = fits.PrimaryHDU(data=data16, header=header16)

# crear nuevo HDUList para guardar en un fits
sp16_corrected = fits.HDUList([slit16corrected])

# guardar datos corregidos en un nuevo archivo FITS
#new_fits_file1 = '../../Documentos/RESPALDO/NGC1313_250624_extinction/datos/slit1_2D_f99_c00.fits'
new_fits_file16 = '../../../reduccion/NGC1313/espectros_oficiales/slit16_2D_c00.fits'
sp16_corrected.writeto(new_fits_file16, overwrite=True)

print(f"Se ha guardado el archivo FITS corregido: {new_fits_file16}")
# Out:
# Se ha guardado el archivo FITS corregido: ../../../reduccion/NGC1313/espectros_oficiales/slit16_2D_c00.fits

# %% [markdown]
# SLIT 21

# %%
#slit 21, now sin f99, MASK 2
#abrir mi fits
#slit1_f99 = '../../Documentos/RESPALDO/NGC1313_250624_extinction/datos/slit1_2D_f99.fits'
slit21_2 = '../../../reduccion/NGC1313/espectros_oficiales/slit21_mask2.fits'
sp21_2 = fits.open(slit21_2)

sp21_2.info()
sp21_2[0].header["OBJECT"]
# Out:
# Filename: ../../../reduccion/NGC1313/espectros_oficiales/slit21_mask2.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      71   (2829, 1)   float32
# 'NGC1313-FIELD2 MASK02_median_avsig'

# %%
# extraer data (flux sin corregir por galáctica)
data21_2=sp21_2[0].data
header21_2=sp21_2[0].header
obj_name21_2 = header21_2.get("OBJECT", "Unknown")

flux21_2=data21_2[0]
w21_2=WCS(header21_2, naxis=1, relax=False, fix=False)
wave21_2=w21_2.wcs_pix2world(np.arange(len(flux21_2)),0)[0]

plt.plot(wave21_2, flux21_2)
plt.title("Espectro slit 21 mask 2 sin corrección galáctica")
plt.xlabel('Wavelength (Angstrom)')
plt.ylabel('Flux $(erg\ cm^{-2} s^{-1} A^{-1} · 1 x 10^{-15})$')
# Out:
# <>:13: SyntaxWarning: invalid escape sequence '\ '
# <>:13: SyntaxWarning: invalid escape sequence '\ '
# /var/folders/1d/sms3rjzs38jbhp0zx04sz91c0000gn/T/ipykernel_3374/3657209093.py:13: SyntaxWarning: invalid escape sequence '\ '
#   plt.ylabel('Flux $(erg\ cm^{-2} s^{-1} A^{-1} · 1 x 10^{-15})$')
# WARNING: FITSFixedWarning: RADECSYS= 'FK5 ' / R.A./DEC. coordinate system reference
# the RADECSYS keyword is deprecated, use RADESYSa. [astropy.wcs.wcs]
# Text(0, 0.5, 'Flux $(erg\\ cm^{-2} s^{-1} A^{-1} · 1 x 10^{-15})$')

# %%
# %matplotlib inline
plt.figure(figsize=(10, 6))
plt.plot(wave21_2, flux21_2, linestyle='-', color='b')
plt.xlabel('Wavelength (Angstrom)')
plt.ylabel('Flux $(erg\ cm^{-2} s^{-1} A^{-1} · 1x 10^{-15})$')
plt.title('Espectro slit 21 mask 2 sin corección galáctica')
plt.grid(True)
plt.show()
# Out:
# <>:5: SyntaxWarning: invalid escape sequence '\ '
# <>:5: SyntaxWarning: invalid escape sequence '\ '
# /var/folders/1d/sms3rjzs38jbhp0zx04sz91c0000gn/T/ipykernel_3374/4242718240.py:5: SyntaxWarning: invalid escape sequence '\ '
#   plt.ylabel('Flux $(erg\ cm^{-2} s^{-1} A^{-1} · 1x 10^{-15})$')

# %%
import extinction
from extinction import calzetti00

#tengo mi array de longitudes de onda de todo el espectro: wave1
# Calzetti+2000 with A_V = según el slit and R_V = 4.05
# mi A_v es A_v1m ojo que aquí estoy asumiendo que la MW es starburst !
wave21_2_c00 = extinction.calzetti00(wave21_2, A_v21_2, 4.05)
print(f' extinción en magnitudes para slit 21_2 con calzetti00: {wave21_2_c00}') #array of extinction in magnitudes at each input wavelength
# Out:
#  extinción en magnitudes para slit 21_2 con calzetti00: [0.08621809 0.08619017 0.08616226 ... 0.03891232 0.03890277 0.03889323]

# %%
from extinction import calzetti00, remove

print(f'valor de flujo sin corregir para slit 21_2: {flux21_2}')

# "deredden" flux by A_v1 with calzetti+2000
flux21_2_c00 = remove(calzetti00(wave21_2, A_v21_2, 4.05), flux21_2)
print(f'valor de flujo deredden para slit 21 mask 2 con calzetti00: {flux21_2_c00}')
# Out:
# valor de flujo sin corregir para slit 21_2: [ 0.22215053 -0.08139356  0.23654763 ...  0.00180901  0.00114812
#   0.00037767]
# valor de flujo deredden para slit 21 mask 2 con calzetti00: [ 0.24051081 -0.0881183   0.25608463 ...  0.00187502  0.00119
#   0.00039145]

# %%
# %matplotlib inline
plt.figure(figsize=(10, 6))
plt.plot(wave21_2, flux21_2_c00, linestyle='-', color='b')
plt.xlabel('Wavelength (Angstrom)')
plt.ylabel('Flux $(erg\ cm^{-2} s^{-1} A^{-1} · 1x 10^{-15})$')
plt.title('Espectro slit 21_2 desenrojecido sólo con calzetti+2000')
plt.grid(True)
plt.show()
# Out:
# <>:5: SyntaxWarning: invalid escape sequence '\ '
# <>:5: SyntaxWarning: invalid escape sequence '\ '
# /var/folders/1d/sms3rjzs38jbhp0zx04sz91c0000gn/T/ipykernel_3374/2980435664.py:5: SyntaxWarning: invalid escape sequence '\ '
#   plt.ylabel('Flux $(erg\ cm^{-2} s^{-1} A^{-1} · 1x 10^{-15})$')

# %%
# guardar info corregida en un nuevo fits
# metemos el array de flujo corregido a la data del espectro
data21_2[0] = flux21_2_c00

# crear nuevo HDU 
slit21_2corrected = fits.PrimaryHDU(data=data21_2, header=header21_2)

# crear nuevo HDUList para guardar en un fits
sp21_2_corrected = fits.HDUList([slit21_2corrected])

# guardar datos corregidos en un nuevo archivo FITS
#new_fits_file1 = '../../Documentos/RESPALDO/NGC1313_250624_extinction/datos/slit1_2D_f99_c00.fits'
new_fits_file21_2 = '../../../reduccion/NGC1313/espectros_oficiales/slit21_2_2D_c00.fits'
sp21_2_corrected.writeto(new_fits_file21_2, overwrite=True)

print(f"Se ha guardado el archivo FITS corregido: {new_fits_file21_2}")
# Out:
# Se ha guardado el archivo FITS corregido: ../../../reduccion/NGC1313/espectros_oficiales/slit21_2_2D_c00.fits

# %% [markdown]
# (slit 23 es el cúmulo)
#
# SLIT 25

# %%
#slit 1, now sin f99
#abrir mi fits
#slit1_f99 = '../../Documentos/RESPALDO/NGC1313_250624_extinction/datos/slit1_2D_f99.fits'
slit25 = '../../../reduccion/NGC1313/espectros_oficiales/slit25.fits'
sp25 = fits.open(slit25)

sp25.info()
sp25[0].header["OBJECT"]
# Out:
# Filename: ../../../reduccion/NGC1313/espectros_oficiales/slit25.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      71   (2590, 1)   float32
# 'NGC1313-FIELD2 MASK02_median_avsig'

# %%
# extraer data (flux sin corregir por galáctica)
data25=sp25[0].data
header25=sp25[0].header
obj_name25 = header25.get("OBJECT", "Unknown")

flux25=data25[0]
w25=WCS(header25, naxis=1, relax=False, fix=False)
wave25=w25.wcs_pix2world(np.arange(len(flux25)),0)[0]

plt.plot(wave25, flux25)
plt.title("Espectro slit 25 sin corrección galáctica")
plt.xlabel('Wavelength (Angstrom)')
plt.ylabel('Flux $(erg\ cm^{-2} s^{-1} A^{-1} · 1 x 10^{-15})$')
# Out:
# <>:13: SyntaxWarning: invalid escape sequence '\ '
# <>:13: SyntaxWarning: invalid escape sequence '\ '
# /var/folders/1d/sms3rjzs38jbhp0zx04sz91c0000gn/T/ipykernel_3374/4201628743.py:13: SyntaxWarning: invalid escape sequence '\ '
#   plt.ylabel('Flux $(erg\ cm^{-2} s^{-1} A^{-1} · 1 x 10^{-15})$')
# WARNING: FITSFixedWarning: RADECSYS= 'FK5 ' / R.A./DEC. coordinate system reference
# the RADECSYS keyword is deprecated, use RADESYSa. [astropy.wcs.wcs]
# Text(0, 0.5, 'Flux $(erg\\ cm^{-2} s^{-1} A^{-1} · 1 x 10^{-15})$')

# %%
# %matplotlib inline
plt.figure(figsize=(10, 6))
plt.plot(wave25, flux25, linestyle='-', color='b')
plt.xlabel('Wavelength (Angstrom)')
plt.ylabel('Flux $(erg\ cm^{-2} s^{-1} A^{-1} · 1x 10^{-15})$')
plt.title('Espectro slit 25 sin corección galáctica')
plt.grid(True)
plt.show()
# Out:
# <>:5: SyntaxWarning: invalid escape sequence '\ '
# <>:5: SyntaxWarning: invalid escape sequence '\ '
# /var/folders/1d/sms3rjzs38jbhp0zx04sz91c0000gn/T/ipykernel_3374/1509527384.py:5: SyntaxWarning: invalid escape sequence '\ '
#   plt.ylabel('Flux $(erg\ cm^{-2} s^{-1} A^{-1} · 1x 10^{-15})$')

# %%
import extinction
from extinction import calzetti00

#tengo mi array de longitudes de onda de todo el espectro: wave1
# Calzetti+2000 with A_V = según el slit and R_V = 4.05
# mi A_v es A_v1m ojo que aquí estoy asumiendo que la MW es starburst !
wave25_c00 = extinction.calzetti00(wave25, A_v25, 4.05)
print(f' extinción en magnitudes para slit 25 con calzetti00: {wave25_c00}') #array of extinction in magnitudes at each input wavelength
# Out:
#  extinción en magnitudes para slit 25 con calzetti00: [0.04216598 0.04215227 0.04213858 ... 0.02015026 0.02014516 0.02014006]

# %%
from extinction import calzetti00, remove

print(f'valor de flujo sin corregir para slit 25: {flux25}')

# "deredden" flux by A_v1 with calzetti+2000
flux25_c00 = remove(calzetti00(wave25, A_v25, 4.05), flux25)
print(f'valor de flujo deredden para slit 25 con calzetti00: {flux25_c00}')
# Out:
# valor de flujo sin corregir para slit 25: [ 0.2658894   0.13221002 -0.26268253 ... -0.00115941  0.00514543
#  -0.01600705]
# valor de flujo deredden para slit 25 con calzetti00: [ 0.2764187   0.13744384 -0.27307794 ... -0.00118113  0.00524179
#  -0.01630675]

# %%
# %matplotlib inline
plt.figure(figsize=(10, 6))
plt.plot(wave25, flux25_c00, linestyle='-', color='b')
plt.xlabel('Wavelength (Angstrom)')
plt.ylabel('Flux $(erg\ cm^{-2} s^{-1} A^{-1} · 1x 10^{-15})$')
plt.title('Espectro slit 25 desenrojecido sólo con calzetti+2000')
plt.grid(True)
plt.show()
# Out:
# <>:5: SyntaxWarning: invalid escape sequence '\ '
# <>:5: SyntaxWarning: invalid escape sequence '\ '
# /var/folders/1d/sms3rjzs38jbhp0zx04sz91c0000gn/T/ipykernel_3374/3535367938.py:5: SyntaxWarning: invalid escape sequence '\ '
#   plt.ylabel('Flux $(erg\ cm^{-2} s^{-1} A^{-1} · 1x 10^{-15})$')

# %%
# guardar info corregida en un nuevo fits
# metemos el array de flujo corregido a la data del espectro
data25[0] = flux25_c00

# crear nuevo HDU 
slit25corrected = fits.PrimaryHDU(data=data25, header=header25)

# crear nuevo HDUList para guardar en un fits
sp25_corrected = fits.HDUList([slit25corrected])

# guardar datos corregidos en un nuevo archivo FITS
#new_fits_file1 = '../../Documentos/RESPALDO/NGC1313_250624_extinction/datos/slit1_2D_f99_c00.fits'
new_fits_file25 = '../../../reduccion/NGC1313/espectros_oficiales/slit25_2D_c00.fits'
sp25_corrected.writeto(new_fits_file25, overwrite=True)

print(f"Se ha guardado el archivo FITS corregido: {new_fits_file25}")
# Out:
# Se ha guardado el archivo FITS corregido: ../../../reduccion/NGC1313/espectros_oficiales/slit25_2D_c00.fits

# %% [markdown]
# SLIT 27

# %%
#slit 1, now sin f99
#abrir mi fits
#slit1_f99 = '../../Documentos/RESPALDO/NGC1313_250624_extinction/datos/slit1_2D_f99.fits'
slit27 = '../../../reduccion/NGC1313/espectros_oficiales/slit27.fits'
sp27 = fits.open(slit27)

sp27.info()
sp27[0].header["OBJECT"]
# Out:
# Filename: ../../../reduccion/NGC1313/espectros_oficiales/slit27.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      71   (2699, 1)   float32
# 'NGC1313-FIELD2 MASK02_median_avsig'

# %%
# extraer data (flux sin corregir por galáctica)
data27=sp27[0].data
header27=sp27[0].header
obj_name27 = header27.get("OBJECT", "Unknown")

flux27=data27[0]
w27=WCS(header27, naxis=1, relax=False, fix=False)
wave27=w27.wcs_pix2world(np.arange(len(flux27)),0)[0]

plt.plot(wave27, flux27)
plt.title("Espectro slit 27 sin corrección galáctica")
plt.xlabel('Wavelength (Angstrom)')
plt.ylabel('Flux $(erg\ cm^{-2} s^{-1} A^{-1} · 1 x 10^{-15})$')
# Out:
# <>:13: SyntaxWarning: invalid escape sequence '\ '
# <>:13: SyntaxWarning: invalid escape sequence '\ '
# /var/folders/1d/sms3rjzs38jbhp0zx04sz91c0000gn/T/ipykernel_3374/1708668368.py:13: SyntaxWarning: invalid escape sequence '\ '
#   plt.ylabel('Flux $(erg\ cm^{-2} s^{-1} A^{-1} · 1 x 10^{-15})$')
# WARNING: FITSFixedWarning: RADECSYS= 'FK5 ' / R.A./DEC. coordinate system reference
# the RADECSYS keyword is deprecated, use RADESYSa. [astropy.wcs.wcs]
# Text(0, 0.5, 'Flux $(erg\\ cm^{-2} s^{-1} A^{-1} · 1 x 10^{-15})$')

# %%
# %matplotlib inline
plt.figure(figsize=(10, 6))
plt.plot(wave27, flux27, linestyle='-', color='b')
plt.xlabel('Wavelength (Angstrom)')
plt.ylabel('Flux $(erg\ cm^{-2} s^{-1} A^{-1} · 1x 10^{-15})$')
plt.title('Espectro slit 27 sin corección galáctica')
plt.grid(True)
plt.show()
# Out:
# <>:5: SyntaxWarning: invalid escape sequence '\ '
# <>:5: SyntaxWarning: invalid escape sequence '\ '
# /var/folders/1d/sms3rjzs38jbhp0zx04sz91c0000gn/T/ipykernel_3374/558817147.py:5: SyntaxWarning: invalid escape sequence '\ '
#   plt.ylabel('Flux $(erg\ cm^{-2} s^{-1} A^{-1} · 1x 10^{-15})$')

# %%
import extinction
from extinction import calzetti00

#tengo mi array de longitudes de onda de todo el espectro: wave1
# Calzetti+2000 with A_V = según el slit and R_V = 4.05
# mi A_v es A_v1m ojo que aquí estoy asumiendo que la MW es starburst !
wave27_c00 = extinction.calzetti00(wave27, A_v27, 4.05)
print(f' extinción en magnitudes para slit 27 con calzetti00: {wave27_c00}') #array of extinction in magnitudes at each input wavelength
# Out:
#  extinción en magnitudes para slit 27 con calzetti00: [0.2171591  0.21708865 0.21701823 ... 0.10109655 0.10107134 0.10104613]

# %%
from extinction import calzetti00, remove

print(f'valor de flujo sin corregir para slit 27: {flux27}')

# "deredden" flux by A_v1 with calzetti+2000
flux27_c00 = remove(calzetti00(wave27, A_v27, 4.05), flux27)
print(f'valor de flujo deredden para slit 27 con calzetti00: {flux27_c00}')
# Out:
# valor de flujo sin corregir para slit 27: [-4.01444912e-01  9.32439983e-01 -1.13359585e-01 ...  1.97663694e-03
#   6.83503691e-04  3.38507094e-03]
# valor de flujo deredden para slit 27 con calzetti00: [-4.90331278e-01  1.13882331e+00 -1.38441260e-01 ...  2.16952934e-03
#   7.50186768e-04  3.71523448e-03]

# %%
# %matplotlib inline
plt.figure(figsize=(10, 6))
plt.plot(wave27, flux27_c00, linestyle='-', color='b')
plt.xlabel('Wavelength (Angstrom)')
plt.ylabel('Flux $(erg\ cm^{-2} s^{-1} A^{-1} · 1x 10^{-15})$')
plt.title('Espectro slit 27 desenrojecido sólo con calzetti+2000')
plt.grid(True)
plt.show()
# Out:
# <>:5: SyntaxWarning: invalid escape sequence '\ '
# <>:5: SyntaxWarning: invalid escape sequence '\ '
# /var/folders/1d/sms3rjzs38jbhp0zx04sz91c0000gn/T/ipykernel_3374/739342813.py:5: SyntaxWarning: invalid escape sequence '\ '
#   plt.ylabel('Flux $(erg\ cm^{-2} s^{-1} A^{-1} · 1x 10^{-15})$')

# %%
# guardar info corregida en un nuevo fits
# metemos el array de flujo corregido a la data del espectro
data27[0] = flux27_c00

# crear nuevo HDU 
slit27corrected = fits.PrimaryHDU(data=data27, header=header27)

# crear nuevo HDUList para guardar en un fits
sp27_corrected = fits.HDUList([slit27corrected])

# guardar datos corregidos en un nuevo archivo FITS
#new_fits_file1 = '../../Documentos/RESPALDO/NGC1313_250624_extinction/datos/slit1_2D_f99_c00.fits'
new_fits_file27 = '../../../reduccion/NGC1313/espectros_oficiales/slit27_2D_c00.fits'
sp27_corrected.writeto(new_fits_file27, overwrite=True)

print(f"Se ha guardado el archivo FITS corregido: {new_fits_file27}")
# Out:
# Se ha guardado el archivo FITS corregido: ../../../reduccion/NGC1313/espectros_oficiales/slit27_2D_c00.fits
