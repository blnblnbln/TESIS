# %%
import numpy as np

# Set up matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

from astropy.io import fits

# %%
hdu_list = fits.open('../../../reduccion/mrgS20190730S0157_add.fits')
hdu_list.info()
# Out:
# Filename: ../../../reduccion/mrgS20190730S0157_add.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU     251   ()
#   1  SCI           1 ImageHDU        71   (3132, 2088)   float32

# %%
image_data = hdu_list[1].data

# %%
print(type(image_data))
print(image_data.shape)
# Out:
# <class 'numpy.ndarray'>
# (2088, 3132)

# %%
hdu_list.close()

# %%
image_data = fits.getdata("../../../reduccion/mrgS20190730S0157_add.fits")

# %%
print(type(image_data)) # Show the Python type for image_data
print(image_data.shape) # Show the number of pixels per side in the 2-D image
# Out:
# <class 'numpy.ndarray'>
# (2088, 3132)

# %%
plt.imshow(image_data, cmap='gray')
plt.colorbar()

# To see more color maps
# http://wiki.scipy.org/Cookbook/Matplotlib/Show_colormaps

# %%
print('Min:', np.min(image_data))
print('Max:', np.max(image_data))
print('Mean:', np.mean(image_data))
print('Stdev:', np.std(image_data))
# Out:
# Min: -3.505066
# Max: 221372.36
# Mean: 639.74854
# Stdev: 1825.3179

# %%
print(type(image_data.flatten()))
print(image_data.flatten().shape)
# Out:
# <class 'numpy.ndarray'>
# (6539616,)

# %%
histogram = plt.hist(image_data.flatten(), bins='auto')
