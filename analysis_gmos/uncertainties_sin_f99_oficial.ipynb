# %%
import uncertainties
from uncertainties import ufloat, umath, unumpy
import numpy as np
from astropy.io import fits
import pandas as pd
import matplotlib.pyplot as plt
from astropy.wcs import WCS

# %%
Ha1 = ufloat(184.479077,1.414290)
Hb1 = ufloat(48.294198,1.376638)
ratio1 = Ha1/Hb1
Ha1, Hb1, ratio1
# Out:
# (184.479077+/-1.41429,
#  48.294198+/-1.376638,
#  3.81990145068772+/-0.11275652318574136)

# %%
Ha3 = ufloat(39.064974,0.379652)
Hb3 = ufloat(11.822841,0.493198)
ratio3 = Ha3/Hb3
Ha3, Hb3, ratio3
# Out:
# (39.064974+/-0.379652,
#  11.822841+/-0.493198,
#  3.3041951591838203+/-0.14152789250574868)

# %%
#con última extracción, fit en mac (all mask 2)
Ha4 = ufloat(28.314379,0.360135)
Hb4 = ufloat(8.897626,0.357650)
ratio4 = Ha4/Hb4
Ha4, Hb4, ratio4
# Out:
# (28.314379+/-0.360135,
#  8.897626+/-0.35765,
#  3.1822397345089573+/-0.1341646992876656)

# %%
Ha7 = ufloat(27.926135,0.261522)
Hb7 = ufloat(7.343620,0.310548)
ratio7 = Ha7/Hb7
Ha7, Hb7, ratio7
# Out:
# (27.926135+/-0.261522,
#  7.34362+/-0.310548,
#  3.802775061890457+/-0.16470825702123276)

# %%
Ha8 = ufloat(14.639131,0.161281)
Hb8 = ufloat(4.396045,0.168001)
ratio8 = Ha8/Hb8
Ha8, Hb8, ratio8
# Out:
# (14.639131+/-0.161281,
#  4.396045+/-0.168001,
#  3.3300685047582546+/-0.13244590588754623)

# %%
Ha9 = ufloat(73.081374,1.521088)
Hb9 = ufloat(22.736416,0.603964)
ratio9 = Ha9/Hb9
Ha9, Hb9, ratio9
# Out:
# (73.081374+/-1.521088,
#  22.736416+/-0.603964,
#  3.2142873353478403+/-0.10847153141985126)

# %%
Ha10 = ufloat(4.437450,0.047571)
Hb10 = ufloat(1.515061,0.095131)
ratio10 = Ha10/Hb10
Ha10, Hb10, ratio10
# Out:
# (4.43745+/-0.047571,
#  1.515061+/-0.095131,
#  2.928891972006408+/-0.18656688804643282)

# %%
Ha11 = ufloat(97.157440,2.444699)
Hb11 = ufloat(24.291412,0.663081)
ratio11 = Ha11/Hb11
Ha11, Hb11, ratio11
# Out:
# (97.15744+/-2.444699,
#  24.291412+/-0.663081,
#  3.9996621028040686+/-0.14848719897652873)

# %%
Ha12 = ufloat(2.700172,0.042468)
Hb12 = ufloat(0.912737,0.051332)
ratio12 = Ha12/Hb12
Ha12, Hb12, ratio12
# Out:
# (2.700172+/-0.042468,
#  0.912737+/-0.051332,
#  2.958324248934797+/-0.17275862617158486)

# %%
Ha13 = ufloat(73.356268,1.143934)
Hb13 = ufloat(23.786815,0.865148)
ratio13 = Ha13/Hb13
Ha13, Hb13, ratio13
# Out:
# (73.356268+/-1.143934,
#  23.786815+/-0.865148,
#  3.083904591682409+/-0.12203936523621217)

# %%
Ha14 = ufloat(14.712767,0.273852)
Hb14 = ufloat(4.067869,0.118995)
ratio14 = Ha14/Hb14
Ha14, Hb14, ratio14
# Out:
# (14.712767+/-0.273852,
#  4.067869+/-0.118995,
#  3.6168241897661897+/-0.12540296379429094)

# %%
Ha16 = ufloat(9.559606,0.150714)
Hb16 = ufloat(2.648035,0.152600)
ratio16 = Ha16/Hb16
Ha16, Hb16, ratio16
# Out:
# (9.559606+/-0.150714,
#  2.648035+/-0.1526,
#  3.6100753955291376+/-0.21568507911708037)

# %%
Ha17 = ufloat(25.561836,0.279209)
Hb17 = ufloat(7.740044,0.251500)
ratio17 = Ha17/Hb17
Ha17, Hb17, ratio17
# Out:
# (25.561836+/-0.279209,
#  7.740044+/-0.2515,
#  3.3025440165456423+/-0.11321165021641931)

# %%
Ha19 = ufloat(17.750033,0.113360)
Hb19 = ufloat(5.306353,0.262317)
ratio19 = Ha19/Hb19
Ha19, Hb19, ratio19
# Out:
# (17.750033+/-0.11336,
#  5.306353+/-0.262317,
#  3.345053184362216+/-0.16673533198291468)

# %%
Ha21_1 = ufloat(18.094754,0.415183)
Hb21_1 = ufloat(3.950258,0.138168)
ratio21_1 = Ha21_1/Hb21_1
Ha21_1, Hb21_1, ratio21_1
# Out:
# (18.094754+/-0.415183,
#  3.950258+/-0.138168,
#  4.580651187846464+/-0.1916145910063952)

# %%
Ha21_2 = ufloat(2.651297,0.053817)
Hb21_2 = ufloat(0.889021,0.063899)
ratio21_2 = Ha21_2/Hb21_2
Ha21_2, Hb21_2, ratio21_2
# Out:
# (2.651297+/-0.053817,
#  0.889021+/-0.063899,
#  2.9822658857327333+/-0.22273631072141442)

# %%
Ha23_1 = ufloat(9.287973,0.088957)
Hb23_1 = ufloat(2.973351,0.109359)
ratio23_1 = Ha23_1/Hb23_1
Ha23_1, Hb23_1, ratio23_1
# Out:
# (9.287973+/-0.088957,
#  2.973351+/-0.109359,
#  3.123739175092345+/-0.11872176862877964)

# %%
Ha25 = ufloat(1.591199,0.027649)
Hb25 = ufloat(0.545103,0.086827)
ratio25 = Ha25/Hb25
Ha25, Hb25, ratio25
# Out:
# (1.591199+/-0.027649,
#  0.545103+/-0.086827,
#  2.9190795134130614+/-0.46772545699242435)

# %%
Ha27 = ufloat(1.239752,0.017830)
Hb27 = ufloat(0.390135,0.104473)
ratio27 = Ha27/Hb27
Ha27, Hb27, ratio27
# Out:
# (1.239752+/-0.01783,
#  0.390135+/-0.104473,
#  3.177751291219706+/-0.8521861917299794)

# %% [markdown]
# Cálculo de exceso de color estelar para desenrojecer el espectro por extinción interna usando Calzetti+2010
#
# $E(B-V)_{estelar} = 0.44 * E(B-V)_{gaseoso}$
#
# Para tener el valor de exceso de color estelar, primero debemos calcular el exceso de color gaseoso, haciendo uso de Dominguez+2013
#
#
# $E(B-V)_{gas} = 1.97 * log_{10} \dfrac{(H_{\alpha}/H_{\beta})_{obs}}{2.86} $

# %%
#ebv1_gas corresponde al exceso de color gaseoso para slit 1, donde H alfa (profile flux) es 227.407607 y H beta es 66.368468
ebv1_gas = 1.97 * unumpy.log10(ratio1/2.86)
print(f'el exceso de color gaseoso para slit 1 en magnitudes es: {ebv1_gas:.18f}')
#ebv3_gas corresponde al exceso de color gaseoso para slit 3, donde H alfa (profile flux) es 48.179734 y H beta es 16.314618
ebv3_gas = 1.97 * unumpy.log10(ratio3/2.86)
print(f'el exceso de color gaseoso para slit 3 en magnitudes es: {ebv3_gas:.18f}')
#ebv1_gas corresponde al exceso de color gaseoso para slit 1, donde H alfa (profile flux) es 227.407607 y H beta es 66.368468
ebv4_gas = 1.97 * unumpy.log10(ratio4/2.86)
print(f'el exceso de color gaseoso para slit 4 en magnitudes es: {ebv4_gas:.18f}')
#ebv7_gas corresponde al exceso de color gaseoso para slit 7, donde H alfa (profile flux) es 34.397799 y H beta es 10.126691
ebv7_gas = 1.97 * unumpy.log10(ratio7/2.86)
print(f'el exceso de color gaseoso para slit 7 en magnitudes es: {ebv7_gas:.18f}')
#ebv1_gas corresponde al exceso de color gaseoso para slit 1, donde H alfa (profile flux) es 227.407607 y H beta es 66.368468
ebv8_gas = 1.97 * unumpy.log10(ratio8/2.86)
print(f'el exceso de color gaseoso para slit 8 en magnitudes es: {ebv8_gas:.18f}')
#ebv9_gas corresponde al exceso de color gaseoso para slit 9, donde H alfa (profile flux) es 89.948951 y H beta es 31.371316
ebv9_gas = 1.97 * unumpy.log10(ratio9/2.86)
print(f'el exceso de color gaseoso para slit 9 en magnitudes es: {ebv9_gas:.18f}')
#ebv1_gas corresponde al exceso de color gaseoso para slit 1, donde H alfa (profile flux) es 227.407607 y H beta es 66.368468
ebv10_gas = 1.97 * unumpy.log10(ratio10/2.86)
print(f'el exceso de color gaseoso para slit 10 en magnitudes es: {ebv10_gas:.18f}')
#ebv11_gas corresponde al exceso de color gaseoso para slit 11, donde H alfa (profile flux) es 119.634652 y H beta es 33.414302
ebv11_gas = 1.97 * unumpy.log10(ratio11/2.86)
print(f'el exceso de color gaseoso para slit 11 en magnitudes es: {ebv11_gas:.18f}')
#ebv1_gas corresponde al exceso de color gaseoso para slit 1, donde H alfa (profile flux) es 227.407607 y H beta es 66.368468
ebv12_gas = 1.97 * unumpy.log10(ratio12/2.86)
print(f'el exceso de color gaseoso para slit 12 en magnitudes es: {ebv12_gas:.18f}')
#ebv1_gas corresponde al exceso de color gaseoso para slit 1, donde H alfa (profile flux) es 227.407607 y H beta es 66.368468
ebv13_gas = 1.97 * unumpy.log10(ratio13/2.86)
print(f'el exceso de color gaseoso para slit 13 en magnitudes es: {ebv13_gas:.18f}')
#ebv1_gas corresponde al exceso de color gaseoso para slit 1, donde H alfa (profile flux) es 227.407607 y H beta es 66.368468
ebv14_gas = 1.97 * unumpy.log10(ratio14/2.86)
print(f'el exceso de color gaseoso para slit 14 en magnitudes es: {ebv14_gas:.18f}')
#ebv1_gas corresponde al exceso de color gaseoso para slit 1, donde H alfa (profile flux) es 227.407607 y H beta es 66.368468
ebv16_gas = 1.97 * unumpy.log10(ratio16/2.86)
print(f'el exceso de color gaseoso para slit 16 en magnitudes es: {ebv16_gas:.18f}')
#ebv17_gas corresponde al exceso de color gaseoso para slit 17, donde H alfa (profile flux) es 31.497060 y H beta es 10.690070
ebv17_gas = 1.97 * unumpy.log10(ratio17/2.86)
print(f'el exceso de color gaseoso para slit 17 en magnitudes es: {ebv17_gas:.18f}')
#ebv19_gas corresponde al exceso de color gaseoso para slit 19, donde H alfa (profile flux) es 21.871311 y H beta es 7.311777
ebv19_gas = 1.97 * unumpy.log10(ratio19/2.86)
print(f'el exceso de color gaseoso para slit 19 en magnitudes es: {ebv19_gas:.18f}')
#ebv21_gas corresponde al exceso de color gaseoso para slit 21, donde H alfa (profile flux) es 22.314230 y H beta es 5.434664
ebv21_1_gas = 1.97 * unumpy.log10(ratio21_1/2.86)
print(f'el exceso de color gaseoso para slit 21 mask1 en magnitudes es: {ebv21_1_gas:.18f}')
#ebv21_gas corresponde al exceso de color gaseoso para slit 21, donde H alfa (profile flux) es 22.314230 y H beta es 5.434664
ebv21_2_gas = 1.97 * unumpy.log10(ratio21_2/2.86)
print(f'el exceso de color gaseoso para slit 21 mask2 en magnitudes es: {ebv21_2_gas:.18f}')
#ebv23_gas corresponde al exceso de color gaseoso para slit 23, donde H alfa (profile flux) es 11.441358 y H beta es 4.100256
ebv23_1_gas = 1.97 * unumpy.log10(ratio23_1/2.86)
print(f'el exceso de color gaseoso para slit 23 mask1 en magnitudes es: {ebv23_1_gas:.18f}')
#ebv1_gas corresponde al exceso de color gaseoso para slit 1, donde H alfa (profile flux) es 227.407607 y H beta es 66.368468
ebv25_gas = 1.97 * unumpy.log10(ratio25/2.86)
print(f'el exceso de color gaseoso para slit 25 en magnitudes es: {ebv25_gas:.18f}')
#ebv1_gas corresponde al exceso de color gaseoso para slit 1, donde H alfa (profile flux) es 227.407607 y H beta es 66.368468
ebv27_gas = 1.97 * unumpy.log10(ratio27/2.86)
print(f'el exceso de color gaseoso para slit 27 en magnitudes es: {ebv27_gas:.18f}')
# Out:
# el exceso de color gaseoso para slit 1 en magnitudes es: 0.247601667433639816+/-0.025254574445739725
# el exceso de color gaseoso para slit 3 en magnitudes es: 0.123518325220929884+/-0.036646026092683012
# el exceso de color gaseoso para slit 4 en magnitudes es: 0.091342716276539421+/-0.036070810829213540
# el exceso de color gaseoso para slit 7 en magnitudes es: 0.243757170019654051+/-0.037056574577394870
# el exceso de color gaseoso para slit 8 en magnitudes es: 0.130191655144730856+/-0.034027959548289972
# el exceso de color gaseoso para slit 9 en magnitudes es: 0.099915768071990457+/-0.028872315312860216
# el exceso de color gaseoso para slit 10 en magnitudes es: 0.020364521418107299+/-0.054498148922842209
# el exceso de color gaseoso para slit 11 en magnitudes es: 0.286944821756936030+/-0.031762614915401319
# el exceso de color gaseoso para slit 12 en magnitudes es: 0.028919088297304128+/-0.049962539639394531
# ...

# %% [markdown]
# Cálculo de exceso de color estelar (Calzetti+2000) usando el exceso de color gaseoso obtenido con Dominguez+2013
#
# $E(B-V)_{estelar} = 0.44 \pm 0.03 * E(B-V)_{gaseoso}$

# %%
factor = ufloat(0.44,0.03)
factor
# Out:
# 0.44+/-0.03

# %%
ebv1_est = factor * ebv1_gas
print(f'el exceso de color estelar para slit 1 es: {ebv1_est:.18f}')
ebv3_est = factor * ebv3_gas
print(f'el exceso de color estelar para slit 3 es: {ebv3_est:.18f}')
ebv4_est = factor * ebv4_gas
print(f'el exceso de color estelar para slit 4 es: {ebv4_est:.18f}')
#ebv5_est = factor * ebv5_gas
ebv7_est = factor * ebv7_gas
print(f'el exceso de color estelar para slit 7 es: {ebv7_est:.18f}')
ebv8_est = factor * ebv8_gas
print(f'el exceso de color estelar para slit 8 es: {ebv8_est:.18f}')
ebv9_est = factor * ebv9_gas
print(f'el exceso de color estelar para slit 9 es: {ebv9_est:.18f}')
ebv10_est = factor * ebv10_gas
print(f'el exceso de color estelar para slit 10 es: {ebv10_est:.18f}')
ebv11_est = factor * ebv11_gas
print(f'el exceso de color estelar para slit 11 es: {ebv11_est:.18f}')
ebv12_est = factor * ebv12_gas
print(f'el exceso de color estelar para slit 12 es: {ebv12_est:.18f}')
ebv13_est = factor * ebv13_gas
print(f'el exceso de color estelar para slit 13 es: {ebv13_est:.18f}')
ebv14_est = factor * ebv14_gas
print(f'el exceso de color estelar para slit 14 es: {ebv14_est:.18f}')
#ebv15_est = factor * ebv15_gas
ebv16_est = factor * ebv16_gas
print(f'el exceso de color estelar para slit 16 es: {ebv16_est:.18f}')
ebv17_est = factor * ebv17_gas
print(f'el exceso de color estelar para slit 17 es: {ebv17_est:.18f}')
ebv19_est = factor * ebv19_gas
print(f'el exceso de color estelar para slit 19 es: {ebv19_est:.18f}')
ebv21_1_est = factor * ebv21_1_gas
print(f'el exceso de color estelar para slit 21 mask 1 es: {ebv21_1_est:.18f}')
ebv21_2_est = factor * ebv21_2_gas
print(f'el exceso de color estelar para slit 21 mask 2 es: {ebv21_2_est:.18f}')
ebv23_1_est = factor * ebv23_1_gas
print(f'el exceso de color estelar para slit 23 mask 1 es: {ebv23_1_est:.18f}')
ebv25_est = factor * ebv25_gas
print(f'el exceso de color estelar para slit 25 es: {ebv25_est:.18f}')
ebv27_est = factor * ebv27_gas
print(f'el exceso de color estelar para slit 27 es: {ebv27_est:.18f}')
# Out:
# el exceso de color estelar para slit 1 es: 0.108944733670801513+/-0.013366104691967000
# el exceso de color estelar para slit 3 es: 0.054348063097209152+/-0.016544563603017703
# el exceso de color estelar para slit 4 es: 0.040190795161677347+/-0.016105985213257474
# el exceso de color estelar para slit 7 es: 0.107253154808647777+/-0.017869676321080153
# el exceso de color estelar para slit 8 es: 0.057284328263681579+/-0.015473354955143872
# el exceso de color estelar para slit 9 es: 0.043962937951675801+/-0.013052657015250086
# el exceso de color estelar para slit 10 es: 0.008960389423967211+/-0.023986966895630700
# el exceso de color estelar para slit 11 es: 0.126255721573051843+/-0.016414006555150778
# el exceso de color estelar para slit 12 es: 0.012724398850813817+/-0.022000630022673686
# el exceso de color estelar para slit 13 es: 0.028374611726928151+/-0.015022213214209943
# el exceso de color estelar para slit 14 es: 0.088380111634433281+/-0.014376074412368383
# ...

# %% [markdown]
# Desenrojecer el espectro usando exceso de color estelar de Calzetti+2000
# (obtenido con exceso de color gaseoso de Dominguez+2013)
#
# Ahora, para poder ingresar por input en la librería extinction el valor de $A_V$, lo calculamos teniendo el exceso de color gaseoso y el R_V:
#
# $R_V = \dfrac{A_V}{E(B-V)}$
#
# $A_V = E(B-V) * R_V$
#
# Donde R_v , de Calzetti+2000 , será 4.05 $\pm$ 0.80

# %%
Rv = ufloat(4.05,0.80)
Rv
# Out:
# 4.05+/-0.8

# %%
A_v1 = ebv1_est * Rv
A_v3 = ebv3_est * Rv
A_v4 = ebv4_est * Rv
A_v7 = ebv7_est * Rv
A_v8 = ebv8_est * Rv
A_v9 = ebv9_est * Rv
A_v10 = ebv10_est * Rv
A_v11 = ebv11_est * Rv
A_v12 = ebv12_est * Rv
A_v13 = ebv13_est * Rv
A_v14 = ebv14_est * Rv
A_v16 = ebv16_est * Rv
A_v17 = ebv17_est * Rv
A_v19 = ebv19_est * Rv
A_v21_1 = ebv21_1_est * Rv
A_v21_2 = ebv21_2_est * Rv
A_v23_1 = ebv23_1_est * Rv
A_v25 = ebv25_est * Rv
A_v27 = ebv27_est * Rv

print(f'el valor de A_v para slit 1 es {A_v1:.18f}')
print(f'el valor de A_v para slit 3 es {A_v3:.18f}')
print(f'el valor de A_v para slit 4 es {A_v4:.18f}')
print(f'el valor de A_v para slit 7 es {A_v7:.18f}')
print(f'el valor de A_v para slit 8 es {A_v8:.18f}')
print(f'el valor de A_v para slit 9 es {A_v9:.18f}')
print(f'el valor de A_v para slit 10 es {A_v10:.18f}')
print(f'el valor de A_v para slit 11 es {A_v11:.18f}')
print(f'el valor de A_v para slit 12 es {A_v12:.18f}')
print(f'el valor de A_v para slit 13 es {A_v13:.18f}')
print(f'el valor de A_v para slit 14 es {A_v14:.18f}')
print(f'el valor de A_v para slit 16 es {A_v16:.18f}')
print(f'el valor de A_v para slit 17 es {A_v17:.18f}')
print(f'el valor de A_v para slit 19 es {A_v19:.18f}')
print(f'el valor de A_v para slit 21 mask 1 es {A_v21_1:.18f}')
print(f'el valor de A_v para slit 21 mask 2 es {A_v21_2:.18f}')
print(f'el valor de A_v para slit 23 mask 1 es {A_v23_1:.18f}')
print(f'el valor de A_v para slit 25 es {A_v25:.18f}')
print(f'el valor de A_v para slit 27 es {A_v27:.18f}')
# Out:
# el valor de A_v para slit 1 es 0.441226171366746134+/-0.102598650110381065
# el valor de A_v para slit 3 es 0.220109655543697047+/-0.079875592976604501
# el valor de A_v para slit 4 es 0.162772720404793236+/-0.072723075951692570
# el valor de A_v para slit 7 es 0.434375276975023483+/-0.112248861257837951
# el valor de A_v para slit 8 es 0.232001529467910389+/-0.077635817723874484
# el valor de A_v para slit 9 es 0.178049898704286974+/-0.063493920171655546
# el valor de A_v para slit 10 es 0.036289577167067204+/-0.097411325074392346
# el valor de A_v para slit 11 es 0.511335672370859973+/-0.120917657104915768
# el valor de A_v para slit 12 es 0.051533815345795958+/-0.089682145987302203
# el valor de A_v para slit 13 es 0.114917177494059011+/-0.064936715799579520
# el valor de A_v para slit 14 es 0.357939452119454771+/-0.091591472190163711
# el valor de A_v para slit 16 es 0.355091960032595078+/-0.117486462374847139
# ...
