# %%
import numpy as np
from astropy.io import fits
import lime
import matplotlib.pyplot as plt

# %%
hdul = fits.open('../../../Desktop/respaldo/NGC1313_250624_extinction/datos/slit1_1D_f99_c00.fits', mode='update')
header = hdul[0].header
#header['BUNIT'] = '1e-15 erg / (Angstrom s cm2)'
header['FLUXSCAL'] = 1
header

hdul.flush()

# %%
print(header)
# Out:
# SIMPLE  =                    T / Fits standard                                  BITPIX  =                  -32 / Bits per pixel                                 NAXIS   =                    1 / Number of axes                                 NAXIS1  =                 2234 / Axis length                                    EXTEND  =                    F / File may contain extensions                    ORIGIN  = 'NOAO-IRAF FITS Image Kernel July 2003' / FITS file originator        OBJECT  = 'NGC1313-MSK01 2D CON LACOS' / Name of the object observed            DATE    = '2024-07-03T21:09:20' / Date FITS file was generated                  IRAF-TLM= '2024-07-03T21:09:20' / Time of last modification                     FIXPIX  = 'Jun 14 10:25 Bad pixel file is tmpbpm894khg.pl'                      CTYPE1  = 'LINEAR  '           / R.A. in tangent plane projection               CRPIX1  =                   1. / Ref pix of axis 1                              CRVAL1  =     4024.00463867188 / RA at Ref pix in decimal degrees               CD1_1   =     1.49589705467224 / WCS matrix element 1 1                         CCDSUM  = '2 2     '           / CCD sum                                        GAIN    =                   2. / Amplifier gain                                 GAINMULT=                1.933 / Gain multiplication                            RDNOISE =      5.9962655044619 / Readout noise                                  RADECSYS= 'FK5     '           / R.A./DEC. coordinate system reference          EQUINOX =                2000. / Equinox of coordinate system                   MJD-OBS =     58792.2853984876 / MJD of start of obseration                     WCSDIM  =                    1 /                                                LTM1_1  =                   1.                                                  WAT0_001= 'system=equispec'    /                                                WAT1_001= 'wtype=linear label=Wavelength units=angstroms' /                     MDFROW  =                    1 / Corresponding row in MDF                       DETSEC  = '[1:4338,2593:2950]' / Detector section(s)                            DATASEC = '[1:2169,1:179]'     / Data section(s)                                REFPIX1 =                1363. / Pixel of central wavelength                    DCLOG1  = 'Transform'                                                           DC-FLAG =                    0                                                  WAVTRAN = 'cmgsS20191105S0276_001' / Name of wavelength transformation          EXPTIME =                1050. /                                                IMCMB001= 'tcmxfrqgsS20191105S0274.fits[SCI,1]'                                 IMCMB002= 'tcmxfrqgsS20191105S0279.fits[SCI,1]'                                 NCOMBINE=                    2                                                  GAINORIG=                   1. / Input gain                                     RONORIG =                 4.24 / Input read-noise                               BANDID1 = 'spectrum - background fit, weights variance, clean no'               BANDID2 = 'raw - background fit, weights none, clean no'                        BANDID3 = 'background - background fit'                                         BANDID4 = 'sigma - background fit, weights variance, clean no'                  APNUM1  = '1 1 151.48 165.80'                                                   AIRMASS =                1.304 / Mean airmass for the observation               EX-FLAG =                    0                                                  CA-FLAG =                    0                                                  BUNIT   = 'erg/cm2/s/A'                                                         FLUXSCAL=                    1                                                  CDELT1  =     1.49589705467224                                                                                                                                   ...

# %%
def import_1313_fits(file_address, ext=0):
    
    #open the fits file
    with fits.open(file_address) as hdul:
        data, header = hdul[ext].data, hdul[ext].header
        
    #reconstruct the wavelength array from the header data
    w_min, dw, n_pix = header["CRVAL1"], header["CD1_1"], header["NAXIS1"]
    w_max = w_min + dw * n_pix
    wavelength = np.linspace(w_min, w_max, n_pix, endpoint=False)
    
    return wavelength, data, header

# %%
#now we specify the location and load the data
#address of NGC1313 spectrum (in this case, here)
fits_file1 = "../../../Desktop/respaldo/NGC1313_250624_extinction/datos/slit1_1D_f99_c00.fits"

#load the data
wave1, flux1, hdr1 = import_1313_fits(fits_file1)

# %%
# Galaxy redshift and the flux normalization
# la misma para todos los slits
z_obj = 0.001568
normFlux = 1

# %%
spec1 = lime.Spectrum(wave1, flux1, redshift=z_obj, norm_flux=normFlux, units_flux='1e-15 * FLAM')

# %%
spec1.plot.spectrum(label='slit1_NGC1313')

# %%
spec1.fit.bands(6300)
spec1.plot.bands()

# %%
line1_OI = 'O1_6300A'
band_edges_OI_1 = np.array([6282.963147, 6293.637954, 6293.754436, 6307, 6319.711710, 6327.945925])
spec1.fit.bands(line1_OI, band_edges_OI_1)
spec1.plot.bands()

# %% [markdown]
# SLIT 3

# %%
hdul3 = fits.open('../../../Desktop/respaldo/NGC1313_250624_extinction/datos/slit3_1D_f99_c00.fits', mode='update')
header3 = hdul3[0].header
#header['BUNIT'] = '1e-15 erg / (Angstrom s cm2)'
header3['FLUXSCAL'] = 1
header3
    
hdul3.flush()

# %%
print(header3)
# Out:
# SIMPLE  =                    T / Fits standard                                  BITPIX  =                  -32 / Bits per pixel                                 NAXIS   =                    1 / Number of axes                                 NAXIS1  =                 2225 / Axis length                                    EXTEND  =                    F / File may contain extensions                    ORIGIN  = 'NOAO-IRAF FITS Image Kernel July 2003' / FITS file originator        OBJECT  = 'NGC1313-MSK01 2D CON LACOS' / Name of the object observed            DATE    = '2024-07-03T21:09:20' / Date FITS file was generated                  IRAF-TLM= '2024-07-03T21:09:20' / Time of last modification                     FIXPIX  = 'Jun 14 10:25 Bad pixel file is tmpbpm894khg.pl'                      CTYPE1  = 'LINEAR  '           / R.A. in tangent plane projection               CRPIX1  =                   1. / Ref pix of axis 1                              CRVAL1  =     4024.88818359375 / RA at Ref pix in decimal degrees               CD1_1   =     1.49576783180237 / WCS matrix element 1 1                         CCDSUM  = '2 2     '           / CCD sum                                        GAIN    =                   2. / Amplifier gain                                 GAINMULT=                1.933 / Gain multiplication                            RDNOISE =      5.9962655044619 / Readout noise                                  RADECSYS= 'FK5     '           / R.A./DEC. coordinate system reference          EQUINOX =                2000. / Equinox of coordinate system                   MJD-OBS =     58792.2853984876 / MJD of start of obseration                     WCSDIM  =                    1 /                                                LTM1_1  =                   1.                                                  WAT0_001= 'system=equispec'    /                                                WAT1_001= 'wtype=linear label=Wavelength units=angstroms' /                     MDFROW  =                    3 / Corresponding row in MDF                       DETSEC  = '[1:4320,2955:3034]' / Detector section(s)                            DATASEC = '[1:2160,1:40]'      / Data section(s)                                REFPIX1 =                1354. / Pixel of central wavelength                    DCLOG1  = 'Transform'                                                           DC-FLAG =                    0                                                  WAVTRAN = 'cmgsS20191105S0276_003' / Name of wavelength transformation          EXPTIME =                1050. /                                                IMCMB001= 'tcmxfrqgsS20191105S0274.fits[SCI,3]'                                 IMCMB002= 'tcmxfrqgsS20191105S0279.fits[SCI,3]'                                 NCOMBINE=                    2                                                  GAINORIG=                   1. / Input gain                                     RONORIG =                 4.24 / Input read-noise                               BANDID1 = 'spectrum - background fit, weights variance, clean no'               BANDID2 = 'raw - background fit, weights none, clean no'                        BANDID3 = 'background - background fit'                                         BANDID4 = 'sigma - background fit, weights variance, clean no'                  APNUM1  = '1 1 15.08 29.86'                                                     AIRMASS =                1.304 / Mean airmass for the observation               EX-FLAG =                    0                                                  CA-FLAG =                    0                                                  BUNIT   = 'erg/cm2/s/A'                                                         FLUXSCAL=                    1                                                  CDELT1  =     1.49576783180237                                                                                                                                   ...

# %%
#now we specify the location and load the data
#address of NGC1313 spectrum (in this case, here)
fits_file3 = "../../../Desktop/respaldo/NGC1313_250624_extinction/datos/slit3_1D_f99_c00.fits"

#load the data
wave3, flux3, hdr3 = import_1313_fits(fits_file3)

# %%
spec3 = lime.Spectrum(wave3, flux3, redshift=z_obj, norm_flux=normFlux, units_flux='1e-15 * FLAM')

# %%
spec3.plot.spectrum(label='slit3_NGC1313')

# %%
spec3.fit.bands(6300)
spec3.plot.bands()

# %%
band_edges_OI_3 = np.array([6282.963147, 6293.637954, 6293.5, 6306, 6319.711710, 6327.945925])
spec3.fit.bands(line1_OI, band_edges_OI_3)
spec3.plot.bands()

# %% [markdown]
# SLIT 7

# %%
hdul7 = fits.open('../../../Desktop/respaldo/NGC1313_250624_extinction/datos/slit7_1D_f99_c00.fits', mode='update')
header7 = hdul7[0].header
#header['BUNIT'] = '1e-15 erg / (Angstrom s cm2)'
header7['FLUXSCAL'] = 1
header7
    
hdul7.flush()

# %%
print(header7)
# Out:
# SIMPLE  =                    T / Fits standard                                  BITPIX  =                  -32 / Bits per pixel                                 NAXIS   =                    1 / Number of axes                                 NAXIS1  =                 2178 / Axis length                                    EXTEND  =                    F / File may contain extensions                    ORIGIN  = 'NOAO-IRAF FITS Image Kernel July 2003' / FITS file originator        OBJECT  = 'NGC1313-MSK01 2D CON LACOS' / Name of the object observed            DATE    = '2024-07-04T15:22:41' / Date FITS file was generated                  IRAF-TLM= '2024-07-04T15:22:41' / Time of last modification                     FIXPIX  = 'Jun 14 10:25 Bad pixel file is tmpbpm894khg.pl'                      CTYPE1  = 'LINEAR  '           / R.A. in tangent plane projection               CRPIX1  =                   1. / Ref pix of axis 1                              CRVAL1  =      4021.7333984375 / RA at Ref pix in decimal degrees               CD1_1   =     1.49659216403961 / WCS matrix element 1 1                         CCDSUM  = '2 2     '           / CCD sum                                        GAIN    =                   2. / Amplifier gain                                 GAINMULT=                1.933 / Gain multiplication                            RDNOISE =      5.9962655044619 / Readout noise                                  RADECSYS= 'FK5     '           / R.A./DEC. coordinate system reference          EQUINOX =                2000. / Equinox of coordinate system                   MJD-OBS =     58792.2853984876 / MJD of start of obseration                     WCSDIM  =                    1 /                                                LTM1_1  =                   1.                                                  WAT0_001= 'system=equispec'    /                                                WAT1_001= 'wtype=linear label=Wavelength units=angstroms' /                     MDFROW  =                    7 / Corresponding row in MDF                       DETSEC  = '[1:4226,2219:2586]' / Detector section(s)                            DATASEC = '[1:2113,1:184]'     / Data section(s)                                REFPIX1 =                1307. / Pixel of central wavelength                    DCLOG1  = 'Transform'                                                           DC-FLAG =                    0                                                  WAVTRAN = 'cmgsS20191105S0276_007' / Name of wavelength transformation          EXPTIME =                1050. /                                                IMCMB001= 'tcmxfrqgsS20191105S0274.fits[SCI,7]'                                 IMCMB002= 'tcmxfrqgsS20191105S0279.fits[SCI,7]'                                 NCOMBINE=                    2                                                  GAINORIG=                   1. / Input gain                                     RONORIG =                 4.24 / Input read-noise                               BANDID1 = 'spectrum - background fit, weights variance, clean no'               BANDID2 = 'raw - background fit, weights none, clean no'                        BANDID3 = 'background - background fit'                                         BANDID4 = 'sigma - background fit, weights variance, clean no'                  APNUM1  = '1 1 26.80 38.06'                                                     AIRMASS =                1.304 / Mean airmass for the observation               EX-FLAG =                    0                                                  CA-FLAG =                    0                                                  BUNIT   = 'erg/cm2/s/A'                                                         FLUXSCAL=                    1                                                  CDELT1  =     1.49659216403961                                                                                                                                   ...

# %%
#now we specify the location and load the data
#address of NGC1313 spectrum (in this case, here)
fits_file7 = "../../../Desktop/respaldo/NGC1313_250624_extinction/datos/slit7_1D_f99_c00.fits"

#load the data
wave7, flux7, hdr7 = import_1313_fits(fits_file7)

# %%
spec7 = lime.Spectrum(wave7, flux7, redshift=z_obj, norm_flux=normFlux, units_flux='1e-15 * FLAM')

# %%
spec7.plot.spectrum(label='slit7_NGC1313')

# %%
spec7.fit.bands(6300)
spec7.plot.bands()

# %%
band_edges_OI_7 = np.array([6282.963147, 6291, 6292, 6306, 6319.711710, 6327.945925])
spec7.fit.bands(line1_OI, band_edges_OI_7)
spec7.plot.bands()

# %% [markdown]
# SLIT 9

# %%
hdul9 = fits.open('../../../Desktop/respaldo/NGC1313_250624_extinction/datos/slit9_1D_f99_c00.fits', mode='update')
header9 = hdul9[0].header
#header['BUNIT'] = '1e-15 erg / (Angstrom s cm2)'
header9['FLUXSCAL'] = 1
header9
    
hdul9.flush()

# %%
print(header9)
# Out:
# SIMPLE  =                    T / Fits standard                                  BITPIX  =                  -32 / Bits per pixel                                 NAXIS   =                    1 / Number of axes                                 NAXIS1  =                 2807 / Axis length                                    EXTEND  =                    F / File may contain extensions                    ORIGIN  = 'NOAO-IRAF FITS Image Kernel July 2003' / FITS file originator        OBJECT  = 'NGC1313-MSK01 2D CON LACOS' / Name of the object observed            DATE    = '2024-07-03T21:09:20' / Date FITS file was generated                  IRAF-TLM= '2024-07-03T21:09:20' / Time of last modification                     FIXPIX  = 'Jun 14 10:25 Bad pixel file is tmpbpm894khg.pl'                      CTYPE1  = 'LINEAR  '           / R.A. in tangent plane projection               CRPIX1  =                   1. / Ref pix of axis 1                              CRVAL1  =     4035.11450195312 / RA at Ref pix in decimal degrees               CD1_1   =     1.48707938194275 / WCS matrix element 1 1                         CCDSUM  = '2 2     '           / CCD sum                                        GAIN    =                   2. / Amplifier gain                                 GAINMULT=                1.933 / Gain multiplication                            RDNOISE =      5.9962655044619 / Readout noise                                  RADECSYS= 'FK5     '           / R.A./DEC. coordinate system reference          EQUINOX =                2000. / Equinox of coordinate system                   MJD-OBS =     58792.2853984876 / MJD of start of obseration                     WCSDIM  =                    1 /                                                LTM1_1  =                   1.                                                  WAT0_001= 'system=equispec'    /                                                WAT1_001= 'wtype=linear label=Wavelength units=angstroms' /                     MDFROW  =                    9 / Corresponding row in MDF                       DETSEC  = '[1:5486,1665:1872]' / Detector section(s)                            DATASEC = '[1:2743,1:104]'     / Data section(s)                                REFPIX1 =                1937. / Pixel of central wavelength                    DCLOG1  = 'Transform'                                                           DC-FLAG =                    0                                                  WAVTRAN = 'cmgsS20191105S0276_009' / Name of wavelength transformation          EXPTIME =                1050. /                                                IMCMB001= 'tcmxfrqgsS20191105S0274.fits[SCI,9]'                                 IMCMB002= 'tcmxfrqgsS20191105S0279.fits[SCI,9]'                                 NCOMBINE=                    2                                                  GAINORIG=                   1. / Input gain                                     RONORIG =                 4.24 / Input read-noise                               BANDID1 = 'spectrum - background fit, weights variance, clean no'               BANDID2 = 'raw - background fit, weights none, clean no'                        BANDID3 = 'background - background fit'                                         BANDID4 = 'sigma - background fit, weights variance, clean no'                  APNUM1  = '1 1 74.19 85.90'                                                     AIRMASS =                1.304 / Mean airmass for the observation               EX-FLAG =                    0                                                  CA-FLAG =                    0                                                  BUNIT   = 'erg/cm2/s/A'                                                         FLUXSCAL=                    1                                                  CDELT1  =     1.48707938194275                                                                                                                                   ...

# %%
#now we specify the location and load the data
#address of NGC1313 spectrum (in this case, here)
fits_file9 = "../../../Desktop/respaldo/NGC1313_250624_extinction/datos/slit9_1D_f99_c00.fits"

#load the data
wave9, flux9, hdr9 = import_1313_fits(fits_file9)

# %%
spec9 = lime.Spectrum(wave9, flux9, redshift=z_obj, norm_flux=normFlux, units_flux='1e-15 * FLAM')

# %%
spec9.plot.spectrum(label='slit9_NGC1313')

# %%
spec9.fit.bands(6300)
spec9.plot.bands()

# %%
band_edges_OI_9 = np.array([6282.963147, 6292, 6293, 6307, 6319.711710, 6327.945925])
spec9.fit.bands(line1_OI, band_edges_OI_9)
spec9.plot.bands()

# %% [markdown]
# SLIT 11

# %%
hdul11 = fits.open('../../../Desktop/respaldo/NGC1313_250624_extinction/datos/slit11_1D_f99_c00.fits', mode='update')
header11 = hdul11[0].header
#header['BUNIT'] = '1e-15 erg / (Angstrom s cm2)'
header11['FLUXSCAL'] = 1
header11
    
hdul11.flush()

# %%
print(header11)
# Out:
# SIMPLE  =                    T / Fits standard                                  BITPIX  =                  -32 / Bits per pixel                                 NAXIS   =                    1 / Number of axes                                 NAXIS1  =                 2789 / Axis length                                    EXTEND  =                    F / File may contain extensions                    ORIGIN  = 'NOAO-IRAF FITS Image Kernel July 2003' / FITS file originator        OBJECT  = 'NGC1313-MSK01 2D CON LACOS' / Name of the object observed            DATE    = '2024-07-03T21:09:20' / Date FITS file was generated                  IRAF-TLM= '2024-07-03T21:09:20' / Time of last modification                     FIXPIX  = 'Jun 14 10:25 Bad pixel file is tmpbpm894khg.pl'                      CTYPE1  = 'LINEAR  '           / R.A. in tangent plane projection               CRPIX1  =                   1. / Ref pix of axis 1                              CRVAL1  =     4035.43627929687 / RA at Ref pix in decimal degrees               CD1_1   =     1.48749339580536 / WCS matrix element 1 1                         CCDSUM  = '2 2     '           / CCD sum                                        GAIN    =                   2. / Amplifier gain                                 GAINMULT=                1.933 / Gain multiplication                            RDNOISE =      5.9962655044619 / Readout noise                                  RADECSYS= 'FK5     '           / R.A./DEC. coordinate system reference          EQUINOX =                2000. / Equinox of coordinate system                   MJD-OBS =     58792.2853984876 / MJD of start of obseration                     WCSDIM  =                    1 /                                                LTM1_1  =                   1.                                                  WAT0_001= 'system=equispec'    /                                                WAT1_001= 'wtype=linear label=Wavelength units=angstroms' /                     MDFROW  =                   11 / Corresponding row in MDF                       DETSEC  = '[1:5450,1295:1656]' / Detector section(s)                            DATASEC = '[1:2725,1:181]'     / Data section(s)                                REFPIX1 =                1919. / Pixel of central wavelength                    DCLOG1  = 'Transform'                                                           DC-FLAG =                    0                                                  WAVTRAN = 'cmgsS20191105S0276_011' / Name of wavelength transformation          EXPTIME =                1050. /                                                IMCMB001= 'tcmxfrqgsS20191105S0274.fits[SCI,11]'                                IMCMB002= 'tcmxfrqgsS20191105S0279.fits[SCI,11]'                                NCOMBINE=                    2                                                  GAINORIG=                   1. / Input gain                                     RONORIG =                 4.24 / Input read-noise                               BANDID1 = 'spectrum - background fit, weights variance, clean no'               BANDID2 = 'raw - background fit, weights none, clean no'                        BANDID3 = 'background - background fit'                                         BANDID4 = 'sigma - background fit, weights variance, clean no'                  APNUM1  = '1 1 103.64 115.91'                                                   AIRMASS =                1.304 / Mean airmass for the observation               EX-FLAG =                    0                                                  CA-FLAG =                    0                                                  BUNIT   = 'erg/cm2/s/A'                                                         FLUXSCAL=                    1                                                  CDELT1  =     1.48749339580536                                                                                                                                   ...
