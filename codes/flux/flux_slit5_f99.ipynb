# %%
import numpy as np
from astropy.io import fits
import lime 
import matplotlib.pyplot as plt

# %%
hdul = fits.open('../../Documentos/RESPALDO/NGC1313_250624_extinction/datos/slit5_1D_f99.fits', mode='update')
header = hdul[0].header
#header['BUNIT'] = '1e-15 erg / (Angstrom s cm2)'
header['FLUXSCAL'] = 1
header
    
hdul.flush()

# %%
#hdul = fits.open('../../../reduccion/NGC1313/cal/slit1copy_1D001.fits', mode='update')
#header = hdul[0].header
#header['BUNIT'] = '1e-15 erg / (Angstrom s cm2)'
#header['FLUXSCAL'] = 1
#header
    
#hdul.flush()

# %%
print(header)
# Out:
# SIMPLE  =                    T / Fits standard                                  BITPIX  =                  -32 / Bits per pixel                                 NAXIS   =                    1 / Number of axes                                 NAXIS1  =                 2294 / Axis length                                    EXTEND  =                    F / File may contain extensions                    ORIGIN  = 'NOAO-IRAF FITS Image Kernel July 2003' / FITS file originator        OBJECT  = 'NGC1313-MSK01 2D CON LACOS' / Name of the object observed            DATE    = '2024-07-01T18:37:34' / Date FITS file was generated                  IRAF-TLM= '2024-07-01T18:37:34' / Time of last modification                     FIXPIX  = 'Jun 14 10:25 Bad pixel file is tmpbpm894khg.pl'                      CTYPE1  = 'LINEAR  '           / R.A. in tangent plane projection               CRPIX1  =                   1. / Ref pix of axis 1                              CRVAL1  =     4026.58569335938 / RA at Ref pix in decimal degrees               CD1_1   =     1.49517977237701 / WCS matrix element 1 1                         CCDSUM  = '2 2     '           / CCD sum                                        GAIN    =                   2. / Amplifier gain                                 GAINMULT=                1.933 / Gain multiplication                            RDNOISE =      5.9962655044619 / Readout noise                                  RADECSYS= 'FK5     '           / R.A./DEC. coordinate system reference          EQUINOX =                2000. / Equinox of coordinate system                   MJD-OBS =     58792.2853984876 / MJD of start of obseration                     WCSDIM  =                    1 /                                                LTM1_1  =                   1.                                                  WAT0_001= 'system=equispec'    /                                                WAT1_001= 'wtype=linear label=Wavelength units=angstroms' /                     MDFROW  =                    5 / Corresponding row in MDF                       DETSEC  = '[1:4458,3043:3204]' / Detector section(s)                            DATASEC = '[1:2229,1:81]'      / Data section(s)                                REFPIX1 =                1423. / Pixel of central wavelength                    DCLOG1  = 'Transform'                                                           DC-FLAG =                    0                                                  WAVTRAN = 'cmgsS20191105S0276_005' / Name of wavelength transformation          EXPTIME =                1050. /                                                IMCMB001= 'tcmxfrqgsS20191105S0274.fits[SCI,5]'                                 IMCMB002= 'tcmxfrqgsS20191105S0279.fits[SCI,5]'                                 NCOMBINE=                    2                                                  GAINORIG=                   1. / Input gain                                     RONORIG =                 4.24 / Input read-noise                               BANDID1 = 'spectrum - background fit, weights variance, clean no'               BANDID2 = 'raw - background fit, weights none, clean no'                        BANDID3 = 'background - background fit'                                         BANDID4 = 'sigma - background fit, weights variance, clean no'                  APNUM1  = '1 1 15.06 30.14'                                                     AIRMASS =                1.304 / Mean airmass for the observation               EX-FLAG =                    0                                                  CA-FLAG =                    0                                                  BUNIT   = 'erg/cm2/s/A'                                                         FLUXSCAL=                    1                                                  CDELT1  =     1.49517977237701                                                                                                                                   ...

# %%
def import_1313_fits(file_address, ext=0):
    
    #open the fits file
    with fits.open(file_address) as hdul:
        data, header = hdul[ext].data, hdul[ext].header
        
    #reconstruct the wavelength array from the header data
    w_min, dw, n_pix = header["CRVAL1"], header["CD1_1"], header["NAXIS1"]
    w_max = w_min + dw * n_pix
    wavelength = np.linspace(w_min, w_max, n_pix, endpoint=False)
    
    return wavelength, data, header

# %%
#now we specify the location and load the data
#address of NGC1313 spectrum (in this case, here)
fits_file = "../../Documentos/RESPALDO/NGC1313_250624_extinction/datos/slit5_1D_f99.fits"

#load the data
wave, flux, hdr = import_1313_fits(fits_file)

# %%
# Galaxy redshift and the flux normalization
z_obj = 0.001568
normFlux = 1

# %%
spec5 = lime.Spectrum(wave, flux, redshift=z_obj, norm_flux=normFlux, units_flux='1e-15 * FLAM')

# %%
spec5.plot.spectrum(label='NGC1313')

# %%
spec5.fit.bands(6563)

# %%
spec5.plot.bands()

# %%
# Line name and its location mask in the rest _frame
line = 'H1_6563A'
band_edges = np.array([6438.03, 6508.66, 6535.10, 6600.95, 6627.70, 6661.82])

# %%
# Run the fitting and plot it
spec5.fit.bands(line, band_edges)
spec5.plot.bands()

# %%
# Fit configuration
line = 'H1_6563A_b'
fit_conf = {'H1_6563A_b': 'H1_6563A+N2_6584A+N2_6548A',
            'N2_6548A_amp': {'expr': 'N2_6584A_amp/2.94'},
            'N2_6548A_kinem': 'N2_6584A'}

# %%
# New attempt including the fit configuration
spec5.fit.bands(line, band_edges, fit_conf=fit_conf)
spec5.plot.bands()

# %%
spec5.fit.bands(4861)
spec5.plot.bands()

# %%
spec5.fit.frame
# Out:
# <bound method SpecTreatment.frame of <lime.workflow.SpecTreatment object at 0x7fa315558370>>

# %%
spec5.plot.grid()

# %%
#spec5.save_frame('slit5_Hae_HbMALO_f99.txt
