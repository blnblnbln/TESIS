# %%
import astropy
from astropy.io import fits
from astropy.io import ascii
from astropy.table import Table
import numpy as np
import matplotlib.pyplot as plt
from dust_extinction.parameter_averages import CCM89, F99


# Leer el archivo FITS
sp1 = ascii.read("../../../reduccion/NGC1313/cal/slit1_ascii.txt")
print(sp1)

# renombrar las columnas
sp1['col1'].name = 'wavelength'
sp1['col2'].name = "flux"
sp1

wave = sp1["wavelength"]
flux = sp1["flux"]
wave.data
# Out:
#       col1           col2
# ---------------- -----------
# 4024.00463867189   0.2809365
# 4025.50053572656   0.1263353
# 4026.99643278123   0.6645973
#  4028.4923298359   0.2400979
# 4029.98822689057   0.4354501
# 4031.48412394525 -0.03192461
# 4032.98002099992   0.2785238
# 4034.47591805459   0.2410768
# 4035.97181510926   0.3245422
# 4037.46771216393   0.3363686
#              ...         ...
# 7349.38379120828  0.07615397
# 7350.87968826295  0.07790677
# 7352.37558531762  0.07631195
# 7353.87148237229  0.07529981
# 7355.36737942697  0.07321899
# 7356.86327648164  0.07274434
# 7358.35917353631  0.06967138
# 7359.85507059098  0.07259004
# 7361.35096764566  0.07287291
# 7362.84686470033  0.07423379
#   7364.342761755  0.06625135
# Length = 2234 rows
# array([4024.00463867, 4025.50053573, 4026.99643278, ..., 7361.35096765,
#        7362.8468647 , 7364.34276175])

# %%
pip install ipympl
# Out:
# Collecting ipympl
#   Using cached ipympl-0.9.3-py2.py3-none-any.whl.metadata (1.3 kB)
# Requirement already satisfied: ipython<9 in /Users/belen/opt/anaconda3/lib/python3.8/site-packages (from ipympl) (7.22.0)
# Requirement already satisfied: numpy in /Users/belen/opt/anaconda3/lib/python3.8/site-packages (from ipympl) (1.24.4)
# Requirement already satisfied: ipython-genutils in /Users/belen/opt/anaconda3/lib/python3.8/site-packages (from ipympl) (0.2.0)
# Requirement already satisfied: pillow in /Users/belen/opt/anaconda3/lib/python3.8/site-packages (from ipympl) (8.2.0)
# Requirement already satisfied: traitlets<6 in /Users/belen/opt/anaconda3/lib/python3.8/site-packages (from ipympl) (5.0.5)
# Requirement already satisfied: ipywidgets<9,>=7.6.0 in /Users/belen/opt/anaconda3/lib/python3.8/site-packages (from ipympl) (7.6.3)
# Requirement already satisfied: matplotlib<4,>=3.4.0 in /Users/belen/opt/anaconda3/lib/python3.8/site-packages (from ipympl) (3.7.2)
# Requirement already satisfied: setuptools>=18.5 in /Users/belen/opt/anaconda3/lib/python3.8/site-packages (from ipython<9->ipympl) (52.0.0.post20210125)
# Requirement already satisfied: jedi>=0.16 in /Users/belen/opt/anaconda3/lib/python3.8/site-packages (from ipython<9->ipympl) (0.17.2)
# Requirement already satisfied: decorator in /Users/belen/opt/anaconda3/lib/python3.8/site-packages (from ipython<9->ipympl) (5.0.6)
# Requirement already satisfied: pickleshare in /Users/belen/opt/anaconda3/lib/python3.8/site-packages (from ipython<9->ipympl) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /Users/belen/opt/anaconda3/lib/python3.8/site-packages (from ipython<9->ipympl) (3.0.17)
# Requirement already satisfied: pygments in /Users/belen/opt/anaconda3/lib/python3.8/site-packages (from ipython<9->ipympl) (2.8.1)
# Requirement already satisfied: backcall in /Users/belen/opt/anaconda3/lib/python3.8/site-packages (from ipython<9->ipympl) (0.2.0)
# Requirement already satisfied: pexpect>4.3 in /Users/belen/opt/anaconda3/lib/python3.8/site-packages (from ipython<9->ipympl) (4.8.0)
# Requirement already satisfied: appnope in /Users/belen/opt/anaconda3/lib/python3.8/site-packages (from ipython<9->ipympl) (0.1.2)
# Requirement already satisfied: ipykernel>=4.5.1 in /Users/belen/opt/anaconda3/lib/python3.8/site-packages (from ipywidgets<9,>=7.6.0->ipympl) (5.3.4)
# Requirement already satisfied: nbformat>=4.2.0 in /Users/belen/opt/anaconda3/lib/python3.8/site-packages (from ipywidgets<9,>=7.6.0->ipympl) (5.1.3)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in /Users/belen/opt/anaconda3/lib/python3.8/site-packages (from ipywidgets<9,>=7.6.0->ipympl) (3.5.1)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /Users/belen/opt/anaconda3/lib/python3.8/site-packages (from ipywidgets<9,>=7.6.0->ipympl) (1.0.0)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/belen/opt/anaconda3/lib/python3.8/site-packages (from matplotlib<4,>=3.4.0->ipympl) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in /Users/belen/opt/anaconda3/lib/python3.8/site-packages (from matplotlib<4,>=3.4.0->ipympl) (0.10.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/belen/opt/anaconda3/lib/python3.8/site-packages (from matplotlib<4,>=3.4.0->ipympl) (4.53.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/belen/opt/anaconda3/lib/python3.8/site-packages (from matplotlib<4,>=3.4.0->ipympl) (1.3.1)
# Requirement already satisfied: packaging>=20.0 in /Users/belen/opt/anaconda3/lib/python3.8/site-packages (from matplotlib<4,>=3.4.0->ipympl) (20.9)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in /Users/belen/opt/anaconda3/lib/python3.8/site-packages (from matplotlib<4,>=3.4.0->ipympl) (2.4.7)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/belen/opt/anaconda3/lib/python3.8/site-packages (from matplotlib<4,>=3.4.0->ipympl) (2.9.0.post0)
# Requirement already satisfied: importlib-resources>=3.2.0 in /Users/belen/opt/anaconda3/lib/python3.8/site-packages (from matplotlib<4,>=3.4.0->ipympl) (6.4.0)
# Requirement already satisfied: six in /Users/belen/opt/anaconda3/lib/python3.8/site-packages (from cycler>=0.10->matplotlib<4,>=3.4.0->ipympl) (1.15.0)
# Requirement already satisfied: zipp>=3.1.0 in /Users/belen/opt/anaconda3/lib/python3.8/site-packages (from importlib-resources>=3.2.0->matplotlib<4,>=3.4.0->ipympl) (3.4.1)
# Requirement already satisfied: jupyter-client in /Users/belen/opt/anaconda3/lib/python3.8/site-packages (from ipykernel>=4.5.1->ipywidgets<9,>=7.6.0->ipympl) (6.1.12)
# Requirement already satisfied: tornado>=4.2 in /Users/belen/opt/anaconda3/lib/python3.8/site-packages (from ipykernel>=4.5.1->ipywidgets<9,>=7.6.0->ipympl) (6.1)
# Requirement already satisfied: parso<0.8.0,>=0.7.0 in /Users/belen/opt/anaconda3/lib/python3.8/site-packages (from jedi>=0.16->ipython<9->ipympl) (0.7.0)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in /Users/belen/opt/anaconda3/lib/python3.8/site-packages (from nbformat>=4.2.0->ipywidgets<9,>=7.6.0->ipympl) (3.2.0)
# Requirement already satisfied: jupyter-core in /Users/belen/opt/anaconda3/lib/python3.8/site-packages (from nbformat>=4.2.0->ipywidgets<9,>=7.6.0->ipympl) (4.7.1)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/belen/opt/anaconda3/lib/python3.8/site-packages (from pexpect>4.3->ipython<9->ipympl) (0.7.0)
# Requirement already satisfied: wcwidth in /Users/belen/opt/anaconda3/lib/python3.8/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython<9->ipympl) (0.2.5)
# Requirement already satisfied: notebook>=4.4.1 in /Users/belen/opt/anaconda3/lib/python3.8/site-packages (from widgetsnbextension~=3.5.0->ipywidgets<9,>=7.6.0->ipympl) (6.3.0)
# Requirement already satisfied: attrs>=17.4.0 in /Users/belen/opt/anaconda3/lib/python3.8/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets<9,>=7.6.0->ipympl) (20.3.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in /Users/belen/opt/anaconda3/lib/python3.8/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets<9,>=7.6.0->ipympl) (0.17.3)
# Requirement already satisfied: jinja2 in /Users/belen/opt/anaconda3/lib/python3.8/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.6.0->ipympl) (2.11.3)
# Requirement already satisfied: pyzmq>=17 in /Users/belen/opt/anaconda3/lib/python3.8/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.6.0->ipympl) (20.0.0)
# Requirement already satisfied: argon2-cffi in /Users/belen/opt/anaconda3/lib/python3.8/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.6.0->ipympl) (20.1.0)
# Requirement already satisfied: nbconvert in /Users/belen/opt/anaconda3/lib/python3.8/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.6.0->ipympl) (6.0.7)
# Requirement already satisfied: Send2Trash>=1.5.0 in /Users/belen/opt/anaconda3/lib/python3.8/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.6.0->ipympl) (1.5.0)
# Requirement already satisfied: terminado>=0.8.3 in /Users/belen/opt/anaconda3/lib/python3.8/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.6.0->ipympl) (0.9.4)
# Requirement already satisfied: prometheus-client in /Users/belen/opt/anaconda3/lib/python3.8/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<9,>=7.6.0->ipympl) (0.10.1)
# ERROR: Exception:
# Traceback (most recent call last):
#   File "/Users/belen/opt/anaconda3/lib/python3.8/site-packages/pip/_vendor/pkg_resources/__init__.py", line 2751, in _dep_map
#     return self.__dep_map
#   File "/Users/belen/opt/anaconda3/lib/python3.8/site-packages/pip/_vendor/pkg_resources/__init__.py", line 2863, in __getattr__
#     raise AttributeError(attr)
# AttributeError: _Distribution__dep_map
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/belen/opt/anaconda3/lib/python3.8/site-packages/pip/_internal/cli/base_command.py", line 179, in exc_logging_wrapper
#     status = run_func(*args)
#   File "/Users/belen/opt/anaconda3/lib/python3.8/site-packages/pip/_internal/cli/req_command.py", line 67, in wrapper
#     return func(self, options, args)
#   File "/Users/belen/opt/anaconda3/lib/python3.8/site-packages/pip/_internal/commands/install.py", line 377, in run
#     requirement_set = resolver.resolve(
#   File "/Users/belen/opt/anaconda3/lib/python3.8/site-packages/pip/_internal/resolution/resolvelib/resolver.py", line 95, in resolve
#     result = self._result = resolver.resolve(
#   File "/Users/belen/opt/anaconda3/lib/python3.8/site-packages/pip/_vendor/resolvelib/resolvers.py", line 546, in resolve
#     state = resolution.resolve(requirements, max_rounds=max_rounds)
#   File "/Users/belen/opt/anaconda3/lib/python3.8/site-packages/pip/_vendor/resolvelib/resolvers.py", line 427, in resolve
#     failure_causes = self._attempt_to_pin_criterion(name)
#   File "/Users/belen/opt/anaconda3/lib/python3.8/site-packages/pip/_vendor/resolvelib/resolvers.py", line 239, in _attempt_to_pin_criterion
#     criteria = self._get_updated_criteria(candidate)
#   File "/Users/belen/opt/anaconda3/lib/python3.8/site-packages/pip/_vendor/resolvelib/resolvers.py", line 229, in _get_updated_criteria
#     for requirement in self._p.get_dependencies(candidate=candidate):
#   File "/Users/belen/opt/anaconda3/lib/python3.8/site-packages/pip/_internal/resolution/resolvelib/provider.py", line 247, in get_dependencies
#     return [r for r in candidate.iter_dependencies(with_requires) if r is not None]
#   File "/Users/belen/opt/anaconda3/lib/python3.8/site-packages/pip/_internal/resolution/resolvelib/provider.py", line 247, in <listcomp>
#     return [r for r in candidate.iter_dependencies(with_requires) if r is not None]
#   File "/Users/belen/opt/anaconda3/lib/python3.8/site-packages/pip/_internal/resolution/resolvelib/candidates.py", line 401, in iter_dependencies
#     for r in self.dist.iter_dependencies():
#   File "/Users/belen/opt/anaconda3/lib/python3.8/site-packages/pip/_internal/metadata/pkg_resources.py", line 247, in iter_dependencies
#     return self._dist.requires(extras)
#   File "/Users/belen/opt/anaconda3/lib/python3.8/site-packages/pip/_vendor/pkg_resources/__init__.py", line 2786, in requires
#     dm = self._dep_map
#   File "/Users/belen/opt/anaconda3/lib/python3.8/site-packages/pip/_vendor/pkg_resources/__init__.py", line 2753, in _dep_map
#     self.__dep_map = self._filter_extras(self._build_dep_map())
#   File "/Users/belen/opt/anaconda3/lib/python3.8/site-packages/pip/_vendor/pkg_resources/__init__.py", line 2768, in _filter_extras
#     invalid_marker(marker) or not evaluate_marker(marker)
#   File "/Users/belen/opt/anaconda3/lib/python3.8/site-packages/pip/_vendor/pkg_resources/__init__.py", line 1428, in invalid_marker
#     evaluate_marker(text)
#   File "/Users/belen/opt/anaconda3/lib/python3.8/site-packages/pip/_vendor/pkg_resources/__init__.py", line 1446, in evaluate_marker
#     return marker.evaluate()
#   File "/Users/belen/opt/anaconda3/lib/python3.8/site-packages/pip/_vendor/packaging/markers.py", line 325, in evaluate
#     return _evaluate_markers(self._markers, current_environment)
#   File "/Users/belen/opt/anaconda3/lib/python3.8/site-packages/pip/_vendor/packaging/markers.py", line 225, in _evaluate_markers
#     groups[-1].append(_eval_op(lhs_value, op, rhs_value))
#   File "/Users/belen/opt/anaconda3/lib/python3.8/site-packages/pip/_vendor/packaging/markers.py", line 183, in _eval_op
#     return spec.contains(lhs, prereleases=True)
#   File "/Users/belen/opt/anaconda3/lib/python3.8/site-packages/pip/_vendor/packaging/specifiers.py", line 552, in contains
#     normalized_item = _coerce_version(item)
#   File "/Users/belen/opt/anaconda3/lib/python3.8/site-packages/pip/_vendor/packaging/specifiers.py", line 28, in _coerce_version
#     version = Version(version)
#   File "/Users/belen/opt/anaconda3/lib/python3.8/site-packages/pip/_vendor/packaging/version.py", line 202, in __init__
#     raise InvalidVersion(f"Invalid version: '{version}'")
# pip._vendor.packaging.version.InvalidVersion: Invalid version: 'cpython'
# Note: you may need to restart the kernel to use updated packages.

# %%
wavelength_microns = wave/1e3
# Valor de E(B-V) obtenido previamente
E_BV = 0.09645  # Reemplaza esto con el valor correcto

# Crear curvas de extinción usando CCM89 y F99
ext_curve_ccm = CCM89(Rv=3.1)
ext_curve_f99 = F99(Rv=3.1)

# Calcular la extinción en cada longitud de onda
A_lambda_ccm = ext_curve_ccm(wavelength_microns) * E_BV
A_lambda_f99 = ext_curve_f99(wavelength_microns) * E_BV

# Convertir A_lambda a factores de corrección
flux_correction_factor_ccm = 10**(0.4 * A_lambda_ccm)
flux_correction_factor_f99 = 10**(0.4 * A_lambda_f99)

# Corregir el espectro
flux_corrected_ccm = flux * flux_correction_factor_ccm
flux_corrected_f99 = flux * flux_correction_factor_f99

# Guardar los espectros corregidos en nuevos archivos FITS
hdu_ccm = fits.BinTableHDU.from_columns([
    fits.Column(name='wavelength', format='E', array=wavelength_microns),
    fits.Column(name='flux', format='E', array=flux_corrected_ccm)
])
hdu_ccm.writeto('espectro_corregido_ccm.fits', overwrite=True)

hdu_f99 = fits.BinTableHDU.from_columns([
    fits.Column(name='wavelength', format='E', array=wavelength_microns),
    fits.Column(name='flux', format='E', array=flux_corrected_f99)
])
hdu_f99.writeto('espectro_corregido_f99.fits', overwrite=True)

# Verificar visualmente la corrección


plt.figure()
plt.plot(wavelength_microns, flux, label='Original')
plt.plot(wavelength_microns, flux_corrected_ccm, label='Corregido CCM89')
plt.plot(wavelength_microns, flux_corrected_f99, label='Corregido Fitzpatrick99')
plt.xlabel('Longitud de onda (Angstrom)')
plt.ylabel('Flujo')
plt.legend()
plt.show()
