# %%
import numpy as np
from astropy.io import fits
import lime 
import matplotlib.pyplot as plt

# %%
hdul4 = fits.open('../../../../reduccion/NGC1313/cal2_pcULS/espectros/slit4_1D_f99.fits', mode='update')
header4 = hdul4[0].header
#header['BUNIT'] = '1e-15 erg / (Angstrom s cm2)'
header4['FLUXSCAL'] = 1
header4
    
hdul4.flush()

# %%
print(header4)
# Out:
# SIMPLE  =                    T / Fits standard                                  BITPIX  =                  -32 / Bits per pixel                                 NAXIS   =                    1 / Number of axes                                 NAXIS1  =                 2245 / Axis length                                    EXTEND  =                    F / File may contain extensions                    ORIGIN  = 'NOAO-IRAF FITS Image Kernel July 2003' / FITS file originator        OBJECT  = 'NGC1313-FIELD2 MASK02_median_avsig' / Name of the object observed    DATE    = '2024-10-30T12:34:44' / Date FITS file was generated                  IRAF-TLM= '2024-10-30T12:34:44' / Time of last modification                     FIXPIX  = 'Sep 24 17:25 Bad pixel file is tmpbpm899t.pl'                        CTYPE1  = 'LINEAR  '           / R.A. in tangent plane projection               CRPIX1  =                   1. / Ref pix of axis 1                              CRVAL1  =     4024.07153320312 / RA at Ref pix in decimal degrees               CD1_1   =      1.4960515499115 / WCS matrix element 1 1                         CCDSUM  = '2 2     '           / CCD sum                                        GAIN    =      1.3333333333333 / Amplifier gain                                 GAINMULT=                1.933 / Gain multiplication                            RDNOISE =       4.895930282728 / Readout noise                                  RADECSYS= 'FK5     '           / R.A./DEC. coordinate system reference          EQUINOX =                2000. / Equinox of coordinate system                   MJD-OBS =     58792.3237116093 / MJD of start of obseration                     WCSDIM  =                    1 /                                                LTM1_1  =                   1.                                                  WAT0_001= 'system=equispec'    /                                                WAT1_001= 'wtype=linear label=Wavelength units=angstroms' /                     MDFROW  =                    4 / Corresponding row in MDF                       DETSEC  = '[1:4360,1297:1468]' / Detector section(s)                            DATASEC = '[1:2180,1:86]'      / Data section(s)                                REFPIX1 =                1374. / Pixel of central wavelength                    DCLOG1  = 'Transform'                                                           DC-FLAG =                    0                                                  WAVTRAN = 'cmgsS20191105S0286_004' / Name of wavelength transformation          EXPTIME =                1079. /                                                IMCMB001= 'tcmxfrqgsS20191105S0284.fits[SCI,1]'                                 IMCMB002= 'tcmxfrqgsS20191105S0289.fits[SCI,1]'                                 NCOMBINE=                    2                                                  GAINORIG=                   1. / Input gain                                     RONORIG =                 4.24 / Input read-noise                               BANDID1 = 'spectrum - background median, weights variance, clean no'            BANDID2 = 'raw - background median, weights none, clean no'                     BANDID3 = 'background - background median'                                      BANDID4 = 'sigma - background median, weights variance, clean no'               APNUM1  = '1 1 38.22 61.17'                                                     AIRMASS =                1.393 / Mean airmass for the observation               EX-FLAG =                    0                                                  CA-FLAG =                    0                                                  BUNIT   = 'erg/cm2/s/A'                                                         FLUXSCAL=                    1                                                  CDELT1  =      1.4960515499115                                                                                                                                   ...

# %%
def import_1313_fits(file_address, ext=0):
    
    #open the fits file
    with fits.open(file_address) as hdul:
        data, header = hdul[ext].data, hdul[ext].header
        
    #reconstruct the wavelength array from the header data
    w_min, dw, n_pix = header["CRVAL1"], header["CD1_1"], header["NAXIS1"]
    w_max = w_min + dw * n_pix
    wavelength = np.linspace(w_min, w_max, n_pix, endpoint=False)
    
    return wavelength, data, header

# %%
#now we specify the location and load the data
#address of NGC1313 spectrum (in this case, here)
fits_file4 = '../../../../reduccion/NGC1313/cal2_pcULS/espectros/slit4_1D_f99.fits'

#load the data
wave4, flux4, hdr4 = import_1313_fits(fits_file4)

# %%
# Galaxy redshift and the flux normalization
z_obj = 0.001568
normFlux = 1

# %%
spec4 = lime.Spectrum(wave4, flux4, redshift=z_obj, norm_flux=normFlux, units_flux='1e-15 * FLAM')

# %%
spec4.plot.spectrum(label='NGC1313')

# %%
spec4.fit.bands(6563)
spec4.plot.bands()

# %%
# Line name and its location mask in the rest _frame
line4 = 'H1_6563A'
band_edges4 = np.array([6438.03, 6508.66, 6535.10, 6600.95, 6627.70, 6661.82])

# %%
# Run the fitting and plot it
spec4.fit.bands(line4, band_edges4)
spec4.plot.bands()

# %%
# Fit configuration
line4 = 'H1_6563A_b'
fit_conf4 = {'H1_6563A_b': 'H1_6563A+N2_6584A+N2_6548A',
            'N2_6548A_amp': {'expr': 'N2_6584A_amp/2.94'},
            'N2_6548A_kinem': 'N2_6584A'}

# %%
# New attempt including the fit configuration
spec4.fit.bands(line4, band_edges4, fit_conf=fit_conf4)
spec4.plot.bands()

# %%
spec4.fit.bands(4861)
spec4.plot.bands()

# %%
spec4.fit.frame
# Out:
# <bound method SpecTreatment.frame of <lime.workflow.SpecTreatment object at 0x135550530>>

# %%
spec4.plot.grid()

# %%
spec4.save_frame('slit4_Hae_Hb_f99.txt')

# %% [markdown]
# SLIT 8

# %%
hdul8 = fits.open('../../../../reduccion/NGC1313/cal2_pcULS/espectros/slit8_1D_f99.fits', mode='update')
header8 = hdul8[0].header
#header['BUNIT'] = '1e-15 erg / (Angstrom s cm2)'
header8['FLUXSCAL'] = 1
header8
hdul8.flush()

# %%
print(header8)
# Out:
# SIMPLE  =                    T / Fits standard                                  BITPIX  =                  -32 / Bits per pixel                                 NAXIS   =                    1 / Number of axes                                 NAXIS1  =                 2382 / Axis length                                    EXTEND  =                    F / File may contain extensions                    ORIGIN  = 'NOAO-IRAF FITS Image Kernel July 2003' / FITS file originator        OBJECT  = 'NGC1313-FIELD2 MASK02_median_avsig' / Name of the object observed    DATE    = '2024-10-30T12:34:59' / Date FITS file was generated                  IRAF-TLM= '2024-10-30T12:34:59' / Time of last modification                     FIXPIX  = 'Sep 24 17:25 Bad pixel file is tmpbpm899t.pl'                        CTYPE1  = 'LINEAR  '           / R.A. in tangent plane projection               CRPIX1  =                   1. / Ref pix of axis 1                              CRVAL1  =     4028.45336914063 / RA at Ref pix in decimal degrees               CD1_1   =     1.49394512176514 / WCS matrix element 1 1                         CCDSUM  = '2 2     '           / CCD sum                                        GAIN    =      1.3333333333333 / Amplifier gain                                 GAINMULT=                1.933 / Gain multiplication                            RDNOISE =       4.895930282728 / Readout noise                                  RADECSYS= 'FK5     '           / R.A./DEC. coordinate system reference          EQUINOX =                2000. / Equinox of coordinate system                   MJD-OBS =     58792.3237116093 / MJD of start of obseration                     WCSDIM  =                    1 /                                                LTM1_1  =                   1.                                                  WAT0_001= 'system=equispec'    /                                                WAT1_001= 'wtype=linear label=Wavelength units=angstroms' /                     MDFROW  =                    8 / Corresponding row in MDF                       DETSEC  = '[1:4634,1021:1134]' / Detector section(s)                            DATASEC = '[1:2317,1:57]'      / Data section(s)                                REFPIX1 =                1511. / Pixel of central wavelength                    DCLOG1  = 'Transform'                                                           DC-FLAG =                    0                                                  WAVTRAN = 'cmgsS20191105S0286_008' / Name of wavelength transformation          EXPTIME =                1079. /                                                IMCMB001= 'tcmxfrqgsS20191105S0284.fits[SCI,5]'                                 IMCMB002= 'tcmxfrqgsS20191105S0289.fits[SCI,5]'                                 NCOMBINE=                    2                                                  GAINORIG=                   1. / Input gain                                     RONORIG =                 4.24 / Input read-noise                               BANDID1 = 'spectrum - background median, weights variance, clean no'            BANDID2 = 'raw - background median, weights none, clean no'                     BANDID3 = 'background - background median'                                      BANDID4 = 'sigma - background median, weights variance, clean no'               APNUM1  = '1 1 25.97 39.89'                                                     AIRMASS =                1.393 / Mean airmass for the observation               EX-FLAG =                    0                                                  CA-FLAG =                    0                                                  BUNIT   = 'erg/cm2/s/A'                                                         FLUXSCAL=                    1                                                  CDELT1  =     1.49394512176514                                                                                                                                   ...

# %%
#now we specify the location and load the data
#address of NGC1313 spectrum (in this case, here)
fits_file8 = '../../../../reduccion/NGC1313/cal2_pcULS/espectros/slit8_1D_f99.fits'

#load the data
wave8, flux8, hdr8 = import_1313_fits(fits_file8)

# %%
spec8 = lime.Spectrum(wave8, flux8, redshift=z_obj, norm_flux=normFlux, units_flux='1e-15 * FLAM')

# %%
spec8.plot.spectrum(label='NGC1313')

# %%
spec8.fit.bands(6563)
spec8.plot.bands()

# %%
# Line name and its location mask in the rest _frame
line8 = 'H1_6563A'
band_edges8 = np.array([6438.03, 6508.66, 6535.10, 6600.95, 6627.70, 6661.82])

# %%
# Run the fitting and plot it
spec8.fit.bands(line8, band_edges8)
spec8.plot.bands()

# %%
# Fit configuration
line8 = 'H1_6563A_b'
fit_conf8 = {'H1_6563A_b': 'H1_6563A+N2_6584A+N2_6548A',
            'N2_6548A_amp': {'expr': 'N2_6584A_amp/2.94'},
            'N2_6548A_kinem': 'N2_6584A'}

# %%
# New attempt including the fit configuration
spec8.fit.bands(line8, band_edges8, fit_conf=fit_conf8)
spec8.plot.bands()

# %%
spec8.fit.bands(4861)
spec8.plot.bands()

# %%
spec8.fit.frame
# Out:
# <bound method SpecTreatment.frame of <lime.workflow.SpecTreatment object at 0x138456cf0>>

# %%
spec8.plot.grid()

# %%
spec8.save_frame('slit8_Hae_Hb_f99.txt')

# %% [markdown]
# SLIT 12

# %%
hdul12 = fits.open('../../../../reduccion/NGC1313/cal2_pcULS/espectros/slit12_1D_f99.fits', mode='update')
header12 = hdul12[0].header
#header['BUNIT'] = '1e-15 erg / (Angstrom s cm2)'
header12['FLUXSCAL'] = 1
header12
hdul12.flush()

# %%
print(header12)
# Out:
# SIMPLE  =                    T / Fits standard                                  BITPIX  =                  -32 / Bits per pixel                                 NAXIS   =                    1 / Number of axes                                 NAXIS1  =                 2440 / Axis length                                    EXTEND  =                    F / File may contain extensions                    ORIGIN  = 'NOAO-IRAF FITS Image Kernel July 2003' / FITS file originator        OBJECT  = 'NGC1313-FIELD2 MASK02_median_avsig' / Name of the object observed    DATE    = '2024-10-30T12:35:06' / Date FITS file was generated                  IRAF-TLM= '2024-10-30T12:35:06' / Time of last modification                     FIXPIX  = 'Sep 24 17:25 Bad pixel file is tmpbpm899t.pl'                        CTYPE1  = 'LINEAR  '           / R.A. in tangent plane projection               CRPIX1  =                   1. / Ref pix of axis 1                              CRVAL1  =     4031.98266601562 / RA at Ref pix in decimal degrees               CD1_1   =      1.4934766292572 / WCS matrix element 1 1                         CCDSUM  = '2 2     '           / CCD sum                                        GAIN    =      1.3333333333333 / Amplifier gain                                 GAINMULT=                1.933 / Gain multiplication                            RDNOISE =       4.895930282728 / Readout noise                                  RADECSYS= 'FK5     '           / R.A./DEC. coordinate system reference          EQUINOX =                2000. / Equinox of coordinate system                   MJD-OBS =     58792.3237116093 / MJD of start of obseration                     WCSDIM  =                    1 /                                                LTM1_1  =                   1.                                                  WAT0_001= 'system=equispec'    /                                                WAT1_001= 'wtype=linear label=Wavelength units=angstroms' /                     MDFROW  =                   12 / Corresponding row in MDF                       DETSEC  = '[1:4750,545:820]'   / Detector section(s)                            DATASEC = '[1:2375,1:138]'     / Data section(s)                                REFPIX1 =                1569. / Pixel of central wavelength                    DCLOG1  = 'Transform'                                                           DC-FLAG =                    0                                                  WAVTRAN = 'cmgsS20191105S0286_012' / Name of wavelength transformation          EXPTIME =                1079. /                                                IMCMB001= 'tcmxfrqgsS20191105S0284.fits[SCI,9]'                                 IMCMB002= 'tcmxfrqgsS20191105S0289.fits[SCI,9]'                                 NCOMBINE=                    2                                                  GAINORIG=                   1. / Input gain                                     RONORIG =                 4.24 / Input read-noise                               BANDID1 = 'spectrum - background median, weights variance, clean no'            BANDID2 = 'raw - background median, weights none, clean no'                     BANDID3 = 'background - background median'                                      BANDID4 = 'sigma - background median, weights variance, clean no'               APNUM1  = '1 1 73.62 98.90'                                                     AIRMASS =                1.393 / Mean airmass for the observation               EX-FLAG =                    0                                                  CA-FLAG =                    0                                                  BUNIT   = 'erg/cm2/s/A'                                                         FLUXSCAL=                    1                                                  CDELT1  =      1.4934766292572                                                                                                                                   ...

# %%
#now we specify the location and load the data
#address of NGC1313 spectrum (in this case, here)
fits_file12 = '../../../../reduccion/NGC1313/cal2_pcULS/espectros/slit12_1D_f99.fits'

#load the data
wave12, flux12, hdr12 = import_1313_fits(fits_file12)

# %%
spec12 = lime.Spectrum(wave12, flux12, redshift=z_obj, norm_flux=normFlux, units_flux='1e-15 * FLAM')

# %%
spec12.plot.spectrum(label='NGC1313')

# %%
spec12.fit.bands(6563)
spec12.plot.bands()

# %%
# Line name and its location mask in the rest _frame
line12 = 'H1_6563A'
band_edges12 = np.array([6438.03, 6508.66, 6535.10, 6600.95, 6627.70, 6661.82])

# %%
# Run the fitting and plot it
spec12.fit.bands(line12, band_edges12)
spec12.plot.bands()

# %%
# Fit configuration
line12 = 'H1_6563A_b'
fit_conf12 = {'H1_6563A_b': 'H1_6563A+N2_6584A+N2_6548A',
            'N2_6548A_amp': {'expr': 'N2_6584A_amp/2.94'},
            'N2_6548A_kinem': 'N2_6584A'}

# %%
# New attempt including the fit configuration
spec12.fit.bands(line12, band_edges12, fit_conf=fit_conf12)
spec12.plot.bands()

# %%
spec12.fit.bands(4861)
spec12.plot.bands()

# %%
spec12.fit.frame
# Out:
# <bound method SpecTreatment.frame of <lime.workflow.SpecTreatment object at 0x13a323800>>

# %%
spec12.plot.grid()

# %%
spec12.save_frame('slit12_Hae_Hb_f99.txt')

# %% [markdown]
# SLIT 14

# %%
hdul14 = fits.open('../../../../reduccion/NGC1313/cal2_pcULS/espectros/slit14_1D_f99.fits', mode='update')
header14 = hdul14[0].header
#header['BUNIT'] = '1e-15 erg / (Angstrom s cm2)'
header14['FLUXSCAL'] = 1
header14
hdul14.flush()

# %%
print(header14)
# Out:
# SIMPLE  =                    T / Fits standard                                  BITPIX  =                  -32 / Bits per pixel                                 NAXIS   =                    1 / Number of axes                                 NAXIS1  =                 2809 / Axis length                                    EXTEND  =                    F / File may contain extensions                    ORIGIN  = 'NOAO-IRAF FITS Image Kernel July 2003' / FITS file originator        OBJECT  = 'NGC1313-FIELD2 MASK02_median_avsig' / Name of the object observed    DATE    = '2024-10-30T12:35:12' / Date FITS file was generated                  IRAF-TLM= '2024-10-30T12:35:12' / Time of last modification                     FIXPIX  = 'Sep 24 17:25 Bad pixel file is tmpbpm899t.pl'                        CTYPE1  = 'LINEAR  '           / R.A. in tangent plane projection               CRPIX1  =                   1. / Ref pix of axis 1                              CRVAL1  =     4036.02270507813 / RA at Ref pix in decimal degrees               CD1_1   =     1.48656523227692 / WCS matrix element 1 1                         CCDSUM  = '2 2     '           / CCD sum                                        GAIN    =      1.3333333333333 / Amplifier gain                                 GAINMULT=                1.933 / Gain multiplication                            RDNOISE =       4.895930282728 / Readout noise                                  RADECSYS= 'FK5     '           / R.A./DEC. coordinate system reference          EQUINOX =                2000. / Equinox of coordinate system                   MJD-OBS =     58792.3237116093 / MJD of start of obseration                     WCSDIM  =                    1 /                                                LTM1_1  =                   1.                                                  WAT0_001= 'system=equispec'    /                                                WAT1_001= 'wtype=linear label=Wavelength units=angstroms' /                     MDFROW  =                   14 / Corresponding row in MDF                       DETSEC  = '[1:5490,2863:2992]' / Detector section(s)                            DATASEC = '[1:2745,1:65]'      / Data section(s)                                REFPIX1 =                1939. / Pixel of central wavelength                    DCLOG1  = 'Transform'                                                           DC-FLAG =                    0                                                  WAVTRAN = 'cmgsS20191105S0286_014' / Name of wavelength transformation          EXPTIME =                1079. /                                                IMCMB001= 'tcmxfrqgsS20191105S0284.fits[SCI,11]'                                IMCMB002= 'tcmxfrqgsS20191105S0289.fits[SCI,11]'                                NCOMBINE=                    2                                                  GAINORIG=                   1. / Input gain                                     RONORIG =                 4.24 / Input read-noise                               BANDID1 = 'spectrum - background median, weights variance, clean no'            BANDID2 = 'raw - background median, weights none, clean no'                     BANDID3 = 'background - background median'                                      BANDID4 = 'sigma - background median, weights variance, clean no'               APNUM1  = '1 1 5.92 20.98'                                                      AIRMASS =                1.393 / Mean airmass for the observation               EX-FLAG =                    0                                                  CA-FLAG =                    0                                                  BUNIT   = 'erg/cm2/s/A'                                                         FLUXSCAL=                    1                                                  CDELT1  =     1.48656523227692                                                                                                                                   ...

# %%
#now we specify the location and load the data
#address of NGC1313 spectrum (in this case, here)
fits_file14 = '../../../../reduccion/NGC1313/cal2_pcULS/espectros/slit14_1D_f99.fits'

#load the data
wave14, flux14, hdr14 = import_1313_fits(fits_file14)

# %%
spec14 = lime.Spectrum(wave14, flux14, redshift=z_obj, norm_flux=normFlux, units_flux='1e-15 * FLAM')

# %%
spec14.plot.spectrum(label='NGC1313')

# %%
spec14.fit.bands(6563)
spec14.plot.bands()

# %%
# Line name and its location mask in the rest _frame
line14 = 'H1_6563A'
band_edges14 = np.array([6438.03, 6508.66, 6535.10, 6594, 6627.70, 6661.82])

# %%
# Run the fitting and plot it
spec14.fit.bands(line14, band_edges14)
spec14.plot.bands()

# %%
# Fit configuration
line14 = 'H1_6563A_b'
fit_conf14 = {'H1_6563A_b': 'H1_6563A+N2_6584A+N2_6548A',
            'N2_6548A_amp': {'expr': 'N2_6584A_amp/2.94'},
            'N2_6548A_kinem': 'N2_6584A'}

# %%
# New attempt including the fit configuration
spec14.fit.bands(line14, band_edges14, fit_conf=fit_conf14)
spec14.plot.bands()

# %%
spec14.fit.bands(4861)
spec14.plot.bands()

# %%
spec14.fit.frame
# Out:
# <bound method SpecTreatment.frame of <lime.workflow.SpecTreatment object at 0x13a641a90>>

# %%
spec14.plot.grid()

# %%
spec14.save_frame('slit14_Hae_Hb_f99.txt')

# %% [markdown]
# SLIT 16

# %%
hdul16 = fits.open('../../../../reduccion/NGC1313/cal2_pcULS/espectros/slit16_1D_f99.fits', mode='update')
header16 = hdul16[0].header
#header['BUNIT'] = '1e-15 erg / (Angstrom s cm2)'
header16['FLUXSCAL'] = 1
header16
hdul16.flush()

# %%
print(header16)
# Out:
# SIMPLE  =                    T / Fits standard                                  BITPIX  =                  -32 / Bits per pixel                                 NAXIS   =                    1 / Number of axes                                 NAXIS1  =                 2696 / Axis length                                    EXTEND  =                    F / File may contain extensions                    ORIGIN  = 'NOAO-IRAF FITS Image Kernel July 2003' / FITS file originator        OBJECT  = 'NGC1313-FIELD2 MASK02_median_avsig' / Name of the object observed    DATE    = '2024-10-30T12:35:18' / Date FITS file was generated                  IRAF-TLM= '2024-10-30T12:35:18' / Time of last modification                     FIXPIX  = 'Sep 24 17:25 Bad pixel file is tmpbpm899t.pl'                        CTYPE1  = 'LINEAR  '           / R.A. in tangent plane projection               CRPIX1  =                   1. / Ref pix of axis 1                              CRVAL1  =     4033.59643554687 / RA at Ref pix in decimal degrees               CD1_1   =     1.48876130580902 / WCS matrix element 1 1                         CCDSUM  = '2 2     '           / CCD sum                                        GAIN    =      1.3333333333333 / Amplifier gain                                 GAINMULT=                1.933 / Gain multiplication                            RDNOISE =       4.895930282728 / Readout noise                                  RADECSYS= 'FK5     '           / R.A./DEC. coordinate system reference          EQUINOX =                2000. / Equinox of coordinate system                   MJD-OBS =     58792.3237116093 / MJD of start of obseration                     WCSDIM  =                    1 /                                                LTM1_1  =                   1.                                                  WAT0_001= 'system=equispec'    /                                                WAT1_001= 'wtype=linear label=Wavelength units=angstroms' /                     MDFROW  =                   16 / Corresponding row in MDF                       DETSEC  = '[1:5262,2791:2856]' / Detector section(s)                            DATASEC = '[1:2631,1:33]'      / Data section(s)                                REFPIX1 =                1825. / Pixel of central wavelength                    DCLOG1  = 'Transform'                                                           DC-FLAG =                    0                                                  WAVTRAN = 'cmgsS20191105S0286_016' / Name of wavelength transformation          EXPTIME =                1079. /                                                IMCMB001= 'tcmxfrqgsS20191105S0284.fits[SCI,13]'                                IMCMB002= 'tcmxfrqgsS20191105S0289.fits[SCI,13]'                                NCOMBINE=                    2                                                  GAINORIG=                   1. / Input gain                                     RONORIG =                 4.24 / Input read-noise                               BANDID1 = 'spectrum - background median, weights variance, clean no'            BANDID2 = 'raw - background median, weights none, clean no'                     BANDID3 = 'background - background median'                                      BANDID4 = 'sigma - background median, weights variance, clean no'               APNUM1  = '1 1 12.96 24.98'                                                     AIRMASS =                1.393 / Mean airmass for the observation               EX-FLAG =                    0                                                  CA-FLAG =                    0                                                  BUNIT   = 'erg/cm2/s/A'                                                         FLUXSCAL=                    1                                                  CDELT1  =     1.48876130580902                                                                                                                                   ...

# %%
#now we specify the location and load the data
#address of NGC1313 spectrum (in this case, here)
fits_file16 = '../../../../reduccion/NGC1313/cal2_pcULS/espectros/slit16_1D_f99.fits'

#load the data
wave16, flux16, hdr16 = import_1313_fits(fits_file16)

# %%
spec16 = lime.Spectrum(wave16, flux16, redshift=z_obj, norm_flux=normFlux, units_flux='1e-15 * FLAM')

# %%
spec16.plot.spectrum(label='NGC1313')

# %%
spec16.fit.bands(6563)
spec16.plot.bands()

# %%
# Line name and its location mask in the rest _frame
line16 = 'H1_6563A'
band_edges16 = np.array([6438.03, 6508.66, 6535.10, 6600.95, 6627.70, 6661.82])

# %%
# Run the fitting and plot it
spec16.fit.bands(line16, band_edges16)
spec16.plot.bands()

# %%
# Fit configuration
line16 = 'H1_6563A_b'
fit_conf16 = {'H1_6563A_b': 'H1_6563A+N2_6584A+N2_6548A',
            'N2_6548A_amp': {'expr': 'N2_6584A_amp/2.94'},
            'N2_6548A_kinem': 'N2_6584A'}

# %%
# New attempt including the fit configuration
spec16.fit.bands(line16, band_edges16, fit_conf=fit_conf16)
spec16.plot.bands()

# %%
spec16.fit.bands(4861)
spec16.plot.bands()

# %%
spec16.fit.frame
# Out:
# <bound method SpecTreatment.frame of <lime.workflow.SpecTreatment object at 0x13cf5eea0>>

# %%
spec16.plot.grid()

# %%
spec16.save_frame('slit16_Hae_Hb_f99.txt')

# %% [markdown]
# SLIT 21

# %%
hdul21 = fits.open('../../../../reduccion/NGC1313/cal2_pcULS/espectros/slit21_1D_f99.fits', mode='update')
header21 = hdul21[0].header
#header['BUNIT'] = '1e-15 erg / (Angstrom s cm2)'
header21['FLUXSCAL'] = 1
header21
hdul21.flush()

# %%
print(header21)
# Out:
# SIMPLE  =                    T / Fits standard                                  BITPIX  =                  -32 / Bits per pixel                                 NAXIS   =                    1 / Number of axes                                 NAXIS1  =                 2829 / Axis length                                    EXTEND  =                    F / File may contain extensions                    ORIGIN  = 'NOAO-IRAF FITS Image Kernel July 2003' / FITS file originator        OBJECT  = 'NGC1313-FIELD2 MASK02_median_avsig' / Name of the object observed    DATE    = '2024-10-30T12:35:41' / Date FITS file was generated                  IRAF-TLM= '2024-10-30T12:35:41' / Time of last modification                     FIXPIX  = 'Sep 24 17:25 Bad pixel file is tmpbpm899t.pl'                        CTYPE1  = 'LINEAR  '           / R.A. in tangent plane projection               CRPIX1  =                   1. / Ref pix of axis 1                              CRVAL1  =      4036.4033203125 / RA at Ref pix in decimal degrees               CD1_1   =     1.48660230636597 / WCS matrix element 1 1                         CCDSUM  = '2 2     '           / CCD sum                                        GAIN    =      1.3333333333333 / Amplifier gain                                 GAINMULT=                1.933 / Gain multiplication                            RDNOISE =       4.895930282728 / Readout noise                                  RADECSYS= 'FK5     '           / R.A./DEC. coordinate system reference          EQUINOX =                2000. / Equinox of coordinate system                   MJD-OBS =     58792.3237116093 / MJD of start of obseration                     WCSDIM  =                    1 /                                                LTM1_1  =                   1.                                                  WAT0_001= 'system=equispec'    /                                                WAT1_001= 'wtype=linear label=Wavelength units=angstroms' /                     MDFROW  =                   21 / Corresponding row in MDF                       DETSEC  = '[1:5530,2519:2650]' / Detector section(s)                            DATASEC = '[1:2765,1:66]'      / Data section(s)                                REFPIX1 =                1959. / Pixel of central wavelength                    DCLOG1  = 'Transform'                                                           DC-FLAG =                    0                                                  WAVTRAN = 'cmgsS20191105S0286_021' / Name of wavelength transformation          EXPTIME =                1079. /                                                IMCMB001= 'tcmxfrqgsS20191105S0284.fits[SCI,18]'                                IMCMB002= 'tcmxfrqgsS20191105S0289.fits[SCI,18]'                                NCOMBINE=                    2                                                  GAINORIG=                   1. / Input gain                                     RONORIG =                 4.24 / Input read-noise                               BANDID1 = 'spectrum - background median, weights variance, clean no'            BANDID2 = 'raw - background median, weights none, clean no'                     BANDID3 = 'background - background median'                                      BANDID4 = 'sigma - background median, weights variance, clean no'               APNUM1  = '1 1 16.25 39.89'                                                     AIRMASS =                1.393 / Mean airmass for the observation               EX-FLAG =                    0                                                  CA-FLAG =                    0                                                  BUNIT   = 'erg/cm2/s/A'                                                         FLUXSCAL=                    1                                                  CDELT1  =     1.48660230636597                                                                                                                                   ...

# %%
#now we specify the location and load the data
#address of NGC1313 spectrum (in this case, here)
fits_file21 = '../../../../reduccion/NGC1313/cal2_pcULS/espectros/slit21_1D_f99.fits'

#load the data
wave21, flux21, hdr21 = import_1313_fits(fits_file21)

# %%
spec21 = lime.Spectrum(wave21, flux21, redshift=z_obj, norm_flux=normFlux, units_flux='1e-15 * FLAM')

# %%
spec21.plot.spectrum(label='NGC1313')

# %%
spec21.fit.bands(6563)
spec21.plot.bands()

# %%
# Line name and its location mask in the rest _frame
line21 = 'H1_6563A'
band_edges21 = np.array([6438.03, 6508.66, 6535.10, 6600.95, 6629, 6661.82])

# %%
# Run the fitting and plot it
spec21.fit.bands(line21, band_edges21)
spec21.plot.bands()

# %%
# Fit configuration
line21 = 'H1_6563A_b'
fit_conf21 = {'H1_6563A_b': 'H1_6563A+N2_6584A+N2_6548A',
            'N2_6548A_amp': {'expr': 'N2_6584A_amp/2.94'},
            'N2_6548A_kinem': 'N2_6584A'}

# %%
# New attempt including the fit configuration
spec21.fit.bands(line21, band_edges21, fit_conf=fit_conf21)
spec21.plot.bands()

# %%
spec21.fit.bands(4861)
spec21.plot.bands()

# %%
spec21.fit.frame
# Out:
# <bound method SpecTreatment.frame of <lime.workflow.SpecTreatment object at 0x13e9e5dc0>>

# %%
spec21.plot.grid()

# %%
spec21.save_frame('slit21_mask2_Hae_Hb_f99.txt')

# %% [markdown]
# SLIT 23

# %%
hdul23 = fits.open('../../../../reduccion/NGC1313/cal2_pcULS/espectros/slit23_1D_f99.fits', mode='update')
header23 = hdul23[0].header
#header['BUNIT'] = '1e-15 erg / (Angstrom s cm2)'
header23['FLUXSCAL'] = 1
header23
hdul23.flush()

# %%
print(header23)
# Out:
# SIMPLE  =                    T / Fits standard                                  BITPIX  =                  -32 / Bits per pixel                                 NAXIS   =                    1 / Number of axes                                 NAXIS1  =                 3184 / Axis length                                    EXTEND  =                    F / File may contain extensions                    ORIGIN  = 'NOAO-IRAF FITS Image Kernel July 2003' / FITS file originator        OBJECT  = 'NGC1313-FIELD2 MASK02_median_avsig' / Name of the object observed    DATE    = '2024-10-30T12:35:50' / Date FITS file was generated                  IRAF-TLM= '2024-10-30T12:35:50' / Time of last modification                     FIXPIX  = 'Sep 24 17:25 Bad pixel file is tmpbpm899t.pl'                        CTYPE1  = 'LINEAR  '           / R.A. in tangent plane projection               CRPIX1  =                   1. / Ref pix of axis 1                              CRVAL1  =     4040.19873046875 / RA at Ref pix in decimal degrees               CD1_1   =     1.48027443885803 / WCS matrix element 1 1                         CCDSUM  = '2 2     '           / CCD sum                                        GAIN    =      1.3333333333333 / Amplifier gain                                 GAINMULT=                1.933 / Gain multiplication                            RDNOISE =       4.895930282728 / Readout noise                                  RADECSYS= 'FK5     '           / R.A./DEC. coordinate system reference          EQUINOX =                2000. / Equinox of coordinate system                   MJD-OBS =     58792.3237116093 / MJD of start of obseration                     WCSDIM  =                    1 /                                                LTM1_1  =                   1.                                                  WAT0_001= 'system=equispec'    /                                                WAT1_001= 'wtype=linear label=Wavelength units=angstroms' /                     MDFROW  =                   23 / Corresponding row in MDF                       DETSEC  = '[1:6240,2001:2312]' / Detector section(s)                            DATASEC = '[1:3120,1:156]'     / Data section(s)                                REFPIX1 =                2314. / Pixel of central wavelength                    DCLOG1  = 'Transform'                                                           DC-FLAG =                    0                                                  WAVTRAN = 'cmgsS20191105S0286_023' / Name of wavelength transformation          EXPTIME =                1079. /                                                IMCMB001= 'tcmxfrqgsS20191105S0284.fits[SCI,20]'                                IMCMB002= 'tcmxfrqgsS20191105S0289.fits[SCI,20]'                                NCOMBINE=                    2                                                  GAINORIG=                   1. / Input gain                                     RONORIG =                 4.24 / Input read-noise                               BANDID1 = 'spectrum - background median, weights variance, clean no'            BANDID2 = 'raw - background median, weights none, clean no'                     BANDID3 = 'background - background median'                                      BANDID4 = 'sigma - background median, weights variance, clean no'               APNUM1  = '1 1 76.53 108.44'                                                    AIRMASS =                1.393 / Mean airmass for the observation               EX-FLAG =                    0                                                  CA-FLAG =                    0                                                  BUNIT   = 'erg/cm2/s/A'                                                         FLUXSCAL=                    1                                                  CDELT1  =     1.48027443885803                                                                                                                                   ...

# %%
#now we specify the location and load the data
#address of NGC1313 spectrum (in this case, here)
fits_file23 = '../../../../reduccion/NGC1313/cal2_pcULS/espectros/slit23_1D_f99.fits'

#load the data
wave23, flux23, hdr23 = import_1313_fits(fits_file23)

# %%
spec23 = lime.Spectrum(wave23, flux23, redshift=z_obj, norm_flux=normFlux, units_flux='1e-15 * FLAM')

# %%
spec23.plot.spectrum(label='NGC1313')

# %%
spec23.fit.bands(6563)
spec23.plot.bands()

# %%
spec23.fit.bands(4861)
spec23.plot.bands()
# Out:
# LiMe WARNING: Line H1_4861A introduced as an emission but the line peak is below the continuum level
# LiMe WARNING: Line H1_4861A introduced as an absorption but the line peak is below the continuum level

# %%
#pendiente terminar slit 23 pke es absorción ,,, cómo des-enrojecer sin razón Ha/Hb ? o cuando tengo Ha emisión y Hb absorción?

# %% [markdown]
# SLIT 25

# %%
hdul25 = fits.open('../../../../reduccion/NGC1313/cal2_pcULS/espectros/slit25_1D_f99.fits', mode='update')
header25 = hdul25[0].header
#header['BUNIT'] = '1e-15 erg / (Angstrom s cm2)'
header25['FLUXSCAL'] = 1
header25
hdul25.flush()

# %%
print(header25)
# Out:
# SIMPLE  =                    T / Fits standard                                  BITPIX  =                  -32 / Bits per pixel                                 NAXIS   =                    1 / Number of axes                                 NAXIS1  =                 2590 / Axis length                                    EXTEND  =                    F / File may contain extensions                    ORIGIN  = 'NOAO-IRAF FITS Image Kernel July 2003' / FITS file originator        OBJECT  = 'NGC1313-FIELD2 MASK02_median_avsig' / Name of the object observed    DATE    = '2024-10-30T12:36:02' / Date FITS file was generated                  IRAF-TLM= '2024-10-30T12:36:02' / Time of last modification                     FIXPIX  = 'Sep 24 17:25 Bad pixel file is tmpbpm899t.pl'                        CTYPE1  = 'LINEAR  '           / R.A. in tangent plane projection               CRPIX1  =                   1. / Ref pix of axis 1                              CRVAL1  =     4030.51049804688 / RA at Ref pix in decimal degrees               CD1_1   =      1.4912029504776 / WCS matrix element 1 1                         CCDSUM  = '2 2     '           / CCD sum                                        GAIN    =      1.3333333333333 / Amplifier gain                                 GAINMULT=                1.933 / Gain multiplication                            RDNOISE =       4.895930282728 / Readout noise                                  RADECSYS= 'FK5     '           / R.A./DEC. coordinate system reference          EQUINOX =                2000. / Equinox of coordinate system                   MJD-OBS =     58792.3237116093 / MJD of start of obseration                     WCSDIM  =                    1 /                                                LTM1_1  =                   1.                                                  WAT0_001= 'system=equispec'    /                                                WAT1_001= 'wtype=linear label=Wavelength units=angstroms' /                     MDFROW  =                   25 / Corresponding row in MDF                       DETSEC  = '[1:5050,1509:1990]' / Detector section(s)                            DATASEC = '[1:2525,1:241]'     / Data section(s)                                REFPIX1 =                1719. / Pixel of central wavelength                    DCLOG1  = 'Transform'                                                           DC-FLAG =                    0                                                  WAVTRAN = 'cmgsS20191105S0286_025' / Name of wavelength transformation          EXPTIME =                1079. /                                                IMCMB001= 'tcmxfrqgsS20191105S0284.fits[SCI,22]'                                IMCMB002= 'tcmxfrqgsS20191105S0289.fits[SCI,22]'                                NCOMBINE=                    2                                                  GAINORIG=                   1. / Input gain                                     RONORIG =                 4.24 / Input read-noise                               BANDID1 = 'spectrum - background median, weights variance, clean no'            BANDID2 = 'raw - background median, weights none, clean no'                     BANDID3 = 'background - background median'                                      BANDID4 = 'sigma - background median, weights variance, clean no'               APNUM1  = '1 1 138.48 167.98'                                                   AIRMASS =                1.393 / Mean airmass for the observation               EX-FLAG =                    0                                                  CA-FLAG =                    0                                                  BUNIT   = 'erg/cm2/s/A'                                                         FLUXSCAL=                    1                                                  CDELT1  =      1.4912029504776                                                                                                                                   ...

# %%
#now we specify the location and load the data
#address of NGC1313 spectrum (in this case, here)
fits_file25 = '../../../../reduccion/NGC1313/cal2_pcULS/espectros/slit25_1D_f99.fits'

#load the data
wave25, flux25, hdr25 = import_1313_fits(fits_file25)

# %%
spec25 = lime.Spectrum(wave25, flux25, redshift=z_obj, norm_flux=normFlux, units_flux='1e-15 * FLAM')

# %%
spec25.plot.spectrum(label='NGC1313')

# %%
spec25.fit.bands(6563)
spec25.plot.bands()

# %%
# Line name and its location mask in the rest _frame
line25 = 'H1_6563A'
band_edges25 = np.array([6438.03, 6508.66, 6535.10, 6600.95, 6627.70, 6661.82])

# %%
# Run the fitting and plot it
spec25.fit.bands(line25, band_edges25)
spec25.plot.bands()

# %%
# Fit configuration
line25 = 'H1_6563A_b'
fit_conf25 = {'H1_6563A_b': 'H1_6563A+N2_6584A+N2_6548A',
            'N2_6548A_amp': {'expr': 'N2_6584A_amp/2.94'},
            'N2_6548A_kinem': 'N2_6584A'}

# %%
# New attempt including the fit configuration
spec25.fit.bands(line25, band_edges25, fit_conf=fit_conf25)
spec25.plot.bands()

# %%
spec25.fit.bands(4861)
spec25.plot.bands()

# %%
# Line name and its location mask in the rest _frame
line25_Hb = 'H1_4861A'
#band_edges = np.array([4809.80, 4836.10, 4848.715437, 4876.181741, 4883.13, 4908.40])
band_edges25_Hb = np.array([4809.80, 4836.10, 4851, 4876.181741, 4883.13, 4908.40])

# %%
# Run the fitting and plot it
spec25.fit.bands(line25_Hb, band_edges25_Hb)
spec25.plot.bands()

# %%
spec25.fit.frame
# Out:
# <bound method SpecTreatment.frame of <lime.workflow.SpecTreatment object at 0x13f9673b0>>

# %%
spec25.plot.grid()

# %%
spec25.save_frame('slit25_Hae_Hbe_f99.txt')

# %% [markdown]
# SLIT 27

# %%
hdul27 = fits.open('../../../../reduccion/NGC1313/cal2_pcULS/espectros/slit27_1D_f99.fits', mode='update')
header27 = hdul27[0].header
#header['BUNIT'] = '1e-15 erg / (Angstrom s cm2)'
header27['FLUXSCAL'] = 1
header27
hdul27.flush()

# %%
print(header27)
# Out:
# SIMPLE  =                    T / Fits standard                                  BITPIX  =                  -32 / Bits per pixel                                 NAXIS   =                    1 / Number of axes                                 NAXIS1  =                 2699 / Axis length                                    EXTEND  =                    F / File may contain extensions                    ORIGIN  = 'NOAO-IRAF FITS Image Kernel July 2003' / FITS file originator        OBJECT  = 'NGC1313-FIELD2 MASK02_median_avsig' / Name of the object observed    DATE    = '2024-10-30T12:36:09' / Date FITS file was generated                  IRAF-TLM= '2024-10-30T12:36:09' / Time of last modification                     FIXPIX  = 'Sep 24 17:25 Bad pixel file is tmpbpm899t.pl'                        CTYPE1  = 'LINEAR  '           / R.A. in tangent plane projection               CRPIX1  =                   1. / Ref pix of axis 1                              CRVAL1  =     4032.66870117188 / RA at Ref pix in decimal degrees               CD1_1   =     1.48867523670197 / WCS matrix element 1 1                         CCDSUM  = '2 2     '           / CCD sum                                        GAIN    =      1.3333333333333 / Amplifier gain                                 GAINMULT=                1.933 / Gain multiplication                            RDNOISE =       4.895930282728 / Readout noise                                  RADECSYS= 'FK5     '           / R.A./DEC. coordinate system reference          EQUINOX =                2000. / Equinox of coordinate system                   MJD-OBS =     58792.3237116093 / MJD of start of obseration                     WCSDIM  =                    1 /                                                LTM1_1  =                   1.                                                  WAT0_001= 'system=equispec'    /                                                WAT1_001= 'wtype=linear label=Wavelength units=angstroms' /                     MDFROW  =                   27 / Corresponding row in MDF                       DETSEC  = '[1:5270,2323:2508]' / Detector section(s)                            DATASEC = '[1:2635,1:93]'      / Data section(s)                                REFPIX1 =                1829. / Pixel of central wavelength                    DCLOG1  = 'Transform'                                                           DC-FLAG =                    0                                                  WAVTRAN = 'cmgsS20191105S0286_027' / Name of wavelength transformation          EXPTIME =                1079. /                                                IMCMB001= 'tcmxfrqgsS20191105S0284.fits[SCI,24]'                                IMCMB002= 'tcmxfrqgsS20191105S0289.fits[SCI,24]'                                NCOMBINE=                    2                                                  GAINORIG=                   1. / Input gain                                     RONORIG =                 4.24 / Input read-noise                               BANDID1 = 'spectrum - background median, weights variance, clean no'            BANDID2 = 'raw - background median, weights none, clean no'                     BANDID3 = 'background - background median'                                      BANDID4 = 'sigma - background median, weights variance, clean no'               APNUM1  = '1 1 61.08 77.93'                                                     AIRMASS =                1.393 / Mean airmass for the observation               EX-FLAG =                    0                                                  CA-FLAG =                    0                                                  BUNIT   = 'erg/cm2/s/A'                                                         FLUXSCAL=                    1                                                  CDELT1  =     1.48867523670197                                                                                                                                   ...

# %%
#now we specify the location and load the data
#address of NGC1313 spectrum (in this case, here)
fits_file27 = '../../../../reduccion/NGC1313/cal2_pcULS/espectros/slit27_1D_f99.fits'

#load the data
wave27, flux27, hdr27 = import_1313_fits(fits_file27)

# %%
spec27 = lime.Spectrum(wave27, flux27, redshift=z_obj, norm_flux=normFlux, units_flux='1e-15 * FLAM')

# %%
spec27.plot.spectrum(label='NGC1313')

# %%
spec27.fit.bands(6563)
spec27.plot.bands()

# %%
# Line name and its location mask in the rest _frame
line27 = 'H1_6563A'
band_edges27 = np.array([6438.03, 6508.66, 6535.10, 6600.95, 6627.70, 6661.82])

# %%
# Run the fitting and plot it
spec27.fit.bands(line27, band_edges27)
spec27.plot.bands()

# %%
# Fit configuration
line27 = 'H1_6563A_b'
fit_conf27 = {'H1_6563A_b': 'H1_6563A+N2_6584A+N2_6548A',
            'N2_6548A_amp': {'expr': 'N2_6584A_amp/2.94'},
            'N2_6548A_kinem': 'N2_6584A'}

# %%
# New attempt including the fit configuration
spec27.fit.bands(line27, band_edges27, fit_conf=fit_conf27)
spec27.plot.bands()

# %%
spec27.fit.bands(4861)
spec27.plot.bands()

# %%
# Line name and its location mask in the rest _frame
line27_Hb = 'H1_4861A'
#band_edges = np.array([4809.80, 4836.10, 4848.715437, 4876.181741, 4883.13, 4908.40])
band_edges27_Hb = np.array([4809.80, 4836.10, 4848.715437, 4870.5, 4883.13, 4908.40])

# %%
# Run the fitting and plot it
spec27.fit.bands(line27_Hb, band_edges27_Hb)
spec27.plot.bands()

# %%
spec27.fit.frame
# Out:
# <bound method SpecTreatment.frame of <lime.workflow.SpecTreatment object at 0x141860dd0>>

# %%
spec27.plot.grid()

# %%
spec27.save_frame('slit27_Hae_Hbe_f99.txt')
