# %%
import numpy as np
from astropy.io import fits
import lime 
import matplotlib.pyplot as plt

# %%
hdul4 = fits.open('../../../../reduccion/NGC1313/cal2_pcULS/espectros/slit4_1D.fits', mode='update')
header4 = hdul4[0].header
#header['BUNIT'] = '1e-15 erg / (Angstrom s cm2)'
header4['FLUXSCAL'] = 1
header4
    
hdul4.flush()

# %%
def import_1313_fits(file_address, ext=0):
    
    #open the fits file
    with fits.open(file_address) as hdul:
        data, header = hdul[ext].data, hdul[ext].header
        
    #reconstruct the wavelength array from the header data
    w_min, dw, n_pix = header["CRVAL1"], header["CD1_1"], header["NAXIS1"]
    w_max = w_min + dw * n_pix
    wavelength = np.linspace(w_min, w_max, n_pix, endpoint=False)
    
    return wavelength, data, header

# %%
#now we specify the location and load the data
#address of NGC1313 spectrum (in this case, here)
fits_file4 = '../../../../reduccion/NGC1313/cal2_pcULS/espectros/slit4_1D.fits'

#load the data
wave4, flux4, hdr4 = import_1313_fits(fits_file4)

# %%
# Galaxy redshift and the flux normalization
z_obj = 0.001568
normFlux = 1

# %%
spec4 = lime.Spectrum(wave4, flux4, redshift=z_obj, norm_flux=normFlux, units_flux='1e-15 * FLAM')

# %%
spec4.plot.spectrum(label='NGC1313')

# %%
# Line name, its location mask in the rest _frame and fit configuration
line4_Ha = 'H1_6563A_b'
band_edges4_Ha = np.array([6438.03, 6508.66, 6535.10, 6600.95, 6627.70, 6661.82])
fit_conf4_Ha = {'H1_6563A_b': 'H1_6563A+N2_6584A+N2_6548A',
            'N2_6548A_amp': {'expr': 'N2_6584A_amp/2.94'},
            'N2_6548A_kinem': 'N2_6584A'}

# %%
# New attempt including the fit configuration
spec4.fit.bands(line4_Ha, band_edges4_Ha, fit_conf=fit_conf4_Ha)
spec4.plot.bands()

# %%
spec4.fit.bands('H1_4861A')
spec4.plot.bands()

# %%
spec4.fit.frame
# Out:
# <bound method SpecTreatment.frame of <lime.workflow.SpecTreatment object at 0x1378d4cb0>>

# %%
spec4.plot.grid()

# %%
spec4.save_frame('slit4_Hae_Hb.txt')

# %%
hdul8 = fits.open('../../../../reduccion/NGC1313/cal2_pcULS/espectros/slit8_1D.fits', mode='update')
header8 = hdul8[0].header
#header['BUNIT'] = '1e-15 erg / (Angstrom s cm2)'
header8['FLUXSCAL'] = 1
header8
    
hdul8.flush()

# %%
#now we specify the location and load the data
#address of NGC1313 spectrum (in this case, here)
fits_file8 = '../../../../reduccion/NGC1313/cal2_pcULS/espectros/slit8_1D.fits'

#load the data
wave8, flux8, hdr8 = import_1313_fits(fits_file8)

# %%
spec8 = lime.Spectrum(wave8, flux8, redshift=z_obj, norm_flux=normFlux, units_flux='1e-15 * FLAM')

# %%
spec8.plot.spectrum(label='NGC1313')

# %%
# Line name, its location mask in the rest _frame and fit configuration
line8_Ha = 'H1_6563A_b'
band_edges8_Ha = np.array([6438.03, 6508.66, 6535.10, 6600.95, 6627.70, 6661.82])
fit_conf8_Ha = {'H1_6563A_b': 'H1_6563A+N2_6584A+N2_6548A',
            'N2_6548A_amp': {'expr': 'N2_6584A_amp/2.94'},
            'N2_6548A_kinem': 'N2_6584A'}

# %%
# New attempt including the fit configuration
spec8.fit.bands(line8_Ha, band_edges8_Ha, fit_conf=fit_conf8_Ha)
spec8.plot.bands()

# %%
spec8.fit.bands('H1_4861A')
spec8.plot.bands()

# %%
spec8.fit.frame
# Out:
# <bound method SpecTreatment.frame of <lime.workflow.SpecTreatment object at 0x1380292b0>>

# %%
spec8.plot.grid()

# %%
spec8.save_frame('slit8_Hae_Hb.txt')

# %%
hdul12 = fits.open('../../../../reduccion/NGC1313/cal2_pcULS/espectros/slit12_1D.fits', mode='update')
header12 = hdul12[0].header
#header['BUNIT'] = '1e-15 erg / (Angstrom s cm2)'
header12['FLUXSCAL'] = 1
header12
    
hdul12.flush()

# %%
#now we specify the location and load the data
#address of NGC1313 spectrum (in this case, here)
fits_file12 = '../../../../reduccion/NGC1313/cal2_pcULS/espectros/slit12_1D.fits'

#load the data
wave12, flux12, hdr12 = import_1313_fits(fits_file12)

# %%
spec12 = lime.Spectrum(wave12, flux12, redshift=z_obj, norm_flux=normFlux, units_flux='1e-15 * FLAM')

# %%
spec12.plot.spectrum(label='NGC1313')

# %%
# Line name, its location mask in the rest _frame and fit configuration
line12_Ha = 'H1_6563A_b'
band_edges12_Ha = np.array([6438.03, 6508.66, 6535.10, 6600.95, 6627.70, 6661.82])
fit_conf12_Ha = {'H1_6563A_b': 'H1_6563A+N2_6584A+N2_6548A',
            'N2_6548A_amp': {'expr': 'N2_6584A_amp/2.94'},
            'N2_6548A_kinem': 'N2_6584A'}

# %%
# New attempt including the fit configuration
spec12.fit.bands(line12_Ha, band_edges12_Ha, fit_conf=fit_conf12_Ha)
spec12.plot.bands()

# %%
spec12.fit.bands('H1_4861A')
spec12.plot.bands()

# %%
spec12.fit.frame
# Out:
# <bound method SpecTreatment.frame of <lime.workflow.SpecTreatment object at 0x139f14920>>

# %%
spec12.plot.grid()

# %%
spec12.save_frame('slit12_Hae_Hb.txt')

# %%
hdul14 = fits.open('../../../../reduccion/NGC1313/cal2_pcULS/espectros/slit14_1D.fits', mode='update')
header14 = hdul14[0].header
#header['BUNIT'] = '1e-15 erg / (Angstrom s cm2)'
header14['FLUXSCAL'] = 1
header14
    
hdul14.flush()

# %%
#now we specify the location and load the data
#address of NGC1313 spectrum (in this case, here)
fits_file14 = '../../../../reduccion/NGC1313/cal2_pcULS/espectros/slit14_1D.fits'

#load the data
wave14, flux14, hdr14 = import_1313_fits(fits_file14)

# %%
spec14 = lime.Spectrum(wave14, flux14, redshift=z_obj, norm_flux=normFlux, units_flux='1e-15 * FLAM')

# %%
spec14.plot.spectrum(label='NGC1313')

# %%
# Line name, its location mask in the rest _frame and fit configuration
line14_Ha = 'H1_6563A_b'
band_edges14_Ha = np.array([6438.03, 6508.66, 6535.10, 6594, 6627.70, 6661.82])
fit_conf14_Ha = {'H1_6563A_b': 'H1_6563A+N2_6584A+N2_6548A',
            'N2_6548A_amp': {'expr': 'N2_6584A_amp/2.94'},
            'N2_6548A_kinem': 'N2_6584A'}

# %%
# New attempt including the fit configuration
spec14.fit.bands(line14_Ha, band_edges14_Ha, fit_conf=fit_conf14_Ha)
spec14.plot.bands()

# %%
spec14.fit.bands('H1_4861A')
spec14.plot.bands()

# %%
spec14.fit.frame
# Out:
# <bound method SpecTreatment.frame of <lime.workflow.SpecTreatment object at 0x139971d90>>

# %%
spec14.plot.grid()

# %%
spec14.save_frame('slit14_Hae_Hb.txt')

# %%
hdul16 = fits.open('../../../../reduccion/NGC1313/cal2_pcULS/espectros/slit16_1D.fits', mode='update')
header16 = hdul16[0].header
#header['BUNIT'] = '1e-15 erg / (Angstrom s cm2)'
header16['FLUXSCAL'] = 1
header16
    
hdul16.flush()

# %%
#now we specify the location and load the data
#address of NGC1313 spectrum (in this case, here)
fits_file16 = '../../../../reduccion/NGC1313/cal2_pcULS/espectros/slit16_1D.fits'

#load the data
wave16, flux16, hdr16 = import_1313_fits(fits_file16)

# %%
spec16 = lime.Spectrum(wave16, flux16, redshift=z_obj, norm_flux=normFlux, units_flux='1e-15 * FLAM')

# %%
spec16.plot.spectrum(label='NGC1313')

# %%
# Line name, its location mask in the rest _frame and fit configuration
line16_Ha = 'H1_6563A_b'
band_edges16_Ha = np.array([6438.03, 6508.66, 6535.10, 6594, 6627.70, 6661.82])
fit_conf16_Ha = {'H1_6563A_b': 'H1_6563A+N2_6584A+N2_6548A',
            'N2_6548A_amp': {'expr': 'N2_6584A_amp/2.94'},
            'N2_6548A_kinem': 'N2_6584A'}

# %%
# New attempt including the fit configuration
spec16.fit.bands(line16_Ha, band_edges16_Ha, fit_conf=fit_conf16_Ha)
spec16.plot.bands()

# %%
spec16.fit.bands('H1_4861A')
spec16.plot.bands()

# %%
spec16.fit.frame
# Out:
# <bound method SpecTreatment.frame of <lime.workflow.SpecTreatment object at 0x139597740>>

# %%
spec16.plot.grid()

# %%
spec16.save_frame('slit16_Hae_Hb.txt')

# %%
hdul21 = fits.open('../../../../reduccion/NGC1313/cal2_pcULS/espectros/slit21_1D.fits', mode='update')
header21 = hdul21[0].header
#header['BUNIT'] = '1e-15 erg / (Angstrom s cm2)'
header21['FLUXSCAL'] = 1
header21
    
hdul21.flush()

# %%
#now we specify the location and load the data
#address of NGC1313 spectrum (in this case, here)
fits_file21 = '../../../../reduccion/NGC1313/cal2_pcULS/espectros/slit21_1D.fits'

#load the data
wave21, flux21, hdr21 = import_1313_fits(fits_file21)

# %%
spec21 = lime.Spectrum(wave21, flux21, redshift=z_obj, norm_flux=normFlux, units_flux='1e-15 * FLAM')

# %%
spec21.plot.spectrum(label='NGC1313')

# %%
# Line name, its location mask in the rest _frame and fit configuration
line21_Ha = 'H1_6563A_b'
band_edges21_Ha = np.array([6438.03, 6508.66, 6535.10, 6594, 6627.70, 6661.82])
fit_conf21_Ha = {'H1_6563A_b': 'H1_6563A+N2_6584A+N2_6548A',
            'N2_6548A_amp': {'expr': 'N2_6584A_amp/2.94'},
            'N2_6548A_kinem': 'N2_6584A'}

# %%
# New attempt including the fit configuration
spec21.fit.bands(line21_Ha, band_edges21_Ha, fit_conf=fit_conf21_Ha)
spec21.plot.bands()

# %%
spec21.fit.bands('H1_4861A')
spec21.plot.bands()

# %%
spec21.fit.frame
# Out:
# <bound method SpecTreatment.frame of <lime.workflow.SpecTreatment object at 0x13b422a20>>

# %%
spec21.plot.grid()

# %%
spec21.save_frame('slit21_Hae_Hb.txt')

# %%
hdul23 = fits.open('../../../../reduccion/NGC1313/cal2_pcULS/espectros/slit23_1D.fits', mode='update')
header23 = hdul23[0].header
#header['BUNIT'] = '1e-15 erg / (Angstrom s cm2)'
header23['FLUXSCAL'] = 1
header23
    
hdul23.flush()

# %%
#now we specify the location and load the data
#address of NGC1313 spectrum (in this case, here)
fits_file23 = '../../../../reduccion/NGC1313/cal2_pcULS/espectros/slit23_1D.fits'

#load the data
wave23, flux23, hdr23 = import_1313_fits(fits_file23)

# %%
spec23 = lime.Spectrum(wave23, flux23, redshift=z_obj, norm_flux=normFlux, units_flux='1e-15 * FLAM')

# %%
spec23.plot.spectrum(label='NGC1313')

# %%
# Line name, its location mask in the rest _frame and fit configuration
line23_Ha = 'H1_6563A_b'
band_edges23_Ha = np.array([6438.03, 6508.66, 6535.10, 6600.95, 6627.70, 6661.82])
fit_conf23_Ha = {'H1_6563A_b': 'H1_6563A+N2_6584A+N2_6548A',
            'N2_6548A_amp': {'expr': 'N2_6584A_amp/2.94'},
            'N2_6548A_kinem': 'N2_6584A'}

# %%
# New attempt including the fit configuration
spec23.fit.bands(line23_Ha, band_edges23_Ha, fit_conf=fit_conf23_Ha)
spec23.plot.bands()
# Out:
# LiMe WARNING: Gaussian fit uncertainty estimation failed for H1_6563A_b

# %%
spec23.fit.bands(6563)
spec23.plot.bands()

# %%
spec23.fit.bands('H1_4861A')
spec23.plot.bands()
# Out:
# LiMe WARNING: Line H1_4861A introduced as an emission but the line peak is below the continuum level
# LiMe WARNING: Line H1_4861A introduced as an absorption but the line peak is below the continuum level

# %%
spec23.fit.frame
# Out:
# <bound method SpecTreatment.frame of <lime.workflow.SpecTreatment object at 0x13da686b0>>

# %%
spec23.plot.grid()

# %%
spec23.save_frame('slit23_Hae_Hb.txt')

# %%
hdul25 = fits.open('../../../../reduccion/NGC1313/cal2_pcULS/espectros/slit25_1D.fits', mode='update')
header25 = hdul25[0].header
#header['BUNIT'] = '1e-15 erg / (Angstrom s cm2)'
header25['FLUXSCAL'] = 1
header25
    
hdul25.flush()

# %%
#now we specify the location and load the data
#address of NGC1313 spectrum (in this case, here)
fits_file25 = '../../../../reduccion/NGC1313/cal2_pcULS/espectros/slit25_1D.fits'

#load the data
wave25, flux25, hdr25 = import_1313_fits(fits_file25)

# %%
spec25 = lime.Spectrum(wave25, flux25, redshift=z_obj, norm_flux=normFlux, units_flux='1e-15 * FLAM')

# %%
spec25.plot.spectrum(label='NGC1313')

# %%
# Line name, its location mask in the rest _frame and fit configuration
line25_Ha = 'H1_6563A_b'
band_edges25_Ha = np.array([6438.03, 6508.66, 6535.10, 6600.95, 6627.70, 6661.82])
fit_conf25_Ha = {'H1_6563A_b': 'H1_6563A+N2_6584A+N2_6548A',
            'N2_6548A_amp': {'expr': 'N2_6584A_amp/2.94'},
            'N2_6548A_kinem': 'N2_6584A'}

# %%
# New attempt including the fit configuration
spec25.fit.bands(line25_Ha, band_edges25_Ha, fit_conf=fit_conf25_Ha)
spec25.plot.bands()

# %%
spec25.fit.bands('H1_4861A')
spec25.plot.bands()

# %%
# Line name and its location mask in the rest _frame
line25_Hb = 'H1_4861A'
#band_edges = np.array([4809.80, 4836.10, 4848.715437, 4876.181741, 4883.13, 4908.40])
band_edges25_Hb = np.array([4809.80, 4836.10, 4851, 4876.181741, 4883.13, 4908.40])

# %%
# New attempt including the fit configuration
spec25.fit.bands(line25_Hb, band_edges25_Hb)
spec25.plot.bands()

# %%
spec25.fit.frame
# Out:
# <bound method SpecTreatment.frame of <lime.workflow.SpecTreatment object at 0x13d5b4620>>

# %%
spec25.plot.grid()

# %%
spec25.save_frame('slit25_Hae_Hb.txt')

# %%
hdul27 = fits.open('../../../../reduccion/NGC1313/cal2_pcULS/espectros/slit27_1D.fits', mode='update')
header27 = hdul27[0].header
#header['BUNIT'] = '1e-15 erg / (Angstrom s cm2)'
header27['FLUXSCAL'] = 1
header27
    
hdul27.flush()

# %%
#now we specify the location and load the data
#address of NGC1313 spectrum (in this case, here)
fits_file27 = '../../../../reduccion/NGC1313/cal2_pcULS/espectros/slit27_1D.fits'

#load the data
wave27, flux27, hdr27 = import_1313_fits(fits_file27)

# %%
spec27 = lime.Spectrum(wave27, flux27, redshift=z_obj, norm_flux=normFlux, units_flux='1e-15 * FLAM')

# %%
spec27.plot.spectrum(label='NGC1313')

# %%
# Line name, its location mask in the rest _frame and fit configuration
line27_Ha = 'H1_6563A_b'
band_edges27_Ha = np.array([6438.03, 6508.66, 6535.10, 6600.95, 6627.70, 6661.82])
fit_conf27_Ha = {'H1_6563A_b': 'H1_6563A+N2_6584A+N2_6548A',
            'N2_6548A_amp': {'expr': 'N2_6584A_amp/2.94'},
            'N2_6548A_kinem': 'N2_6584A'}

# %%
# New attempt including the fit configuration
spec27.fit.bands(line27_Ha, band_edges27_Ha, fit_conf=fit_conf27_Ha)
spec27.plot.bands()

# %%
spec27.fit.bands('H1_4861A')
spec27.plot.bands()

# %%
# Line name and its location mask in the rest _frame
line27_Hb = 'H1_4861A'
#band_edges = np.array([4809.80, 4836.10, 4848.715437, 4876.181741, 4883.13, 4908.40])
band_edges27_Hb = np.array([4809.80, 4836.10, 4848.715437, 4870.5, 4883.13, 4908.40])

# %%
# Run the fitting and plot it
spec27.fit.bands(line27_Hb, band_edges27_Hb)
spec27.plot.bands()

# %%
spec27.fit.frame
# Out:
# <bound method SpecTreatment.frame of <lime.workflow.SpecTreatment object at 0x13f6c0560>>

# %%
spec27.plot.grid()

# %%
spec27.save_frame('slit27_Hae_Hbe.txt')
